# %%
# Import necessary packages.

import networkx as nx
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from PIL import Image
from keras.models import Model
import random
import time
from itertools import combinations
from pulp import LpBinary, LpMaximize, LpMinimize, LpProblem, LpVariable, lpSum

# %%
# Graph helper functions.
def neighborhood(G, v):
    return list(nx.neighbors(G, v))

def set_neighborhood(G, nodes):
    N = set()
    for n in nodes:
        N |= set(neighborhood(G, n))
    return list(N)

def closed_neighborhood(G, v):
    return list(set(neighborhood(G, v)).union([v]))

# %%
# Set up a linear-integer optimization formulation to compute exactly a largest
# independent set in a graph.
def max_independent_set_ilp(G):
    prob = LpProblem("max-independent-set", LpMaximize)
    variables = {
        node: LpVariable("x{}".format(i + 1), 0, 1, LpBinary)
        for i, node in enumerate(G.nodes())
    }
    prob += lpSum(variables)
    for e in G.edges():
        prob += variables[e[0]] + variables[e[1]] <= 1
    prob.solve()
    solution_set = {node for node in variables if variables[node].value() == 1}
    return solution_set

# Compute the independence number of a graph exactly.
def independence_number(G):
    return len(max_independent_set_ilp(G))

# %%
# Function to convert adjacency matrix and heatmap to fixed-size image.
def convert_to_heatmap_image(G, target_size=64):
    adj_matrix = nx.to_numpy_array(G)
    matrix_size = adj_matrix.shape[0]

    if matrix_size < target_size:
        padded_matrix = np.zeros((target_size, target_size), dtype=int)
        padded_matrix[:matrix_size, :matrix_size] = adj_matrix
    elif matrix_size > target_size:
        image = Image.fromarray(adj_matrix)
        padded_matrix = np.array(image.resize((target_size, target_size), Image.BILINEAR))
    else:
        padded_matrix = adj_matrix

    degree_dict = dict(G.degree())
    degrees = np.array([degree_dict[node] for node in G.nodes()])
    heatmap = np.zeros((target_size, target_size), dtype=float)

    for i, node in enumerate(G.nodes()):
        if i < target_size:
            heatmap[i, i] = degrees[i]

    combined_matrix = padded_matrix + heatmap
    combined_image = (combined_matrix / combined_matrix.max() * 255).astype(np.uint8)

    return Image.fromarray(combined_image, 'L')

# Function to generate random graphs and calculate their independence number.
def generate_independence_number_data(num_graphs, max_nodes):
    graphs = []
    independence_numbers = []
    for _ in range(num_graphs):
        num_nodes = random.randint(5, max_nodes)
        G = nx.gnp_random_graph(num_nodes, np.random.rand())
        ind_num = independence_number(G)
        graphs.append(G)
        independence_numbers.append(ind_num)
    return graphs, independence_numbers

# %%
G = nx.gnp_random_graph(45, 0.5)
nx.draw(G)
plt.show()

# %%
image = convert_to_heatmap_image(G)
plt.imshow(image, cmap='viridis', aspect='auto')
plt.show()

# %%
# Create graphs with different numbers of vertices
graphs = [
    nx.gnp_random_graph(10, 0.5),
    nx.gnp_random_graph(25, 0.5),
    nx.gnp_random_graph(45, 0.5),
    nx.gnp_random_graph(65, 0.5)
]

# Create a figure with 2x2 subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 10))

# Titles for the subplots
titles = ['10 vertices', '25 vertices', '45 vertices', '65 vertices']

for i, (G, ax) in enumerate(zip(graphs, axs.flatten())):
    image = convert_to_heatmap_image(G)
    ax.imshow(image, cmap='viridis', aspect='auto')
    ax.set_title(titles[i])
    ax.axis('off')  # Hide the axes

plt.tight_layout()
plt.show()

# %%
# Generate dataset of 2,000 random graphs with varying node sizes 10 <= n <= 64.
num_graphs = 2_000
max_nodes = 64
graphs, independence_numbers = generate_independence_number_data(num_graphs, max_nodes)

# Convert graphs to images.
target_size = 64
images = [convert_to_heatmap_image(graph, target_size) for graph in graphs]
X = np.array([np.array(image).reshape(target_size, target_size, 1) for image in images])
y = np.array(independence_numbers)

# Split dataset into training and testing.
split_index = int(0.8 * num_graphs)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/b59a86e76c044c35b651720c13f62121-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/b59a86e76c044c35b651720c13f62121-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 129 RHS
# At line 139 BOUNDS
# At line 172 ENDATA
# Problem MODEL has 9 rows, 32 columns and 18 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 25 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -25 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                25.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/7e23dba222da4b3c880134b870f69a43-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/7e23dba222da4b3c880134b870f69a43-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 132 COLUMNS
# At line 543 RHS
# At line 671 BOUNDS
# At line 724 ENDATA
# Problem MODEL has 127 rows, 52 columns and 254 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 26 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0004I processed model has 106 rows, 52 columns (52 integer (52 of which binary)) and 226 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 20 integers unsatisfied sum - 10
# Cbc0038I Solution found of -14
# Cbc0038I Before mini branch and bound, 32 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 106 rows 52 columns, reduced to 20 rows 16 columns
# Cbc0038I Mini branch and bound improved solution from -14 to -24 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -24 - took 0.00 seconds
# Cbc0012I Integer solution of -24 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -24, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -24 to -24
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                24.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/c6914ded05894f83a2094725fbd6277f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/c6914ded05894f83a2094725fbd6277f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 72 COLUMNS
# At line 252 RHS
# At line 320 BOUNDS
# At line 336 ENDATA
# Problem MODEL has 67 rows, 15 columns and 134 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 56 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 44 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 37 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 15 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 32 rows, 15 columns (15 integer (15 of which binary)) and 144 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -4
# Cbc0038I Before mini branch and bound, 15 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -4 - took 0.00 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -4, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -4 to -4
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/04281f95bbd340d2aa8ede565572586b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/04281f95bbd340d2aa8ede565572586b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 79 COLUMNS
# At line 267 RHS
# At line 342 BOUNDS
# At line 356 ENDATA
# Problem MODEL has 74 rows, 13 columns and 148 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 6.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 74 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 62 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 59 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 56 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 48 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 36 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0004I processed model has 39 rows, 13 columns (13 integer (13 of which binary)) and 351 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -2 - took 0.00 seconds
# Cbc0012I Integer solution of -2 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -2, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -2 to -2
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/83edf413dafa43a3ae23614b7f7c152c-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/83edf413dafa43a3ae23614b7f7c152c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 51 COLUMNS
# At line 195 RHS
# At line 242 BOUNDS
# At line 260 ENDATA
# Problem MODEL has 46 rows, 17 columns and 92 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 8.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 15 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 23 rows, 15 columns (15 integer (15 of which binary)) and 66 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 11 integers unsatisfied sum - 5.5
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 23 rows 15 columns, reduced to 15 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from -1 to -6 (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -6 - took 0.00 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -6, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 2 variables fixed on reduced cost
# Cuts at root node changed objective from -6.5 to -6.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/6aa391e70ffd444c88ff6110b04c1389-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/6aa391e70ffd444c88ff6110b04c1389-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 44 COLUMNS
# At line 165 RHS
# At line 205 BOUNDS
# At line 220 ENDATA
# Problem MODEL has 39 rows, 14 columns and 78 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 22 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0004I processed model has 19 rows, 14 columns (14 integer (14 of which binary)) and 58 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -5
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -5 - took 0.00 seconds
# Cbc0012I Integer solution of -5 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -5, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -5 to -5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d2b1c7ddf523401ba140eff9e00f6320-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d2b1c7ddf523401ba140eff9e00f6320-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 135 COLUMNS
# At line 588 RHS
# At line 719 BOUNDS
# At line 784 ENDATA
# Problem MODEL has 130 rows, 64 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 33 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0004I processed model has 89 rows, 52 columns (52 integer (52 of which binary)) and 190 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 40 integers unsatisfied sum - 20
# Cbc0038I Solution found of -10
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 89 rows 52 columns, reduced to 69 rows 40 columns
# Cbc0038I Mini branch and bound improved solution from -10 to -30 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -30 - took 0.00 seconds
# Cbc0012I Integer solution of -30 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -30, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -30 to -30
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                30.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/62e9c1f243d34cdca5c0ee16112609d3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/62e9c1f243d34cdca5c0ee16112609d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 245 COLUMNS
# At line 813 RHS
# At line 1054 BOUNDS
# At line 1084 ENDATA
# Problem MODEL has 240 rows, 29 columns and 480 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 14.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 240 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 199 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 156 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 69 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 140 rows, 29 columns (29 integer (29 of which binary)) and 730 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 28 integers unsatisfied sum - 5.52
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 140 rows 29 columns, reduced to 140 rows 28 columns - 1 fixed gives 110, 18 - ok now
# Cbc0038I Full problem 140 rows 29 columns, reduced to 110 rows 18 columns
# Cbc0038I Mini branch and bound improved solution from -1 to -5 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -5 - took 0.00 seconds
# Cbc0012I Integer solution of -5 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -5, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -5.56 to -5.56
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/acd593a874984755a5fe9412a6669b43-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/acd593a874984755a5fe9412a6669b43-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 126 COLUMNS
# At line 444 RHS
# At line 566 BOUNDS
# At line 592 ENDATA
# Problem MODEL has 121 rows, 25 columns and 242 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 76 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 64 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 66 rows, 25 columns (25 integer (25 of which binary)) and 221 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 15 integers unsatisfied sum - 7.5
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 10 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 66 rows 25 columns, reduced to 31 rows 15 columns
# Cbc0038I Mini branch and bound improved solution from -2 to -6 (0.01 seconds)
# Cbc0038I Round again with cutoff of -7.04991
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 2
# Cbc0038I Pass   1: suminf.    5.54961 (17) obj. -7.04991 iterations 22
# Cbc0038I Pass   2: suminf.    5.14973 (21) obj. -7.04991 iterations 10
# Cbc0038I Pass   3: suminf.    5.01624 (21) obj. -7.04991 iterations 5
# Cbc0038I Pass   4: suminf.    6.18240 (20) obj. -7.04991 iterations 21
# Cbc0038I Pass   5: suminf.    5.24955 (18) obj. -7.04991 iterations 12
# Cbc0038I Pass   6: suminf.    5.24955 (18) obj. -7.04991 iterations 1
# Cbc0038I Pass   7: suminf.    7.04991 (15) obj. -7.04991 iterations 17
# Cbc0038I Pass   8: suminf.    6.11646 (22) obj. -7.04991 iterations 18
# Cbc0038I Pass   9: suminf.    5.08258 (21) obj. -7.04991 iterations 9
# Cbc0038I Pass  10: suminf.    4.94949 (19) obj. -7.04991 iterations 4
# Cbc0038I Pass  11: suminf.    7.04991 (15) obj. -7.04991 iterations 22
# Cbc0038I Pass  12: suminf.    5.24955 (15) obj. -7.04991 iterations 13
# Cbc0038I Pass  13: suminf.    5.24955 (15) obj. -7.04991 iterations 7
# Cbc0038I Pass  14: suminf.    6.14973 (16) obj. -7.04991 iterations 33
# Cbc0038I Pass  15: suminf.    6.14973 (16) obj. -7.04991 iterations 8
# Cbc0038I Pass  16: suminf.    5.24955 (15) obj. -7.04991 iterations 20
# Cbc0038I Pass  17: suminf.    5.24955 (18) obj. -7.04991 iterations 7
# Cbc0038I Pass  18: suminf.    5.24955 (18) obj. -7.04991 iterations 1
# Cbc0038I Pass  19: suminf.    7.04991 (15) obj. -7.04991 iterations 17
# Cbc0038I Pass  20: suminf.    6.11646 (22) obj. -7.04991 iterations 12
# Cbc0038I Pass  21: suminf.    5.08258 (21) obj. -7.04991 iterations 9
# Cbc0038I Pass  22: suminf.    4.94949 (19) obj. -7.04991 iterations 4
# Cbc0038I Pass  23: suminf.    7.04991 (15) obj. -7.04991 iterations 20
# Cbc0038I Pass  24: suminf.    5.24955 (15) obj. -7.04991 iterations 19
# Cbc0038I Pass  25: suminf.    5.24955 (20) obj. -7.04991 iterations 9
# Cbc0038I Pass  26: suminf.    7.04991 (18) obj. -7.04991 iterations 19
# Cbc0038I Pass  27: suminf.    6.11646 (22) obj. -7.04991 iterations 20
# Cbc0038I Pass  28: suminf.    5.08258 (21) obj. -7.04991 iterations 9
# Cbc0038I Pass  29: suminf.    4.94949 (19) obj. -7.04991 iterations 4
# Cbc0038I Pass  30: suminf.    5.34937 (18) obj. -7.04991 iterations 13
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 66 rows 25 columns, reduced to 64 rows 23 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -6 - took 0.01 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 66 rows 25 columns, reduced to 31 rows 15 columns
# Cbc0031I 6 added rows had average density of 16
# Cbc0013I At root node, 35 cuts changed objective from -7.5 to -6.75 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 12 row cuts average 22.8 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 25 row cuts average 22.8 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 39 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -6, took 26 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 2 variables fixed on reduced cost
# Cuts at root node changed objective from -7.5 to -6.75
# Probing was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 25 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 2 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               26
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/5c00b8635e83439c81c95a1c95e5eb32-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/5c00b8635e83439c81c95a1c95e5eb32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 286 COLUMNS
# At line 972 RHS
# At line 1254 BOUNDS
# At line 1296 ENDATA
# Problem MODEL has 281 rows, 41 columns and 562 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 20.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 209 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 158 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 70 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 169 rows, 41 columns (41 integer (41 of which binary)) and 612 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 37 integers unsatisfied sum - 11
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 169 rows 41 columns, reduced to 165 rows 37 columns - 0 fixed gives 165, 37 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -2.90791
# Cbc0038I Pass   1: suminf.    0.09209 (1) obj. -2.90791 iterations 61
# Cbc0038I Solution found of -3
# Cbc0038I Rounding solution of -7 is better than previous of -3
#
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 169 rows 41 columns, reduced to 165 rows 37 columns - 1 fixed gives 120, 28 - ok now
# Cbc0038I Full problem 169 rows 41 columns, reduced to 120 rows 28 columns
# Cbc0038I Mini branch and bound improved solution from -7 to -9 (0.02 seconds)
# Cbc0038I Round again with cutoff of -10.2159
# Cbc0038I Pass   2: suminf.    7.37512 (26) obj. -10.2159 iterations 61
# Cbc0038I Pass   3: suminf.    3.21986 (38) obj. -10.2159 iterations 25
# Cbc0038I Pass   4: suminf.    2.85494 (39) obj. -10.2159 iterations 8
# Cbc0038I Pass   5: suminf.    7.82388 (24) obj. -10.2159 iterations 55
# Cbc0038I Pass   6: suminf.    6.47164 (28) obj. -10.2159 iterations 24
# Cbc0038I Pass   7: suminf.    6.30068 (28) obj. -10.2159 iterations 6
# Cbc0038I Pass   8: suminf.    6.30068 (28) obj. -10.2159 iterations 6
# Cbc0038I Pass   9: suminf.    7.86368 (27) obj. -10.2159 iterations 44
# Cbc0038I Pass  10: suminf.    6.95964 (30) obj. -10.2159 iterations 12
# Cbc0038I Pass  11: suminf.    6.91766 (29) obj. -10.2159 iterations 10
# Cbc0038I Pass  12: suminf.   10.21592 (22) obj. -10.2159 iterations 49
# Cbc0038I Pass  13: suminf.    8.88259 (27) obj. -10.2159 iterations 85
# Cbc0038I Pass  14: suminf.    7.81105 (32) obj. -10.2159 iterations 30
# Cbc0038I Pass  15: suminf.    7.05970 (33) obj. -10.2159 iterations 25
# Cbc0038I Pass  16: suminf.    6.07960 (26) obj. -10.2159 iterations 11
# Cbc0038I Pass  17: suminf.    6.07960 (24) obj. -10.2159 iterations 4
# Cbc0038I Pass  18: suminf.    9.83715 (28) obj. -10.2159 iterations 57
# Cbc0038I Pass  19: suminf.    8.65167 (34) obj. -10.2159 iterations 23
# Cbc0038I Pass  20: suminf.    6.89235 (33) obj. -10.2159 iterations 18
# Cbc0038I Pass  21: suminf.    6.53919 (36) obj. -10.2159 iterations 14
# Cbc0038I Pass  22: suminf.    8.86368 (29) obj. -10.2159 iterations 49
# Cbc0038I Pass  23: suminf.    7.15533 (25) obj. -10.2159 iterations 26
# Cbc0038I Pass  24: suminf.    7.15533 (25) obj. -10.2159 iterations 6
# Cbc0038I Pass  25: suminf.    8.28980 (24) obj. -10.2159 iterations 16
# Cbc0038I Pass  26: suminf.    6.73219 (25) obj. -10.2159 iterations 22
# Cbc0038I Pass  27: suminf.    6.30068 (28) obj. -10.2159 iterations 19
# Cbc0038I Pass  28: suminf.    6.30068 (28) obj. -10.2159 iterations 8
# Cbc0038I Pass  29: suminf.    8.67502 (25) obj. -10.2159 iterations 45
# Cbc0038I Pass  30: suminf.    7.83715 (28) obj. -10.2159 iterations 13
# Cbc0038I Pass  31: suminf.    6.95964 (30) obj. -10.2159 iterations 16
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 169 rows 41 columns, reduced to 169 rows 40 columns - 1 fixed gives 132, 29 - ok now
# Cbc0038I Full problem 169 rows 41 columns, reduced to 128 rows 28 columns
# Cbc0038I Mini branch and bound improved solution from -9 to -10 (0.03 seconds)
# Cbc0038I Round again with cutoff of -11.0239
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 4
# Cbc0038I Pass  31: suminf.   10.42013 (39) obj. -11.0239 iterations 38
# Cbc0038I Pass  32: suminf.   10.29100 (36) obj. -11.0239 iterations 13
# Cbc0038I Pass  33: suminf.   10.28974 (36) obj. -11.0239 iterations 2
# Cbc0038I Pass  34: suminf.   11.00000 (38) obj. -11.0239 iterations 21
# Cbc0038I Pass  35: suminf.   10.74274 (40) obj. -11.0239 iterations 19
# Cbc0038I Pass  36: suminf.   10.69648 (40) obj. -11.0239 iterations 8
# Cbc0038I Pass  37: suminf.   10.59639 (37) obj. -11.0239 iterations 10
# Cbc0038I Pass  38: suminf.   10.58061 (37) obj. -11.0239 iterations 3
# Cbc0038I Pass  39: suminf.   10.64763 (36) obj. -11.0239 iterations 13
# Cbc0038I Pass  40: suminf.   10.30147 (36) obj. -11.0239 iterations 5
# Cbc0038I Pass  41: suminf.   10.28974 (36) obj. -11.0239 iterations 2
# Cbc0038I Pass  42: suminf.   11.02393 (38) obj. -11.0239 iterations 22
# Cbc0038I Pass  43: suminf.   11.00084 (39) obj. -11.0239 iterations 21
# Cbc0038I Pass  44: suminf.   10.80154 (40) obj. -11.0239 iterations 20
# Cbc0038I Pass  45: suminf.   11.02393 (39) obj. -11.0239 iterations 20
# Cbc0038I Pass  46: suminf.   10.98297 (39) obj. -11.0239 iterations 13
# Cbc0038I Pass  47: suminf.   10.74274 (40) obj. -11.0239 iterations 17
# Cbc0038I Pass  48: suminf.   10.69648 (40) obj. -11.0239 iterations 8
# Cbc0038I Pass  49: suminf.   10.59639 (37) obj. -11.0239 iterations 10
# Cbc0038I Pass  50: suminf.   10.58061 (37) obj. -11.0239 iterations 3
# Cbc0038I Pass  51: suminf.   10.76048 (37) obj. -11.0239 iterations 16
# Cbc0038I Pass  52: suminf.   10.30147 (36) obj. -11.0239 iterations 6
# Cbc0038I Pass  53: suminf.   10.28974 (36) obj. -11.0239 iterations 2
# Cbc0038I Pass  54: suminf.   11.02393 (38) obj. -11.0239 iterations 16
# Cbc0038I Pass  55: suminf.   10.74274 (40) obj. -11.0239 iterations 19
# Cbc0038I Pass  56: suminf.   10.69648 (40) obj. -11.0239 iterations 8
# Cbc0038I Pass  57: suminf.   10.70051 (37) obj. -11.0239 iterations 18
# Cbc0038I Pass  58: suminf.   10.30267 (36) obj. -11.0239 iterations 8
# Cbc0038I Pass  59: suminf.   10.28974 (36) obj. -11.0239 iterations 1
# Cbc0038I Pass  60: suminf.   11.02393 (38) obj. -11.0239 iterations 29
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 169 rows 41 columns, reduced to 169 rows 40 columns - 1 fixed gives 132, 29 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -10 - took 0.02 seconds
# Cbc0012I Integer solution of -10 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0031I 8 added rows had average density of 16
# Cbc0013I At root node, 67 cuts changed objective from -11.08 to -10.621001 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 17 row cuts average 31.6 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 31 row cuts average 31.6 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 18 row cuts average 6.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -10, took 75 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -11.08 to -10.621
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.00000000
# Enumerated nodes:               0
# Total iterations:               75
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.04
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/7bce876091764026aff634f520a7ad3b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/7bce876091764026aff634f520a7ad3b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1363 COLUMNS
# At line 4242 RHS
# At line 5601 BOUNDS
# At line 5656 ENDATA
# Problem MODEL has 1358 rows, 54 columns and 2716 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 27 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1358 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1305 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1280 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1251 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1244 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1231 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1223 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1222 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1221 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1221 rows, 54 columns (54 integer (54 of which binary)) and 13431 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 38 integers unsatisfied sum - 8.76
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1221 rows 54 columns, reduced to 1022 rows 38 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (1.37 seconds)
# Cbc0038I Round again with cutoff of -1.77591
# Cbc0038I Pass   1: suminf.    1.77591 (5) obj. -1.77591 iterations 353
# Cbc0038I Pass   2: suminf.    2.00000 (4) obj. -2 iterations 4
# Cbc0038I Pass   3: suminf.    3.00000 (6) obj. -3 iterations 14
# Cbc0038I Pass   4: suminf.    0.22409 (1) obj. -1.77591 iterations 19
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -3 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 15 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1221 rows 54 columns, reduced to 1041 rows 39 columns - 1 fixed gives 0, 0 - ok now
# Cbc0038I Mini branch and bound did not improve solution (1.40 seconds)
# Cbc0038I Round again with cutoff of -4.95192
# Cbc0038I Reduced cost fixing fixed 6 variables on major pass 3
# Cbc0038I Pass   5: suminf.    4.95192 (18) obj. -4.95192 iterations 42
# Cbc0038I Pass   6: suminf.    5.29412 (18) obj. -5.35294 iterations 22
# Cbc0038I Pass   7: suminf.    4.08205 (23) obj. -4.95192 iterations 46
# Cbc0038I Pass   8: suminf.    3.68990 (20) obj. -4.95192 iterations 14
# Cbc0038I Pass   9: suminf.    4.95192 (10) obj. -4.95192 iterations 47
# Cbc0038I Pass  10: suminf.    4.95192 (15) obj. -4.95192 iterations 34
# Cbc0038I Pass  11: suminf.    4.95192 (18) obj. -4.95192 iterations 47
# Cbc0038I Pass  12: suminf.    4.95192 (14) obj. -4.95192 iterations 36
# Cbc0038I Pass  13: suminf.    4.09203 (23) obj. -4.95192 iterations 45
# Cbc0038I Pass  14: suminf.    3.62664 (25) obj. -4.95192 iterations 27
# Cbc0038I Pass  15: suminf.    4.95192 (16) obj. -4.95192 iterations 51
# Cbc0038I Pass  16: suminf.    4.95192 (18) obj. -4.95192 iterations 74
# Cbc0038I Pass  17: suminf.    4.91667 (15) obj. -5.08333 iterations 21
# Cbc0038I Pass  18: suminf.    4.08205 (23) obj. -4.95192 iterations 43
# Cbc0038I Pass  19: suminf.    3.68990 (20) obj. -4.95192 iterations 24
# Cbc0038I Pass  20: suminf.    4.95192 (10) obj. -4.95192 iterations 51
# Cbc0038I Pass  21: suminf.    4.95192 (18) obj. -4.95192 iterations 52
# Cbc0038I Pass  22: suminf.    4.95192 (18) obj. -4.95192 iterations 12
# Cbc0038I Pass  23: suminf.    4.87500 (20) obj. -4.95192 iterations 48
# Cbc0038I Pass  24: suminf.    4.15629 (25) obj. -4.95192 iterations 65
# Cbc0038I Pass  25: suminf.    3.87440 (26) obj. -4.95192 iterations 25
# Cbc0038I Pass  26: suminf.    4.95192 (14) obj. -4.95192 iterations 49
# Cbc0038I Pass  27: suminf.    4.95192 (15) obj. -4.95192 iterations 30
# Cbc0038I Pass  28: suminf.    4.95192 (18) obj. -4.95192 iterations 43
# Cbc0038I Pass  29: suminf.    5.29412 (18) obj. -5.35294 iterations 25
# Cbc0038I Pass  30: suminf.    4.08205 (23) obj. -4.95192 iterations 36
# Cbc0038I Pass  31: suminf.    3.68990 (20) obj. -4.95192 iterations 14
# Cbc0038I Pass  32: suminf.    4.95192 (10) obj. -4.95192 iterations 54
# Cbc0038I Pass  33: suminf.    4.95192 (18) obj. -4.95192 iterations 67
# Cbc0038I Pass  34: suminf.    4.55192 (15) obj. -4.95192 iterations 20
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1221 rows 54 columns, reduced to 1168 rows 42 columns - 1 fixed gives 0, 0 - ok now
# Cbc0038I Mini branch and bound did not improve solution (1.50 seconds)
# Cbc0038I After 1.50 seconds - Feasibility pump exiting with objective of -3 - took 0.13 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (1.50 seconds)
# Cbc0038I Full problem 1221 rows 54 columns, reduced to 1066 rows 39 columns - 3 fixed gives 0, 0 - ok now
# Cbc0006I The LP relaxation is infeasible or too expensive
# ...
# Cbc0038I Pass  15: suminf.    1.85041 (33) obj. -4.15833 iterations 63
# Cbc0038I Pass  16: suminf.    1.38850 (39) obj. -4.15833 iterations 57
# Cbc0038I Pass  17: suminf.    1.57139 (36) obj. -4.15833 iterations 52
# Cbc0038I Pass  18: suminf.    1.40581 (42) obj. -4.15833 iterations 41
# Cbc0038I Pass  19: suminf.    4.15833 (23) obj. -4.15833 iterations 95
# Cbc0038I Pass  20: suminf.    4.15833 (33) obj. -4.15833 iterations 76
# Cbc0038I Pass  21: suminf.    4.15833 (24) obj. -4.15833 iterations 46
# Cbc0038I Pass  22: suminf.    4.15833 (34) obj. -4.15833 iterations 87
# Cbc0038I Pass  23: suminf.    4.15833 (30) obj. -4.15833 iterations 89
# Cbc0038I Pass  24: suminf.    2.33804 (32) obj. -4.15833 iterations 75
# Cbc0038I Pass  25: suminf.    1.44543 (43) obj. -4.15833 iterations 75
# Cbc0038I Pass  26: suminf.    4.29630 (24) obj. -4.32593 iterations 96
# Cbc0038I Pass  27: suminf.    1.85041 (33) obj. -4.15833 iterations 95
# Cbc0038I Pass  28: suminf.    1.38850 (39) obj. -4.15833 iterations 57
# Cbc0038I Pass  29: suminf.    3.43835 (28) obj. -4.15833 iterations 97
# Cbc0038I Pass  30: suminf.    1.40581 (42) obj. -4.15833 iterations 68
# Cbc0038I Pass  31: suminf.    2.12561 (24) obj. -4.15833 iterations 115
# Cbc0038I Pass  32: suminf.    4.15833 (34) obj. -4.15833 iterations 91
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 962 rows 51 columns, reduced to 956 rows 49 columns - 2 fixed gives 0, 0 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.63 seconds)
# Cbc0038I After 0.63 seconds - Feasibility pump exiting with objective of -3 - took 0.14 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.63 seconds)
# Cbc0012I Integer solution of -4 found by DiveCoefficient after 11178 iterations and 0 nodes (2.03 seconds)
# Cbc0031I 39 added rows had average density of 19.974359
# Cbc0013I At root node, 39 cuts changed objective from -4.7920604 to -4.074098 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 1539 row cuts average 11.8 elements, 0 column cuts (0 active)  in 0.177 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2145 row cuts average 50.0 elements, 0 column cuts (0 active)  in 0.040 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 606 row cuts average 11.7 elements, 0 column cuts (0 active)  in 0.054 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.062 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -4, took 11178 iterations and 0 nodes (2.03 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -4.79206 to -4.0741
# Probing was tried 100 times and created 1539 cuts of which 0 were active after adding rounds of cuts (0.177 seconds)
# Gomory was tried 100 times and created 2145 cuts of which 0 were active after adding rounds of cuts (0.040 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# Clique was tried 100 times and created 606 cuts of which 0 were active after adding rounds of cuts (0.054 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.062 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               11178
# Time (CPU seconds):             1.99
# Time (Wallclock seconds):       2.05
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.99   (Wallclock seconds):       2.05
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[54], line 4
#       2 num_graphs = 1000
#       3 max_nodes = 64
# ----> 4 graphs, independence_numbers = generate_independence_number_data(num_graphs, max_nodes)
#       6 # Convert graphs to images.
#       7 target_size = 64
#
# Cell In[50], line 35, in generate_independence_number_data(num_graphs, max_nodes)
#      33 num_nodes = random.randint(5, max_nodes)
#      34 G = nx.gnp_random_graph(num_nodes, np.random.rand())
# ---> 35 ind_num = independence_number(G)
#      36 graphs.append(G)
#      37 independence_numbers.append(ind_num)
#
# Cell In[49], line 18, in independence_number(G)
#      17 def independence_number(G):
# ---> 18     return len(max_independent_set_ilp(G))
#
# Cell In[49], line 12, in max_independent_set_ilp(G)
#      10 for e in G.edges():
#      11     prob += variables[e[0]] + variables[e[1]] <= 1
# ---> 12 prob.solve()
#      13 solution_set = {node for node in variables if variables[node].value() == 1}
#      14 return solution_set
#
# File /opt/anaconda3/lib/python3.12/site-packages/pulp/pulp.py:2007, in LpProblem.solve(self, solver, **kwargs)
#    2005 # time it
#    2006 self.startClock()
# -> 2007 status = solver.actualSolve(self, **kwargs)
#    2008 self.stopClock()
#    2009 self.restoreObjective(wasNone, dummyVar)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/coin_api.py:128, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     126 def actualSolve(self, lp: LpProblem, **kwargs):
#     127     """Solve a well formulated lp problem"""
# --> 128     return self.solve_CBC(lp, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/coin_api.py:206, in COIN_CMD.solve_CBC(self, lp, use_mps)
#     204 else:
#     205     cbc = subprocess.Popen(args, stdout=pipe, stderr=pipe, stdin=devnull)
# --> 206 if cbc.wait() != 0:
#     207     if pipe:
#     208         pipe.close()
#
# File /opt/anaconda3/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/anaconda3/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File /opt/anaconda3/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/54ba57d581d94f81a9891bbc9086efc5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/54ba57d581d94f81a9891bbc9086efc5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 904 COLUMNS
# At line 2832 RHS
# At line 3732 BOUNDS
# At line 3776 ENDATA
# Problem MODEL has 899 rows, 43 columns and 1798 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 21.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 899 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 850 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 840 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 817 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 816 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 807 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 802 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 799 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 797 strengthened rows, 0 substitutions
# Cgl0004I processed model has 797 rows, 43 columns (43 integer (43 of which binary)) and 8767 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 32 integers unsatisfied sum - 8.16811
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 797 rows 43 columns, reduced to 738 rows 32 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.91 seconds)
# Cbc0038I Round again with cutoff of -1.71672
# Cbc0038I Pass   1: suminf.    1.38339 (5) obj. -1.71672 iterations 196
# Cbc0038I Pass   2: suminf.    0.79217 (21) obj. -1.71672 iterations 23
# Cbc0038I Pass   3: suminf.    6.30303 (20) obj. -6.33333 iterations 29
# Cbc0038I Pass   4: suminf.    0.28328 (1) obj. -1.71672 iterations 63
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 797 rows 43 columns, reduced to 793 rows 38 columns - 2 fixed gives 0, 0 - ok now
# Cbc0038I Full problem 797 rows 43 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.92 seconds)
# Cbc0038I Round again with cutoff of -4.03354
# Cbc0038I Reduced cost fixing fixed 9 variables on major pass 3
# Cbc0038I Pass   5: suminf.    4.03354 (12) obj. -4.03354 iterations 14
# Cbc0038I Pass   6: suminf.    3.39043 (19) obj. -4.03354 iterations 41
# Cbc0038I Pass   7: suminf.    5.55263 (18) obj. -5.55263 iterations 33
# Cbc0038I Pass   8: suminf.    4.33333 (13) obj. -4.33333 iterations 35
# Cbc0038I Pass   9: suminf.    4.03354 (9) obj. -4.03354 iterations 24
# Cbc0038I Pass  10: suminf.    4.33333 (13) obj. -4.33333 iterations 24
# Cbc0038I Pass  11: suminf.    4.03354 (12) obj. -4.03354 iterations 20
# Cbc0038I Pass  12: suminf.    4.50000 (9) obj. -4.5 iterations 20
# Cbc0038I Pass  13: suminf.    4.03354 (9) obj. -4.03354 iterations 42
# Cbc0038I Pass  14: suminf.    5.57143 (18) obj. -5.57143 iterations 43
# Cbc0038I Pass  15: suminf.    4.88235 (14) obj. -4.94118 iterations 36
# Cbc0038I Pass  16: suminf.    3.35286 (21) obj. -4.03354 iterations 33
# Cbc0038I Pass  17: suminf.    6.35294 (20) obj. -6.41176 iterations 37
# Cbc0038I Pass  18: suminf.    3.35286 (21) obj. -4.03354 iterations 32
# Cbc0038I Pass  19: suminf.    6.30303 (20) obj. -6.33333 iterations 37
# Cbc0038I Pass  20: suminf.    3.35286 (21) obj. -4.03354 iterations 29
# Cbc0038I Pass  21: suminf.    6.59259 (20) obj. -6.59259 iterations 39
# Cbc0038I Pass  22: suminf.    4.03354 (12) obj. -4.03354 iterations 43
# Cbc0038I Pass  23: suminf.    4.16667 (12) obj. -4.16667 iterations 9
# Cbc0038I Pass  24: suminf.    4.03354 (12) obj. -4.03354 iterations 19
# Cbc0038I Pass  25: suminf.    4.03354 (12) obj. -4.03354 iterations 34
# Cbc0038I Pass  26: suminf.    4.03354 (9) obj. -4.03354 iterations 31
# Cbc0038I Pass  27: suminf.    4.03354 (9) obj. -4.03354 iterations 14
# Cbc0038I Pass  28: suminf.    4.50000 (9) obj. -4.5 iterations 27
# Cbc0038I Pass  29: suminf.    4.03354 (11) obj. -4.03354 iterations 31
# Cbc0038I Pass  30: suminf.    4.03354 (9) obj. -4.03354 iterations 31
# Cbc0038I Pass  31: suminf.    4.03354 (9) obj. -4.03354 iterations 43
# Cbc0038I Pass  32: suminf.    4.50000 (9) obj. -4.5 iterations 19
# Cbc0038I Pass  33: suminf.    4.03354 (12) obj. -4.03354 iterations 26
# Cbc0038I Pass  34: suminf.    4.03354 (10) obj. -4.03354 iterations 22
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 9 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 797 rows 43 columns, reduced to 778 rows 34 columns - 0 fixed gives 778, 34 - still too large
# Cbc0038I Mini branch and bound did not improve solution (1.02 seconds)
# Cbc0038I After 1.02 seconds - Feasibility pump exiting with objective of -2 - took 0.12 seconds
# Cbc0012I Integer solution of -2 found by feasibility pump after 0 iterations and 0 nodes (1.02 seconds)
# Cbc0038I Full problem 797 rows 43 columns, reduced to 762 rows 33 columns - 2 fixed gives 0, 0 - ok now
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from -8.1681109 to -8.1681109 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 36 column cuts (36 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -2, took 0 iterations and 0 nodes (1.04 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Cuts at root node changed objective from -8.16811 to -8.16811
# Probing was tried 1 times and created 37 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             1.00
# Time (Wallclock seconds):       1.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.00   (Wallclock seconds):       1.04

# %%
# Define the CNN model.
def create_model(input_shape):
    model = tf.keras.Sequential()
    model.add(tf.keras.Input(shape=input_shape))
    model.add(layers.Conv2D(32, (3, 3), activation='relu'))

    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.MaxPooling2D((2, 2)))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))  # Output layer for regression

    model.compile(optimizer='adam',
                  loss='mean_squared_error',
                  metrics=['mae'])
    return model

# Instantiate and train the model.
input_shape = (target_size, target_size, 1)
model = create_model(input_shape)
model.summary()
history = model.fit(X_train, y_train, epochs=15, validation_split=0.2)
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_27 (Conv2D)              │ (None, 62, 62, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_12 (MaxPooling2D) │ (None, 31, 31, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 29, 29, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_13 (MaxPooling2D) │ (None, 14, 14, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 12, 12, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_9 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 64)             │       589,888 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 645,697 (2.46 MB)
#  Trainable params: 645,697 (2.46 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 481.2241 - mae: 13.5002 - val_loss: 55.0669 - val_mae: 5.2666
# Epoch 2/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 75.9852 - mae: 6.9435 - val_loss: 111.6201 - val_mae: 7.7127
# Epoch 3/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 66.0059 - mae: 6.5624 - val_loss: 107.8856 - val_mae: 7.6346
# Epoch 4/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 61.7219 - mae: 6.2051 - val_loss: 92.3203 - val_mae: 6.8331
# Epoch 5/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 42.9555 - mae: 4.6210 - val_loss: 72.8007 - val_mae: 5.7859
# Epoch 6/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 35.9188 - mae: 4.0631 - val_loss: 46.7750 - val_mae: 4.5041
# Epoch 7/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 26.4804 - mae: 4.1023 - val_loss: 36.3160 - val_mae: 4.1313
# Epoch 8/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 23.6337 - mae: 3.9950 - val_loss: 40.0283 - val_mae: 4.0823
# Epoch 9/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 18.6947 - mae: 3.2181 - val_loss: 34.6176 - val_mae: 3.7949
# Epoch 10/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 11.7290 - mae: 2.5100 - val_loss: 18.5622 - val_mae: 2.8235
# Epoch 11/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 7.3978 - mae: 2.2174 - val_loss: 13.9351 - val_mae: 2.4436
# Epoch 12/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 4.3508 - mae: 1.4819 - val_loss: 13.2220 - val_mae: 2.5076
# Epoch 13/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 4.3122 - mae: 1.3719 - val_loss: 5.0529 - val_mae: 1.5737
# Epoch 14/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 3.7324 - mae: 1.3691 - val_loss: 5.9603 - val_mae: 1.5796
# Epoch 15/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 3.3005 - mae: 1.3191 - val_loss: 5.5612 - val_mae: 1.4939

# %%
# Evaluate the model.
loss, mae = model.evaluate(X_test, y_test)
print(f'Test MAE: {mae}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 106.9846 - mae: 5.0174
# Test MAE: 5.017374515533447

# %%
# Generate a random graph with n nodes.
n = 30
G = nx.gnp_random_graph(n, np.random.rand())

# Convert adjacency matrix to image with heatmap.
adj_image = convert_to_heatmap_image(G)

# Prepare the image for the model.
input_image = np.array(adj_image).reshape(1, 64, 64, 1)  # Add batch dimension and channel dimension.

# Predict the independence number using the trained CNN.
predicted_independence_number = model.predict(input_image)
print(f"Predicted independence number for the {n}-node graph: {predicted_independence_number[0][0]}")

# Compute the actual independence number using linear-integer programming for comparison.
actual_independence_number = independence_number(G)
print(f"Computed independence number for the {n}-node graph: {actual_independence_number}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Predicted independence number for the 30-node graph: 2.472425937652588
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/6ce6776d984d464a8b068be8a2a891f8-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/6ce6776d984d464a8b068be8a2a891f8-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 402 COLUMNS
# At line 1287 RHS
# At line 1685 BOUNDS
# At line 1716 ENDATA
# Problem MODEL has 397 rows, 30 columns and 794 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 397 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 359 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 349 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 342 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 335 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 331 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 329 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 328 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 328 strengthened rows, 0 substitutions
# Cgl0004I processed model has 328 rows, 30 columns (30 integer (30 of which binary)) and 3608 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 17 integers unsatisfied sum - 3.26087
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 328 rows 30 columns, reduced to 237 rows 17 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.16 seconds)
# Cbc0038I Round again with cutoff of -1.226
# Cbc0038I Pass   1: suminf.    0.22600 (1) obj. -1.226 iterations 143
# Cbc0038I Pass   2: suminf.    0.22600 (1) obj. -1.226 iterations 0
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 328 rows 30 columns, reduced to 237 rows 17 columns - 1 fixed gives 4, 3 - ok now
# Cbc0038I Full problem 328 rows 30 columns, reduced to 4 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.16 seconds)
# Cbc0038I Round again with cutoff of -3.05209
# Cbc0038I Reduced cost fixing fixed 6 variables on major pass 3
# Cbc0038I Pass   3: suminf.    3.05209 (14) obj. -3.05209 iterations 44
# Cbc0038I Pass   4: suminf.    3.16667 (13) obj. -3.16667 iterations 20
# Cbc0038I Pass   5: suminf.    2.82763 (16) obj. -3.05209 iterations 18
# Cbc0038I Pass   6: suminf.    1.26762 (15) obj. -3.05209 iterations 24
# Cbc0038I Pass   7: suminf.    0.96104 (21) obj. -3.05209 iterations 20
# Cbc0038I Pass   8: suminf.    3.05209 (20) obj. -3.05209 iterations 41
# Cbc0038I Pass   9: suminf.    3.05209 (14) obj. -3.05209 iterations 36
# Cbc0038I Pass  10: suminf.    3.16667 (13) obj. -3.16667 iterations 16
# Cbc0038I Pass  11: suminf.    3.05209 (19) obj. -3.05209 iterations 19
# Cbc0038I Pass  12: suminf.    3.05209 (16) obj. -3.05209 iterations 34
# Cbc0038I Pass  13: suminf.    3.05209 (16) obj. -3.05209 iterations 28
# Cbc0038I Pass  14: suminf.    2.93881 (19) obj. -3.05209 iterations 11
# Cbc0038I Pass  15: suminf.    2.82763 (16) obj. -3.05209 iterations 7
# Cbc0038I Pass  16: suminf.    1.09397 (15) obj. -3.05209 iterations 22
# Cbc0038I Pass  17: suminf.    0.96104 (21) obj. -3.05209 iterations 12
# Cbc0038I Pass  18: suminf.    3.05209 (16) obj. -3.05209 iterations 36
# Cbc0038I Pass  19: suminf.    3.05209 (14) obj. -3.05209 iterations 25
# Cbc0038I Pass  20: suminf.    3.16667 (13) obj. -3.16667 iterations 16
# Cbc0038I Pass  21: suminf.    3.05209 (20) obj. -3.05209 iterations 22
# Cbc0038I Pass  22: suminf.    3.05209 (15) obj. -3.05209 iterations 27
# Cbc0038I Pass  23: suminf.    3.05209 (18) obj. -3.05209 iterations 20
# Cbc0038I Pass  24: suminf.    3.05209 (16) obj. -3.05209 iterations 27
# Cbc0038I Pass  25: suminf.    3.05209 (19) obj. -3.05209 iterations 26
# Cbc0038I Pass  26: suminf.    1.32977 (18) obj. -3.05209 iterations 25
# Cbc0038I Pass  27: suminf.    3.05209 (17) obj. -3.05209 iterations 34
# Cbc0038I Pass  28: suminf.    3.05209 (12) obj. -3.05209 iterations 21
# Cbc0038I Pass  29: suminf.    1.09397 (17) obj. -3.05209 iterations 25
# Cbc0038I Pass  30: suminf.    3.05209 (17) obj. -3.05209 iterations 17
# Cbc0038I Pass  31: suminf.    3.05209 (22) obj. -3.05209 iterations 37
# Cbc0038I Pass  32: suminf.    3.05209 (18) obj. -3.05209 iterations 27
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 328 rows 30 columns, reduced to 313 rows 24 columns - 1 fixed gives 10, 4 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.26 seconds)
# Cbc0038I After 0.26 seconds - Feasibility pump exiting with objective of -2 - took 0.11 seconds
# Cbc0012I Integer solution of -2 found by feasibility pump after 0 iterations and 0 nodes (0.27 seconds)
# Cbc0012I Integer solution of -3 found by DiveCoefficient after 0 iterations and 0 nodes (0.27 seconds)
# Cbc0038I Full problem 328 rows 30 columns, reduced to 237 rows 17 columns - 2 fixed gives 0, 0 - ok now
# Cbc0001I Search completed - best objective -3, took 0 iterations and 0 nodes (0.27 seconds)
# Cbc0035I Maximum depth 0, 10 variables fixed on reduced cost
# Cuts at root node changed objective from -3.26087 to -3.26087
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.26
# Time (Wallclock seconds):       0.27
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.26   (Wallclock seconds):       0.27
#
# Computed independence number for the 30-node graph: 3

# %%
import pandas as pd
# Generate and process multiple random graphs
num_graphs = 30
num_nodes = 30
results = []

for _ in range(num_graphs):
    G = nx.gnp_random_graph(n, np.random.rand())

    # Convert adjacency matrix to image with heatmap
    adj_image = convert_to_heatmap_image(G)

    # Prepare the image for the model
    input_image = np.array(adj_image).reshape(1, 64, 64, 1)  # Add batch dimension and channel dimension

    # Predict the independence number using the trained CNN
    predicted_independence_number = model.predict(input_image)[0][0]

    # Compute the actual independence number
    actual_independence_number = independence_number(G)

    # Store the results
    results.append({
        "Graph Index": _,
        "Predicted Independence Number": predicted_independence_number,
        "Actual Independence Number": actual_independence_number
    })

# Create a DataFrame to hold the results
results_df = pd.DataFrame(results)

# Display the results as a table
print(results_df)

# Plot the results as a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(results_df["Graph Index"], results_df["Predicted Independence Number"], label="Predicted", color='blue', alpha=0.6)
plt.scatter(results_df["Graph Index"], results_df["Actual Independence Number"], label="Actual", color='red', alpha=0.6)
plt.plot(results_df["Graph Index"], results_df["Actual Independence Number"], color='red', linestyle='dotted')
plt.plot(results_df["Graph Index"], results_df["Predicted Independence Number"], color='blue', linestyle='dotted')
plt.xlabel("Graph Index")
plt.ylabel("Stability Number")
plt.title("Predicted vs Actual Stability Numbers Random Graphs")
plt.ylim(0, num_nodes+1)
plt.legend()


# Optionally, save the figure
plt.savefig("stability_number_prediction_comparison.png")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/33c0df9c61704fd69922dcfb52506efc-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/33c0df9c61704fd69922dcfb52506efc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 200 COLUMNS
# At line 681 RHS
# At line 877 BOUNDS
# At line 908 ENDATA
# Problem MODEL has 195 rows, 30 columns and 390 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 170 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 117 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 65 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 27 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 109 rows, 30 columns (30 integer (30 of which binary)) and 438 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -8
# Cbc0038I Before mini branch and bound, 30 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -8 - took 0.00 seconds
# Cbc0012I Integer solution of -8 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -8, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -8 to -8
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/381b767a120840dcba261e4ead182b0d-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/381b767a120840dcba261e4ead182b0d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 253 COLUMNS
# At line 840 RHS
# At line 1089 BOUNDS
# At line 1120 ENDATA
# Problem MODEL has 248 rows, 30 columns and 496 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 239 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 208 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 176 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 126 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 64 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 27 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 8 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 138 rows, 30 columns (30 integer (30 of which binary)) and 771 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 21 integers unsatisfied sum - 5.80952
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 9 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 138 rows 30 columns, reduced to 100 rows 21 columns
# Cbc0038I Mini branch and bound improved solution from -2 to -6 (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -6 - took 0.00 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective -6, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 6 variables fixed on reduced cost
# Cuts at root node changed objective from -6.28571 to -6.28571
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/507f4762c3df454ea8bd3017e90ffedf-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/507f4762c3df454ea8bd3017e90ffedf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 304 COLUMNS
# At line 993 RHS
# At line 1293 BOUNDS
# At line 1324 ENDATA
# Problem MODEL has 299 rows, 30 columns and 598 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 298 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 264 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 251 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 216 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 132 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 72 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 29 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0004I processed model has 192 rows, 30 columns (30 integer (30 of which binary)) and 1275 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 26 integers unsatisfied sum - 4.63158
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 192 rows 30 columns, reduced to 176 rows 26 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -1.36307
# Cbc0038I Pass   1: suminf.    0.36307 (1) obj. -1.36307 iterations 67
# Cbc0038I Pass   2: suminf.    0.36307 (1) obj. -1.36307 iterations 0
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -4 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of -4 - took 0.00 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0001I Search completed - best objective -4, took 0 iterations and 0 nodes (0.04 seconds)
# Cbc0035I Maximum depth 0, 2 variables fixed on reduced cost
# Cuts at root node changed objective from -4.63158 to -4.63158
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.04
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.05
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d45be2c57fff4ac8bd4707866bf053e5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d45be2c57fff4ac8bd4707866bf053e5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 211 COLUMNS
# At line 714 RHS
# At line 921 BOUNDS
# At line 952 ENDATA
# Problem MODEL has 206 rows, 30 columns and 412 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 175 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 149 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 94 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 34 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 18 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 111 rows, 30 columns (30 integer (30 of which binary)) and 476 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 25 integers unsatisfied sum - 6.8125
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 111 rows 30 columns, reduced to 103 rows 25 columns
# Cbc0038I Mini branch and bound improved solution from -1 to -6 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -6 - took 0.00 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -6, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -6.875 to -6.875
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/0e58b09ebd774f15898d5d20431b32b3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/0e58b09ebd774f15898d5d20431b32b3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 222 COLUMNS
# At line 747 RHS
# At line 965 BOUNDS
# At line 996 ENDATA
# Problem MODEL has 217 rows, 30 columns and 434 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 208 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 158 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 100 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 55 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 114 rows, 30 columns (30 integer (30 of which binary)) and 535 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 28 integers unsatisfied sum - 6.16667
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 114 rows 30 columns, reduced to 113 rows 28 columns
# Cbc0038I Mini branch and bound improved solution from -1 to -6 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -6 - took 0.01 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -6, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -6.5 to -6.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/2e9a062c6f574fc6b0069c47c361da26-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/2e9a062c6f574fc6b0069c47c361da26-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 200 COLUMNS
# At line 681 RHS
# At line 877 BOUNDS
# At line 908 ENDATA
# Problem MODEL has 195 rows, 30 columns and 390 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 165 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 126 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 67 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 109 rows, 30 columns (30 integer (30 of which binary)) and 445 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 30 integers unsatisfied sum - 6.90909
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 109 rows 30 columns, reduced to 109 rows 30 columns
# Cbc0038I Mini branch and bound improved solution from -1 to -6 (0.02 seconds)
# Cbc0038I Round again with cutoff of -6.99991
# Cbc0038I Pass   1: suminf.    6.77731 (30) obj. -6.99991 iterations 20
# Cbc0038I Pass   2: suminf.    6.86478 (30) obj. -6.99991 iterations 11
# Cbc0038I Pass   3: suminf.    6.99991 (30) obj. -6.99991 iterations 18
# Cbc0038I Pass   4: suminf.    6.77777 (30) obj. -6.99991 iterations 16
# Cbc0038I Pass   5: suminf.    6.88872 (30) obj. -6.99991 iterations 22
# Cbc0038I Pass   6: suminf.    6.95680 (30) obj. -6.99991 iterations 19
# Cbc0038I Pass   7: suminf.    6.99991 (30) obj. -6.99991 iterations 6
# Cbc0038I Pass   8: suminf.    6.77777 (30) obj. -6.99991 iterations 15
# Cbc0038I Pass   9: suminf.    6.95696 (30) obj. -6.99991 iterations 13
# Cbc0038I Pass  10: suminf.    6.86918 (30) obj. -6.99991 iterations 10
# Cbc0038I Pass  11: suminf.    6.86665 (30) obj. -6.99991 iterations 4
# Cbc0038I Pass  12: suminf.    6.99991 (30) obj. -6.99991 iterations 20
# Cbc0038I Pass  13: suminf.    6.99961 (30) obj. -6.99991 iterations 14
# Cbc0038I Pass  14: suminf.    6.99982 (30) obj. -6.99991 iterations 14
# Cbc0038I Pass  15: suminf.    6.99950 (30) obj. -6.99991 iterations 10
# Cbc0038I Pass  16: suminf.    6.77765 (30) obj. -6.99991 iterations 9
# Cbc0038I Pass  17: suminf.    6.77731 (30) obj. -6.99991 iterations 9
# Cbc0038I Pass  18: suminf.    6.77772 (30) obj. -6.99991 iterations 6
# Cbc0038I Pass  19: suminf.    6.88824 (30) obj. -6.99991 iterations 11
# Cbc0038I Pass  20: suminf.    6.99986 (30) obj. -6.99991 iterations 14
# Cbc0038I Pass  21: suminf.    6.99966 (30) obj. -6.99991 iterations 18
# Cbc0038I Pass  22: suminf.    6.99991 (30) obj. -6.99991 iterations 13
# Cbc0038I Pass  23: suminf.    6.77777 (30) obj. -6.99991 iterations 22
# Cbc0038I Pass  24: suminf.    6.99991 (30) obj. -6.99991 iterations 17
# Cbc0038I Pass  25: suminf.    6.99991 (30) obj. -6.99991 iterations 15
# Cbc0038I Pass  26: suminf.    6.77777 (30) obj. -6.99991 iterations 25
# Cbc0038I Pass  27: suminf.    6.99991 (30) obj. -6.99991 iterations 14
# Cbc0038I Pass  28: suminf.    6.87228 (30) obj. -6.99991 iterations 15
# Cbc0038I Pass  29: suminf.    6.83309 (30) obj. -6.99991 iterations 8
# Cbc0038I Pass  30: suminf.    6.79955 (30) obj. -6.99991 iterations 6
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 109 rows 30 columns, reduced to 109 rows 30 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -6 - took 0.02 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0031I 3 added rows had average density of 28
# Cbc0013I At root node, 24 cuts changed objective from -7 to -6.861413 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 13 row cuts average 28.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 11 row cuts average 26.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -6, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -7 to -6.86141
# Probing was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 1 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 11 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d93bd9bb07a04788be13d92da7dcfc20-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d93bd9bb07a04788be13d92da7dcfc20-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 28 COLUMNS
# At line 165 RHS
# At line 189 BOUNDS
# At line 220 ENDATA
# Problem MODEL has 23 rows, 30 columns and 46 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 21 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -21 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                21.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d459f3354d954593972eda8a5cf947af-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d459f3354d954593972eda8a5cf947af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 336 COLUMNS
# At line 1089 RHS
# At line 1421 BOUNDS
# At line 1452 ENDATA
# Problem MODEL has 331 rows, 30 columns and 662 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 330 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 292 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 287 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 284 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 264 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 176 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 108 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 35 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0004I processed model has 225 rows, 30 columns (30 integer (30 of which binary)) and 1818 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 25 integers unsatisfied sum - 4.03061
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 225 rows 30 columns, reduced to 192 rows 25 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -1.30297
# Cbc0038I Pass   1: suminf.    0.90891 (3) obj. -1.30297 iterations 102
# Cbc0038I Pass   2: suminf.    0.30297 (1) obj. -1.30297 iterations 2
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -3 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 225 rows 30 columns, reduced to 214 rows 27 columns - 1 fixed gives 18, 5 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -4.00604
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 3
# Cbc0038I Pass   3: suminf.    1.05743 (25) obj. -4.00604 iterations 59
# Cbc0038I Pass   4: suminf.    1.05743 (25) obj. -4.00604 iterations 0
# Cbc0038I Pass   5: suminf.    1.35955 (25) obj. -4.00604 iterations 12
# Cbc0038I Pass   6: suminf.    1.35955 (25) obj. -4.00604 iterations 3
# Cbc0038I Pass   7: suminf.    1.10577 (24) obj. -4.00604 iterations 6
# Cbc0038I Pass   8: suminf.    1.05743 (25) obj. -4.00604 iterations 2
# Cbc0038I Pass   9: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  10: suminf.    1.20648 (25) obj. -4.00604 iterations 9
# Cbc0038I Pass  11: suminf.    1.05743 (25) obj. -4.00604 iterations 6
# Cbc0038I Pass  12: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  13: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  14: suminf.    1.05743 (25) obj. -4.00604 iterations 0
# Cbc0038I Pass  15: suminf.    1.35955 (25) obj. -4.00604 iterations 6
# Cbc0038I Pass  16: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  17: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  18: suminf.    1.10577 (25) obj. -4.00604 iterations 3
# Cbc0038I Pass  19: suminf.    1.05743 (25) obj. -4.00604 iterations 3
# Cbc0038I Pass  20: suminf.    1.05743 (25) obj. -4.00604 iterations 2
# Cbc0038I Pass  21: suminf.    1.07469 (24) obj. -4.00604 iterations 1
# Cbc0038I Pass  22: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  23: suminf.    1.15411 (25) obj. -4.00604 iterations 4
# Cbc0038I Pass  24: suminf.    1.05743 (25) obj. -4.00604 iterations 4
# Cbc0038I Pass  25: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  26: suminf.    4.00604 (24) obj. -4.00604 iterations 10
# Cbc0038I Pass  27: suminf.    1.05743 (25) obj. -4.00604 iterations 9
# Cbc0038I Pass  28: suminf.    1.05743 (25) obj. -4.00604 iterations 0
# Cbc0038I Pass  29: suminf.    4.00604 (23) obj. -4.00604 iterations 16
# Cbc0038I Pass  30: suminf.    1.05743 (25) obj. -4.00604 iterations 12
# Cbc0038I Pass  31: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I Pass  32: suminf.    1.05743 (25) obj. -4.00604 iterations 1
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 225 rows 30 columns, reduced to 210 rows 27 columns - 0 fixed gives 210, 27 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -3 - took 0.01 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0012I Integer solution of -4 found by DiveCoefficient after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0001I Search completed - best objective -4, took 0 iterations and 0 nodes (0.07 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Cuts at root node changed objective from -4.03061 to -4.03061
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.07
# Time (Wallclock seconds):       0.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.07   (Wallclock seconds):       0.07
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/4aa3b49788eb4cba85a130c22d6099a9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/4aa3b49788eb4cba85a130c22d6099a9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 397 COLUMNS
# At line 1272 RHS
# At line 1665 BOUNDS
# At line 1696 ENDATA
# Problem MODEL has 392 rows, 30 columns and 784 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 391 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 351 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 334 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 330 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 325 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 325 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 325 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 325 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 316 strengthened rows, 0 substitutions
# Cgl0004I processed model has 321 rows, 30 columns (30 integer (30 of which binary)) and 3525 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -3
# Cbc0038I Before mini branch and bound, 30 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.20 seconds)
# Cbc0038I After 0.20 seconds - Feasibility pump exiting with objective of -3 - took 0.00 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.20 seconds)
# Cbc0001I Search completed - best objective -3, took 0 iterations and 0 nodes (0.21 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -3 to -3
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.15
# Time (Wallclock seconds):       0.21
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.15   (Wallclock seconds):       0.21
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/ca9acbf505d440ba863142f8ad5b34b9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/ca9acbf505d440ba863142f8ad5b34b9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 132 COLUMNS
# At line 477 RHS
# At line 605 BOUNDS
# At line 636 ENDATA
# Problem MODEL has 127 rows, 30 columns and 254 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 63 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 63 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 26 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 71 rows, 30 columns (30 integer (30 of which binary)) and 222 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 19 integers unsatisfied sum - 9.5
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 11 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 71 rows 30 columns, reduced to 37 rows 19 columns
# Cbc0038I Mini branch and bound improved solution from 0 to -8 (0.01 seconds)
# Cbc0038I Round again with cutoff of -9.04991
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 2
# Cbc0038I Pass   1: suminf.    7.85027 (23) obj. -9.04991 iterations 22
# Cbc0038I Pass   2: suminf.    6.19964 (23) obj. -9.04991 iterations 14
# Cbc0038I Pass   3: suminf.    5.80962 (22) obj. -9.04991 iterations 4
# Cbc0038I Pass   4: suminf.    6.94949 (21) obj. -9.04991 iterations 20
# Cbc0038I Pass   5: suminf.    6.94949 (22) obj. -9.04991 iterations 3
# Cbc0038I Pass   6: suminf.    6.14973 (22) obj. -9.04991 iterations 25
# Cbc0038I Pass   7: suminf.    6.14973 (22) obj. -9.04991 iterations 1
# Cbc0038I Pass   8: suminf.    6.94949 (21) obj. -9.04991 iterations 18
# Cbc0038I Pass   9: suminf.    7.54961 (22) obj. -9.04991 iterations 14
# Cbc0038I Pass  10: suminf.    6.73516 (22) obj. -9.04991 iterations 10
# Cbc0038I Pass  11: suminf.    6.04931 (21) obj. -9.04991 iterations 6
# Cbc0038I Pass  12: suminf.    7.24955 (23) obj. -9.04991 iterations 17
# Cbc0038I Pass  13: suminf.    6.24955 (23) obj. -9.04991 iterations 8
# Cbc0038I Pass  14: suminf.    6.24955 (23) obj. -9.04991 iterations 1
# Cbc0038I Pass  15: suminf.    6.24955 (23) obj. -9.04991 iterations 2
# Cbc0038I Pass  16: suminf.    6.24955 (23) obj. -9.04991 iterations 14
# Cbc0038I Pass  17: suminf.    5.80962 (22) obj. -9.04991 iterations 6
# Cbc0038I Pass  18: suminf.    6.94949 (21) obj. -9.04991 iterations 22
# Cbc0038I Pass  19: suminf.    6.94949 (22) obj. -9.04991 iterations 2
# Cbc0038I Pass  20: suminf.    5.81960 (23) obj. -9.04991 iterations 17
# Cbc0038I Pass  21: suminf.    7.00000 (22) obj. -9.04991 iterations 10
# Cbc0038I Pass  22: suminf.    7.66667 (24) obj. -9.04991 iterations 14
# Cbc0038I Pass  23: suminf.    6.19964 (23) obj. -9.04991 iterations 13
# Cbc0038I Pass  24: suminf.    5.80962 (22) obj. -9.04991 iterations 5
# Cbc0038I Pass  25: suminf.    9.04991 (24) obj. -9.04991 iterations 11
# Cbc0038I Pass  26: suminf.    7.85027 (23) obj. -9.04991 iterations 9
# Cbc0038I Pass  27: suminf.    8.92513 (25) obj. -9.04991 iterations 16
# Cbc0038I Pass  28: suminf.    6.08948 (21) obj. -9.04991 iterations 9
# Cbc0038I Pass  29: suminf.    5.24955 (20) obj. -9.04991 iterations 5
# Cbc0038I Pass  30: suminf.    8.14973 (22) obj. -9.04991 iterations 19
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 71 rows 30 columns, reduced to 71 rows 28 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -8 - took 0.01 seconds
# Cbc0012I Integer solution of -8 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 71 rows 30 columns, reduced to 37 rows 19 columns
# Cbc0031I 6 added rows had average density of 15.666667
# Cbc0013I At root node, 15 cuts changed objective from -9.5 to -8.962963 in 4 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 30 row cuts average 27.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 12 row cuts average 25.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 39 row cuts average 8.5 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -8, took 59 iterations and 0 nodes (0.05 seconds)
# Cbc0035I Maximum depth 0, 2 variables fixed on reduced cost
# Cuts at root node changed objective from -9.5 to -8.96296
# Probing was tried 4 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 4 times and created 30 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 4 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 4 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 4 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               0
# Total iterations:               59
# Time (CPU seconds):             0.04
# Time (Wallclock seconds):       0.05
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.04   (Wallclock seconds):       0.06
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/0286346fa0da4aa7a5bd54d9d071fd17-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/0286346fa0da4aa7a5bd54d9d071fd17-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 287 COLUMNS
# At line 942 RHS
# At line 1225 BOUNDS
# At line 1256 ENDATA
# Problem MODEL has 282 rows, 30 columns and 564 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 281 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 246 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 232 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 180 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 114 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 48 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 11 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 169 rows, 30 columns (30 integer (30 of which binary)) and 1062 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 11 integers unsatisfied sum - 5.5
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 19 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 169 rows 30 columns, reduced to 22 rows 11 columns
# Cbc0038I Mini branch and bound improved solution from -1 to -4 (0.03 seconds)
# Cbc0038I Round again with cutoff of -5.04991
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 2
# Cbc0038I Pass   1: suminf.    1.04811 (14) obj. -5.04991 iterations 24
# Cbc0038I Pass   2: suminf.    0.74865 (13) obj. -5.04991 iterations 17
# Cbc0038I Pass   3: suminf.    5.04991 (11) obj. -5.04991 iterations 24
# Cbc0038I Pass   4: suminf.    0.64883 (12) obj. -5.04991 iterations 20
# Cbc0038I Pass   5: suminf.    0.64883 (12) obj. -5.04991 iterations 20
# Cbc0038I Pass   6: suminf.    0.74865 (13) obj. -5.04991 iterations 21
# Cbc0038I Pass   7: suminf.    0.74865 (13) obj. -5.04991 iterations 12
# Cbc0038I Pass   8: suminf.    5.04991 (11) obj. -5.04991 iterations 34
# Cbc0038I Pass   9: suminf.    0.64883 (12) obj. -5.04991 iterations 19
# Cbc0038I Pass  10: suminf.    0.64883 (12) obj. -5.04991 iterations 7
# Cbc0038I Pass  11: suminf.    0.74865 (13) obj. -5.04991 iterations 33
# Cbc0038I Pass  12: suminf.    0.74865 (13) obj. -5.04991 iterations 12
# Cbc0038I Pass  13: suminf.    5.04991 (11) obj. -5.04991 iterations 34
# Cbc0038I Pass  14: suminf.    0.64883 (12) obj. -5.04991 iterations 16
# ...
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/970e9f00027a435f887c8252d4e188b0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/970e9f00027a435f887c8252d4e188b0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 139 COLUMNS
# At line 498 RHS
# At line 633 BOUNDS
# At line 664 ENDATA
# Problem MODEL has 134 rows, 30 columns and 268 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 67 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 53 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 23 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 82 rows, 30 columns (30 integer (30 of which binary)) and 247 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 17 integers unsatisfied sum - 5.66667
# Cbc0038I Solution found of -8
# Cbc0038I Before mini branch and bound, 13 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 82 rows 30 columns, reduced to 24 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -8 to -9 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -9 - took 0.00 seconds
# Cbc0012I Integer solution of -9 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -9, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -9.66667 to -9.66667
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                9.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/86957899e08848c3b63652ca2a1fc11b-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/86957899e08848c3b63652ca2a1fc11b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 368 COLUMNS
# At line 1185 RHS
# At line 1549 BOUNDS
# At line 1580 ENDATA
# Problem MODEL has 363 rows, 30 columns and 726 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 363 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 330 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 320 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 312 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 306 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 304 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 276 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 214 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 126 strengthened rows, 0 substitutions
# Cgl0004I processed model has 290 rows, 30 columns (30 integer (30 of which binary)) and 2921 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 15 integers unsatisfied sum - 3.45455
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 15 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 290 rows 30 columns, reduced to 110 rows 15 columns
# Cbc0038I Mini branch and bound improved solution from 0 to -3 (0.09 seconds)
# Cbc0038I After 0.09 seconds - Feasibility pump exiting with objective of -3 - took 0.00 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.09 seconds)
# Cbc0001I Search completed - best objective -3, took 0 iterations and 0 nodes (0.09 seconds)
# Cbc0035I Maximum depth 0, 9 variables fixed on reduced cost
# Cuts at root node changed objective from -3.45455 to -3.45455
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.09
# Time (Wallclock seconds):       0.09
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.09   (Wallclock seconds):       0.09
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/5eef2ffd35ed4eaeaadde6dbf4788bb7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/5eef2ffd35ed4eaeaadde6dbf4788bb7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 109 COLUMNS
# At line 408 RHS
# At line 513 BOUNDS
# At line 544 ENDATA
# Problem MODEL has 104 rows, 30 columns and 208 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 34 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 32 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 63 rows, 30 columns (30 integer (30 of which binary)) and 172 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -12
# Cbc0038I Before mini branch and bound, 30 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -12 - took 0.00 seconds
# Cbc0012I Integer solution of -12 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -12, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -12 to -12
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                12.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/60819dc0416a42439f7637c8fc8b1eea-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/60819dc0416a42439f7637c8fc8b1eea-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 167 COLUMNS
# At line 582 RHS
# At line 745 BOUNDS
# At line 776 ENDATA
# Problem MODEL has 162 rows, 30 columns and 324 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 117 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 65 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 34 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0004I processed model has 89 rows, 30 columns (30 integer (30 of which binary)) and 298 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 26 integers unsatisfied sum - 7
# Cbc0038I Solution found of -4
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 89 rows 30 columns, reduced to 81 rows 26 columns
# Cbc0038I Mini branch and bound improved solution from -4 to -8 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -8 - took 0.00 seconds
# Cbc0012I Integer solution of -8 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -8, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -8.33333 to -8.33333
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
#     Graph Index  Predicted Independence Number  Actual Independence Number
# 0             0                       6.167734                           8
# 1             1                       5.825387                           6
# 2             2                       4.358506                           4
# 3             3                       6.227108                           6
# 4             4                       6.194224                           6
# 5             5                       7.028496                           6
# 6             6                      11.885711                          21
# 7             7                       3.690842                           4
# 8             8                       3.111831                           3
# 9             9                       8.179242                           8
# 10           10                       4.792893                           5
# 11           11                       5.489403                           6
# 12           12                       4.550259                           5
# 13           13                       2.150957                           2
# 14           14                       5.801533                           6
# 15           15                       9.566333                           9
# 16           16                       8.679673                          10
# 17           17                      12.196748                          13
# 18           18                       4.388216                           5
# 19           19                       5.573578                           6
# 20           20                       7.427855                           7
# 21           21                      12.763216                          16
# 22           22                       3.845994                           4
# 23           23                       9.761398                          11
# 24           24                       8.548593                           9
# 25           25                      12.530908                          15
# 26           26                       8.950552                           9
# 27           27                       3.285178                           3
# 28           28                      10.788569                          12
# 29           29                       8.418209                           8

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from scipy import stats

# Function to calculate RMSE
def rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# Evaluate the model on the test set
y_pred = model.predict(X_test).flatten()

# Calculate evaluation metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse_val = rmse(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print evaluation metrics
print(f'Test MSE: {mse}')
print(f'Test MAE: {mae}')
print(f'Test RMSE: {rmse_val}')
print(f'Test R-squared: {r2}')

# Calculate 95% confidence intervals for the predictions
conf_interval = stats.t.interval(0.95, len(y_test) - 1, loc=np.mean(y_pred), scale=stats.sem(y_pred))
print(f'95% Confidence Interval for the Predictions: {conf_interval}')

# Display results in a DataFrame
results_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred
})

# Plot the results as a scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(range(len(y_test)), y_test, label="Actual", color='red', alpha=0.6)
plt.scatter(range(len(y_test)), y_pred, label="Predicted", color='blue', alpha=0.6)
plt.plot(range(len(y_test)), y_test, color='red', linestyle='dotted')
plt.plot(range(len(y_test)), y_pred, color='blue', linestyle='dotted')
plt.xlabel("Graph Index")
plt.ylabel("Stability Number")
plt.title("Predicted vs Actual Stability Numbers on Test Set")
plt.ylim(0, max(y_test) + 1)
plt.legend()


# Optionally, save the figure
plt.savefig("stability_number_prediction_comparison_test_set.png")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# Test MSE: 106.9846499280618
# Test MAE: 5.017374064028263
# Test RMSE: 10.343338432443453
# Test R-squared: -0.17788827419281006
# 95% Confidence Interval for the Predictions: (4.736016956049747, 8.87554291180914)

# %%
# Ablation Study
# Model without max pooling layers
def create_model_no_pooling(input_shape):
    model = tf.keras.Sequential()
    model.add(tf.keras.Input(shape=input_shape))
    model.add(layers.Conv2D(32, (3, 3), activation='relu'))

    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Conv2D(64, (3, 3), activation='relu'))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(1))  # Output layer for regression

    model.compile(optimizer='adam',
                  loss='mean_squared_error',
                  metrics=['mae'])
    return model

model_no_pooling = create_model_no_pooling(input_shape)
model_no_pooling.fit(X_train, y_train, epochs=15, validation_split=0.2)
loss_no_pooling, mae_no_pooling = model_no_pooling.evaluate(X_test, y_test)
print(f'Model without Pooling Layers - Test MAE: {mae_no_pooling}')
# Out:
# Epoch 1/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 274ms/step - loss: 22578.9141 - mae: 77.5418 - val_loss: 852.3936 - val_mae: 22.8293
# Epoch 2/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 984.3530 - mae: 23.8056 - val_loss: 69.9420 - val_mae: 6.2998
# Epoch 3/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 25.4381 - mae: 3.9666 - val_loss: 38.1312 - val_mae: 4.4339
# Epoch 4/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - loss: 27.4069 - mae: 4.0830 - val_loss: 38.7033 - val_mae: 4.4218
# Epoch 5/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step - loss: 20.4744 - mae: 3.5131 - val_loss: 43.1144 - val_mae: 4.6389
# Epoch 6/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 17.6955 - mae: 3.1346 - val_loss: 47.8388 - val_mae: 4.9078
# Epoch 7/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 17.4215 - mae: 3.0389 - val_loss: 44.1930 - val_mae: 4.6432
# Epoch 8/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 16.9868 - mae: 3.1657 - val_loss: 35.6476 - val_mae: 4.1740
# Epoch 9/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 11.0502 - mae: 2.5864 - val_loss: 30.5012 - val_mae: 3.9070
# Epoch 10/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 9.7582 - mae: 2.5553 - val_loss: 31.0706 - val_mae: 3.8637
# Epoch 11/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 6.7656 - mae: 2.0738 - val_loss: 26.0106 - val_mae: 3.5859
# Epoch 12/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step - loss: 5.3215 - mae: 1.8822 - val_loss: 20.3507 - val_mae: 3.2370
# Epoch 13/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step - loss: 3.6911 - mae: 1.4249 - val_loss: 19.1149 - val_mae: 3.0804
# Epoch 14/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 2.7729 - mae: 1.2547 - val_loss: 13.3036 - val_mae: 2.6618
# Epoch 15/15
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - loss: 2.3195 - mae: 1.0698 - val_loss: 10.6227 - val_mae: 2.4013
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 104.5640 - mae: 5.4844
# Model without Pooling Layers - Test MAE: 5.484448432922363

# %%
# Stability / Domination / Total Domination’dan bağımsız bir hücredir.
# Sadece modelin mimarisini tanımlar (kaç katman, aktivasyon ne, çıkış sayısı kaç vs.)
from tensorflow.keras import Input, Model

inputs = Input(shape=(64, 64, 1))
x = layers.Conv2D(32, (3, 3), activation='relu')(inputs)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.MaxPooling2D((2, 2))(x)
x = layers.Conv2D(64, (3, 3), activation='relu')(x)
x = layers.Flatten()(x)
x = layers.Dense(64, activation='relu')(x)
outputs = layers.Dense(1)(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# %%
#Stability / Domination / Total Domination’dan bağımsız bir hücredir.
print(model.input)   # ➜ <KerasTensor: shape=(None, 64, 64, 1) ...>
print(model.output)  # ➜ <KerasTensor: shape=(None, 1) ...>
# Out:
# <KerasTensor shape=(None, 64, 64, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_263>
# <KerasTensor shape=(None, 1), dtype=float32, sparse=False, ragged=False, name=keras_tensor_271>

# %%
# Stability / Domination / Total Domination’dan bağımsız bir hücredir.
#Ne yapar bu hücre?
#Bir random graph oluşturur
#Onu CNN’e input olarak verir
#Ardından modelin ara katmanlarındaki (özellikle conv katmanları) aktivasyonları (feature maps) çıkarır
#Bu feature map’leri görselleştirir
#Tahmin edilen değerle (hangi metrik olduğu) hiç ilgilenmez. Sadece girişe verilen grafın CNN içinde nasıl işlendiğini gösterir.

# Choose a random graph and convert it to an image
num_nodes = 64
G = nx.gnp_random_graph(num_nodes, np.random.rand())
input_image = np.array(convert_to_heatmap_image(G)).reshape(1, 64, 64, 1)  # Add batch and channel dimensions

# Create a model to output the intermediate layers
layer_outputs = [layer.output for layer in model.layers if 'conv' in layer.name]
activation_model = Model(inputs=model.input, outputs=layer_outputs)

# Get the feature maps for the input image
activations = activation_model.predict(input_image)

# Visualize the feature maps for a specific layer (e.g., first convolutional layer)
layer_activation = activations[0]
n_features = layer_activation.shape[-1]
size = layer_activation.shape[1]

# Plot each feature map in a grid
n_cols = 8
n_rows = n_features // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 2, n_rows * 2))

for i in range(n_features):
    row = i // n_cols
    col = i % n_cols
    ax = axes[row, col]
    ax.imshow(layer_activation[0, :, :, i], cmap='viridis')
    ax.axis('off')

# plt.title('Feature Maps of First Convolutional Layer')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %%
#  Function to convert adjacency matrix and heatmap to fixed-size image
def convert_to_heatmap_image(G, target_size=64):
    adj_matrix = nx.to_numpy_array(G)
    matrix_size = adj_matrix.shape[0]

    if matrix_size < target_size:
        padded_matrix = np.zeros((target_size, target_size), dtype=int)
        padded_matrix[:matrix_size, :matrix_size] = adj_matrix
    elif matrix_size > target_size:
        image = Image.fromarray(adj_matrix)
        padded_matrix = np.array(image.resize((target_size, target_size), Image.BILINEAR))
    else:
        padded_matrix = adj_matrix

    degree_dict = dict(G.degree())
    degrees = np.array([degree_dict[node] for node in G.nodes()])
    heatmap = np.zeros((target_size, target_size), dtype=float)

    for i, node in enumerate(G.nodes()):
        if i < target_size:
            heatmap[i, i] = degrees[i]

    combined_matrix = padded_matrix + heatmap
    combined_image = (combined_matrix / combined_matrix.max() * 255).astype(np.uint8)

    return Image.fromarray(combined_image, 'L')

# Generate a random graph and convert it to an image
num_nodes = 64
G = nx.gnp_random_graph(num_nodes, np.random.rand())
input_image = np.array(convert_to_heatmap_image(G)).reshape(1, 64, 64, 1)  # Add batch and channel dimensions

# Compute the maximum independent set
mis = max_independent_set_ilp(G)
print(f"Maximum Independent Set: {mis}")

# Extract feature maps from the last convolutional layer
layer_outputs = [layer.output for layer in model.layers if 'conv' in layer.name]
activation_model = Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(input_image)
last_layer_activation = activations[-1]

# Visualize the feature maps for the last convolutional layer
n_features = last_layer_activation.shape[-1]
size = last_layer_activation.shape[1]

# Plot each feature map in a grid
n_cols = 8
n_rows = n_features // n_cols
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 2, n_rows * 2))

for i in range(n_features):
    row = i // n_cols
    col = i % n_cols
    ax = axes[row, col]
    ax.imshow(last_layer_activation[0, :, :, i], cmap='viridis')
    ax.axis('off')

# plt.suptitle('Feature Maps of Last Convolutional Layer')
plt.show()

# Visualize the graph and highlight the maximum independent set
pos = nx.spring_layout(G)
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_color='lightblue', with_labels=True, node_size=500)
nx.draw_networkx_nodes(G, pos, nodelist=mis, node_color='red')
plt.title('Graph with Maximum Independent Set Highlighted')
plt.show()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f333d842ce7a47349e307030d1e9103e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f333d842ce7a47349e307030d1e9103e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1207 COLUMNS
# At line 3804 RHS
# At line 5007 BOUNDS
# At line 5072 ENDATA
# Problem MODEL has 1202 rows, 64 columns and 2404 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1202 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1105 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1080 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1009 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 687 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 279 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 74 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 27 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0004I processed model has 913 rows, 64 columns (64 integer (64 of which binary)) and 6290 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 63 integers unsatisfied sum - 8.68088
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 913 rows 64 columns, reduced to 903 rows 63 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.27 seconds)
# Cbc0038I Round again with cutoff of -1.768
# Cbc0038I Pass   1: suminf.    0.23200 (1) obj. -1.768 iterations 214
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -5 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 913 rows 64 columns, reduced to 903 rows 63 columns - 2 fixed gives 42, 8 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.29 seconds)
# Cbc0038I Round again with cutoff of -6.5361
# Cbc0038I Pass   2: suminf.    6.49513 (41) obj. -6.5361 iterations 103
# Cbc0038I Pass   3: suminf.    4.63245 (45) obj. -6.5361 iterations 179
# Cbc0038I Pass   4: suminf.    2.60000 (52) obj. -6.5361 iterations 114
# Cbc0038I Pass   5: suminf.    2.26121 (57) obj. -6.5361 iterations 62
# Cbc0038I Pass   6: suminf.    6.25038 (24) obj. -6.5361 iterations 172
# Cbc0038I Pass   7: suminf.    2.98349 (54) obj. -6.5361 iterations 115
# Cbc0038I Pass   8: suminf.    2.35516 (55) obj. -6.5361 iterations 80
# Cbc0038I Pass   9: suminf.    6.03610 (19) obj. -6.5361 iterations 201
# Cbc0038I Pass  10: suminf.    2.11246 (49) obj. -6.5361 iterations 131
# Cbc0038I Pass  11: suminf.    2.08666 (49) obj. -6.5361 iterations 18
# Cbc0038I Pass  12: suminf.    6.03610 (21) obj. -6.5361 iterations 135
# Cbc0038I Pass  13: suminf.    4.57319 (48) obj. -6.5361 iterations 111
# Cbc0038I Pass  14: suminf.    4.85161 (16) obj. -6.5361 iterations 120
# Cbc0038I Pass  15: suminf.    4.03897 (42) obj. -6.5361 iterations 107
# Cbc0038I Pass  16: suminf.    6.18411 (24) obj. -6.5361 iterations 174
# Cbc0038I Pass  17: suminf.    4.61809 (23) obj. -6.5361 iterations 186
# Cbc0038I Pass  18: suminf.    2.86707 (47) obj. -6.5361 iterations 102
# Cbc0038I Pass  19: suminf.    2.26121 (57) obj. -6.5361 iterations 95
# Cbc0038I Pass  20: suminf.    6.50792 (26) obj. -6.5361 iterations 175
# Cbc0038I Pass  21: suminf.    5.33610 (22) obj. -6.5361 iterations 141
# Cbc0038I Pass  22: suminf.    4.60829 (21) obj. -6.5361 iterations 141
# Cbc0038I Pass  23: suminf.    3.47530 (44) obj. -6.5361 iterations 93
# Cbc0038I Pass  24: suminf.    5.06451 (21) obj. -6.5361 iterations 141
# Cbc0038I Pass  25: suminf.    2.18846 (50) obj. -6.5361 iterations 117
# Cbc0038I Pass  26: suminf.    2.14351 (50) obj. -6.5361 iterations 22
# Cbc0038I Pass  27: suminf.    5.97849 (29) obj. -6.5361 iterations 110
# Cbc0038I Pass  28: suminf.    2.54912 (57) obj. -6.5361 iterations 134
# Cbc0038I Pass  29: suminf.    2.14848 (56) obj. -6.5361 iterations 73
# Cbc0038I Pass  30: suminf.    5.09759 (18) obj. -6.5361 iterations 179
# Cbc0038I Pass  31: suminf.    4.25089 (17) obj. -6.5361 iterations 137
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 913 rows 64 columns, reduced to 903 rows 64 columns - 1 fixed gives 427, 24 - still too large
# Cbc0038I Full problem 913 rows 64 columns, reduced to 347 rows 23 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.46 seconds)
# Cbc0038I After 0.46 seconds - Feasibility pump exiting with objective of -5 - took 0.19 seconds
# Cbc0012I Integer solution of -5 found by feasibility pump after 0 iterations and 0 nodes (0.46 seconds)
# Cbc0012I Integer solution of -6 found by DiveCoefficient after 14904 iterations and 0 nodes (1.90 seconds)
# Cbc0031I 21 added rows had average density of 26.190476
# Cbc0013I At root node, 21 cuts changed objective from -8.6808835 to -8.3522225 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.140 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2684 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.047 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 25 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.049 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -6 best solution, best possible -8.3522225 (2.43 seconds)
# Cbc0001I Search completed - best objective -6, took 17821 iterations and 32 nodes (3.98 seconds)
# Cbc0032I Strong branching done 492 times (26437 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 15, 4 variables fixed on reduced cost
# Cuts at root node changed objective from -8.68088 to -8.35222
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.140 seconds)
# Gomory was tried 100 times and created 2684 cuts of which 0 were active after adding rounds of cuts (0.047 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# Clique was tried 100 times and created 25 cuts of which 0 were active after adding rounds of cuts (0.056 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.049 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
#
# Result - Optimal solution found
#
# Objective value:                6.00000000
# Enumerated nodes:               32
# Total iterations:               17821
# Time (CPU seconds):             3.86
# Time (Wallclock seconds):       4.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.86   (Wallclock seconds):       4.01
#
# Maximum Independent Set: {32, 44, 13, 14, 51, 56}
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step

# %%
import time

# Generate a random graph
num_nodes = 64
G = nx.gnp_random_graph(num_nodes, np.random.rand())

# Measure time for ILP method
start_time = time.time()
mis = max_independent_set_ilp(G)
ilp_time = time.time() - start_time
ilp_independence_number = len(mis)

# Convert graph to image
input_image = np.array(convert_to_heatmap_image(G)).reshape(1, 64, 64, 1)  # Add batch and channel dimensions

# Measure time for CNN prediction
start_time = time.time()
cnn_pred = model.predict(input_image)[0][0]
cnn_time = time.time() - start_time

print(f"ILP Method: Independence Number = {ilp_independence_number}, Time Taken = {ilp_time:.4f} seconds")
print(f"CNN Method: Predicted Independence Number = {cnn_pred:.4f}, Time Taken = {cnn_time:.4f} seconds")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/80fdbdff992c4fdd96198ad26a5a7bce-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/80fdbdff992c4fdd96198ad26a5a7bce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1809 COLUMNS
# At line 5610 RHS
# At line 7415 BOUNDS
# At line 7480 ENDATA
# Problem MODEL has 1804 rows, 64 columns and 3608 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1804 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1738 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1714 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1698 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1684 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1676 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1674 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1674 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1674 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1674 rows, 64 columns (64 integer (64 of which binary)) and 18414 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 46 integers unsatisfied sum - 8.26813
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 18 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1674 rows 64 columns, reduced to 1540 rows 46 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (1.87 seconds)
# Cbc0038I Round again with cutoff of -1.72672
# Cbc0038I Pass   1: suminf.    0.27328 (1) obj. -1.72672 iterations 315
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -3 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1674 rows 64 columns, reduced to 1671 rows 56 columns - 2 fixed gives 0, 0 - ok now
# Cbc0038I Mini branch and bound did not improve solution (1.92 seconds)
# Cbc0038I Round again with cutoff of -4.85355
# Cbc0038I Reduced cost fixing fixed 2 variables on major pass 3
# Cbc0038I Pass   2: suminf.    4.85355 (22) obj. -4.85355 iterations 59
# Cbc0038I Pass   3: suminf.    4.85355 (15) obj. -4.85355 iterations 28
# Cbc0038I Pass   4: suminf.    4.85355 (15) obj. -4.85355 iterations 69
# Cbc0038I Pass   5: suminf.    4.71069 (15) obj. -4.85355 iterations 26
# Cbc0038I Pass   6: suminf.    3.70903 (35) obj. -4.85355 iterations 68
# Cbc0038I Pass   7: suminf.    3.54903 (39) obj. -4.85355 iterations 48
# Cbc0038I Pass   8: suminf.    5.00000 (16) obj. -5 iterations 76
# Cbc0038I Pass   9: suminf.    3.99976 (28) obj. -4.85355 iterations 62
# Cbc0038I Pass  10: suminf.    3.10543 (39) obj. -4.85355 iterations 56
# Cbc0038I Pass  11: suminf.    4.45355 (17) obj. -4.85355 iterations 99
# Cbc0038I Pass  12: suminf.    3.72320 (36) obj. -4.85355 iterations 49
# Cbc0038I Pass  13: suminf.    5.60870 (23) obj. -5.65217 iterations 81
# Cbc0038I Pass  14: suminf.    4.04866 (26) obj. -4.85355 iterations 73
# Cbc0038I Pass  15: suminf.    4.85355 (18) obj. -4.85355 iterations 48
# Cbc0038I Pass  16: suminf.    4.85355 (22) obj. -4.85355 iterations 141
# Cbc0038I Pass  17: suminf.    4.85355 (19) obj. -4.85355 iterations 30
# Cbc0038I Pass  18: suminf.    4.85355 (19) obj. -4.85355 iterations 49
# Cbc0038I Pass  19: suminf.    5.31000 (21) obj. -5.33 iterations 95
# Cbc0038I Pass  20: suminf.    4.08427 (30) obj. -4.85355 iterations 67
# Cbc0038I Pass  21: suminf.    5.13043 (17) obj. -5.17391 iterations 38
# Cbc0038I Pass  22: suminf.    4.10798 (27) obj. -4.85355 iterations 50
# Cbc0038I Pass  23: suminf.    4.52021 (14) obj. -4.85355 iterations 45
# Cbc0038I Pass  24: suminf.    4.71069 (19) obj. -4.85355 iterations 88
# Cbc0038I Pass  25: suminf.    3.80134 (35) obj. -4.85355 iterations 72
# Cbc0038I Pass  26: suminf.    3.20355 (42) obj. -4.85355 iterations 79
# Cbc0038I Pass  27: suminf.    4.70709 (16) obj. -4.85355 iterations 109
# Cbc0038I Pass  28: suminf.    4.06385 (30) obj. -4.85355 iterations 54
# Cbc0038I Pass  29: suminf.    4.85355 (19) obj. -4.85355 iterations 62
# Cbc0038I Pass  30: suminf.    4.85355 (22) obj. -4.85355 iterations 91
# Cbc0038I Pass  31: suminf.    4.52021 (14) obj. -4.85355 iterations 37
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1674 rows 64 columns, reduced to 1637 rows 56 columns - 0 fixed gives 1637, 56 - still too large
# Cbc0038I Mini branch and bound did not improve solution (2.09 seconds)
# Cbc0038I After 2.09 seconds - Feasibility pump exiting with objective of -3 - took 0.22 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (2.09 seconds)
# Cbc0038I Full problem 1674 rows 64 columns, reduced to 1549 rows 47 columns - 1 fixed gives 26, 7 - ok now
# Cbc0038I Full problem 1674 rows 64 columns, reduced to 26 rows 7 columns
# Cbc0031I 42 added rows had average density of 15.880952
# Cbc0013I At root node, 574 cuts changed objective from -8.268126 to -3.8389876 in 5 passes
# Cbc0014I Cut generator 0 (Probing) - 841 row cuts average 11.0 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 190 row cuts average 62.5 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 2693 row cuts average 16.0 elements, 0 column cuts (0 active)  in 0.061 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 223 row cuts average 60.1 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -3, took 1575 iterations and 0 nodes (2.53 seconds)
# Cbc0035I Maximum depth 0, 11 variables fixed on reduced cost
# Cuts at root node changed objective from -8.26813 to -3.83899
# Probing was tried 5 times and created 841 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# Gomory was tried 5 times and created 190 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# Knapsack was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 5 times and created 2693 cuts of which 0 were active after adding rounds of cuts (0.061 seconds)
# MixedIntegerRounding2 was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# FlowCover was tried 5 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 5 times and created 223 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               1575
# Time (CPU seconds):             2.34
# Time (Wallclock seconds):       2.55
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.34   (Wallclock seconds):       2.55
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ILP Method: Independence Number = 3, Time Taken = 2.5972 seconds
# CNN Method: Predicted Independence Number = 2.4450, Time Taken = 0.0618 seconds

# %%
# Parameters
num_trials = 10
num_nodes = 64

ilp_times = []
cnn_times = []
ilp_results = []
cnn_results = []

for _ in range(num_trials):
    # Generate a random graph
    G = nx.gnp_random_graph(num_nodes, np.random.rand())

    # Measure time for ILP method
    start_time = time.time()
    mis = max_independent_set_ilp(G)
    ilp_time = time.time() - start_time
    ilp_independence_number = len(mis)

    # Convert graph to image
    input_image = np.array(convert_to_heatmap_image(G)).reshape(1, 64, 64, 1)  # Add batch and channel dimensions

    # Measure time for CNN prediction
    start_time = time.time()
    cnn_pred = model.predict(input_image)[0][0]
    cnn_time = time.time() - start_time

    # Collect results
    ilp_times.append(ilp_time)
    cnn_times.append(cnn_time)
    ilp_results.append(ilp_independence_number)
    cnn_results.append(cnn_pred)

# Compute averages
avg_ilp_time = np.mean(ilp_times)
avg_cnn_time = np.mean(cnn_times)
avg_ilp_result = np.mean(ilp_results)
avg_cnn_result = np.mean(cnn_results)

print(f"Average ILP Time: {avg_ilp_time:.4f} seconds")
print(f"Average CNN Time: {avg_cnn_time:.4f} seconds")
print(f"Average ILP Stability Number: {avg_ilp_result:.4f}")
print(f"Average CNN Predicted Stability Number: {avg_cnn_result:.4f}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f13845acb97a455ebee77ecedd3bdf5e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f13845acb97a455ebee77ecedd3bdf5e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 697 COLUMNS
# At line 2274 RHS
# At line 2967 BOUNDS
# At line 3032 ENDATA
# Problem MODEL has 692 rows, 64 columns and 1384 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 645 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 451 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 198 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 65 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 429 rows, 64 columns (64 integer (64 of which binary)) and 1749 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 63 integers unsatisfied sum - 14.3718
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 429 rows 64 columns, reduced to 429 rows 63 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of -2.33709
# Cbc0038I Pass   1: suminf.    0.33709 (1) obj. -2.33709 iterations 139
# Cbc0038I Pass   2: suminf.    0.33709 (1) obj. -2.33709 iterations 0
# Cbc0038I Solution found of -3
# Cbc0038I Rounding solution of -8 is better than previous of -3
#
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 429 rows 64 columns, reduced to 429 rows 63 columns - 2 fixed gives 164, 28 - still too large
# Cbc0038I Full problem 429 rows 64 columns, reduced to 164 rows 28 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -10.0743
# Cbc0038I Pass   3: suminf.    9.07428 (26) obj. -10.0743 iterations 56
# Cbc0038I Pass   4: suminf.    2.83999 (29) obj. -10.0743 iterations 78
# Cbc0038I Pass   5: suminf.    2.64856 (7) obj. -10.0743 iterations 29
# Cbc0038I Pass   6: suminf.    0.51996 (7) obj. -10.0743 iterations 74
# Cbc0038I Pass   7: suminf.    0.24570 (33) obj. -10.0743 iterations 60
# Cbc0038I Pass   8: suminf.    1.92572 (4) obj. -10.0743 iterations 74
# Cbc0038I Pass   9: suminf.    0.22284 (3) obj. -10.0743 iterations 33
# Cbc0038I Pass  10: suminf.    0.22284 (3) obj. -10.0743 iterations 83
# Cbc0038I Solution found of -11
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 429 rows 64 columns, reduced to 429 rows 63 columns - 5 fixed gives 17, 10 - ok now
# Cbc0038I Full problem 429 rows 64 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I Round again with cutoff of -12.7115
# Cbc0038I Pass  11: suminf.   11.41792 (47) obj. -12.7115 iterations 49
# Cbc0038I Pass  12: suminf.   10.34389 (42) obj. -12.7115 iterations 67
# Cbc0038I Pass  13: suminf.    8.53550 (39) obj. -12.7115 iterations 49
# Cbc0038I Pass  14: suminf.    7.57740 (53) obj. -12.7115 iterations 25
# Cbc0038I Pass  15: suminf.    7.53892 (55) obj. -12.7115 iterations 10
# Cbc0038I Pass  16: suminf.    9.69409 (37) obj. -12.7115 iterations 62
# Cbc0038I Pass  17: suminf.    9.09289 (41) obj. -12.7115 iterations 33
# Cbc0038I Pass  18: suminf.    8.66010 (35) obj. -12.7115 iterations 29
# Cbc0038I Pass  19: suminf.    9.78031 (44) obj. -12.7115 iterations 38
# Cbc0038I Pass  20: suminf.    9.56825 (43) obj. -12.7115 iterations 23
# Cbc0038I Pass  21: suminf.    9.29647 (36) obj. -12.7115 iterations 19
# Cbc0038I Pass  22: suminf.    9.25830 (49) obj. -12.7115 iterations 6
# Cbc0038I Pass  23: suminf.    9.96929 (38) obj. -12.7115 iterations 75
# Cbc0038I Pass  24: suminf.    9.56392 (39) obj. -12.7115 iterations 29
# Cbc0038I Pass  25: suminf.    8.90054 (36) obj. -12.7115 iterations 49
# Cbc0038I Pass  26: suminf.    8.66010 (35) obj. -12.7115 iterations 23
# Cbc0038I Pass  27: suminf.   10.02294 (32) obj. -12.7115 iterations 67
# Cbc0038I Pass  28: suminf.    9.47212 (51) obj. -12.7115 iterations 40
# Cbc0038I Pass  29: suminf.    9.84835 (29) obj. -12.7115 iterations 86
# Cbc0038I Pass  30: suminf.    9.25208 (49) obj. -12.7115 iterations 55
# Cbc0038I Pass  31: suminf.   10.23952 (36) obj. -12.7115 iterations 87
# Cbc0038I Pass  32: suminf.    8.98463 (38) obj. -12.7115 iterations 50
# Cbc0038I Pass  33: suminf.    8.84261 (42) obj. -12.7115 iterations 23
# Cbc0038I Pass  34: suminf.    9.81900 (33) obj. -12.7115 iterations 94
# Cbc0038I Pass  35: suminf.    8.93113 (35) obj. -12.7115 iterations 75
# Cbc0038I Pass  36: suminf.    9.49583 (58) obj. -12.7115 iterations 49
# Cbc0038I Pass  37: suminf.   10.98069 (38) obj. -12.7115 iterations 79
# Cbc0038I Pass  38: suminf.    9.38343 (41) obj. -12.7115 iterations 41
# Cbc0038I Pass  39: suminf.    9.05071 (39) obj. -12.7115 iterations 19
# Cbc0038I Pass  40: suminf.    8.93219 (45) obj. -12.7115 iterations 8
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 429 rows 64 columns, reduced to 429 rows 64 columns - 4 fixed gives 11, 6 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.12 seconds)
# Cbc0038I After 0.12 seconds - Feasibility pump exiting with objective of -11 - took 0.06 seconds
# Cbc0012I Integer solution of -11 found by feasibility pump after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0031I 10 added rows had average density of 64
# Cbc0013I At root node, 10 cuts changed objective from -14.371803 to -14.013483 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.055 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1337 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.013 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 7 row cuts average 4.1 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -11 best solution, best possible -14.013483 (0.77 seconds)
# Cbc0001I Search completed - best objective -11, took 11653 iterations and 20 nodes (1.32 seconds)
# Cbc0032I Strong branching done 504 times (20740 iterations), fathomed 4 nodes and fixed 0 variables
# Cbc0035I Maximum depth 9, 3 variables fixed on reduced cost
# Cuts at root node changed objective from -14.3718 to -14.0135
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.055 seconds)
# Gomory was tried 100 times and created 1337 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.013 seconds)
# Clique was tried 100 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.00000000
# Enumerated nodes:               20
# Total iterations:               11653
# Time (CPU seconds):             1.26
# Time (Wallclock seconds):       1.33
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.26   (Wallclock seconds):       1.33
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/e3b520da4d2e409b8b74e44a8dd92301-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/e3b520da4d2e409b8b74e44a8dd92301-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 66 COLUMNS
# At line 381 RHS
# At line 443 BOUNDS
# At line 508 ENDATA
# Problem MODEL has 61 rows, 64 columns and 122 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 38 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -38 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                38.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/0102b705cd3f4b61ae9a1417cb3ff6bd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/0102b705cd3f4b61ae9a1417cb3ff6bd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 491 COLUMNS
# At line 1656 RHS
# At line 2143 BOUNDS
# At line 2208 ENDATA
# Problem MODEL has 486 rows, 64 columns and 972 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 323 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 224 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 88 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 29 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 295 rows, 64 columns (64 integer (64 of which binary)) and 962 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 62 integers unsatisfied sum - 17.4581
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 295 rows 64 columns, reduced to 294 rows 62 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I Round again with cutoff of -2.64572
# Cbc0038I Pass   1: suminf.    0.35428 (1) obj. -2.64572 iterations 104
# Cbc0038I Solution found of -3
# Cbc0038I Rounding solution of -12 is better than previous of -3
#
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 295 rows 64 columns, reduced to 294 rows 62 columns - 2 fixed gives 189, 41 - still too large
# Cbc0038I Full problem 295 rows 64 columns, reduced to 189 rows 41 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -13.8915
# Cbc0038I Pass   2: suminf.   10.93563 (35) obj. -13.8915 iterations 61
# Cbc0038I Pass   3: suminf.    4.18752 (53) obj. -13.8915 iterations 70
# Cbc0038I Pass   4: suminf.    3.67023 (55) obj. -13.8915 iterations 27
# Cbc0038I Pass   5: suminf.    7.67461 (32) obj. -13.8915 iterations 111
# Cbc0038I Pass   6: suminf.    5.77416 (44) obj. -13.8915 iterations 48
# Cbc0038I Pass   7: suminf.    8.76149 (37) obj. -13.8915 iterations 64
# Cbc0038I Pass   8: suminf.    8.19268 (33) obj. -13.8915 iterations 28
# Cbc0038I Pass   9: suminf.    8.10444 (48) obj. -13.8915 iterations 24
# Cbc0038I Pass  10: suminf.    6.51529 (31) obj. -13.8915 iterations 58
# Cbc0038I Pass  11: suminf.    5.96120 (57) obj. -13.8915 iterations 54
# Cbc0038I Pass  12: suminf.    9.05088 (36) obj. -13.8915 iterations 67
# Cbc0038I Pass  13: suminf.    6.90756 (43) obj. -13.8915 iterations 35
# Cbc0038I Pass  14: suminf.    8.25856 (42) obj. -13.8915 iterations 51
# Cbc0038I Pass  15: suminf.    3.66520 (58) obj. -13.8915 iterations 38
# Cbc0038I Pass  16: suminf.    3.54025 (59) obj. -13.8915 iterations 15
# Cbc0038I Pass  17: suminf.    7.37543 (34) obj. -13.8915 iterations 98
# Cbc0038I Pass  18: suminf.    3.91184 (54) obj. -13.8915 iterations 58
# Cbc0038I Pass  19: suminf.   10.28633 (48) obj. -13.8915 iterations 103
# Cbc0038I Pass  20: suminf.    8.49350 (48) obj. -13.8915 iterations 32
# Cbc0038I Pass  21: suminf.    8.04409 (49) obj. -13.8915 iterations 26
# Cbc0038I Pass  22: suminf.    6.22487 (20) obj. -13.8915 iterations 68
# Cbc0038I Pass  23: suminf.    3.49539 (55) obj. -13.8915 iterations 52
# Cbc0038I Pass  24: suminf.    8.02382 (18) obj. -13.8915 iterations 65
# Cbc0038I Pass  25: suminf.    3.79508 (59) obj. -13.8915 iterations 77
# Cbc0038I Pass  26: suminf.    8.70219 (29) obj. -13.8915 iterations 80
# Cbc0038I Pass  27: suminf.    2.77116 (10) obj. -13.8915 iterations 28
# Cbc0038I Solution found of -15
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 295 rows 64 columns, reduced to 295 rows 64 columns - 1 fixed gives 256, 52 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -16.4374
# Cbc0038I Pass  28: suminf.   15.37958 (57) obj. -16.4374 iterations 69
# Cbc0038I Pass  29: suminf.   14.00270 (53) obj. -16.4374 iterations 45
# Cbc0038I Pass  30: suminf.   13.58269 (55) obj. -16.4374 iterations 37
# Cbc0038I Pass  31: suminf.   13.41844 (56) obj. -16.4374 iterations 18
# Cbc0038I Pass  32: suminf.   14.43092 (55) obj. -16.4374 iterations 51
# Cbc0038I Pass  33: suminf.   13.77770 (58) obj. -16.4374 iterations 30
# Cbc0038I Pass  34: suminf.   13.60274 (57) obj. -16.4374 iterations 20
# Cbc0038I Pass  35: suminf.   14.23463 (49) obj. -16.4374 iterations 60
# Cbc0038I Pass  36: suminf.   13.49948 (53) obj. -16.4374 iterations 36
# Cbc0038I Pass  37: suminf.   13.47794 (54) obj. -16.4374 iterations 9
# Cbc0038I Pass  38: suminf.   14.71001 (59) obj. -16.4374 iterations 37
# Cbc0038I Pass  39: suminf.   13.23339 (57) obj. -16.4374 iterations 34
# Cbc0038I Pass  40: suminf.   13.52010 (56) obj. -16.4374 iterations 32
# Cbc0038I Pass  41: suminf.   13.21072 (55) obj. -16.4374 iterations 17
# Cbc0038I Pass  42: suminf.   15.78724 (55) obj. -16.4374 iterations 86
# Cbc0038I Pass  43: suminf.   14.19488 (58) obj. -16.4374 iterations 66
# Cbc0038I Pass  44: suminf.   14.14237 (55) obj. -16.4374 iterations 12
# Cbc0038I Pass  45: suminf.   14.69134 (49) obj. -16.4374 iterations 48
# Cbc0038I Pass  46: suminf.   13.35084 (58) obj. -16.4374 iterations 38
# Cbc0038I Pass  47: suminf.   13.94482 (54) obj. -16.4374 iterations 35
# Cbc0038I Pass  48: suminf.   13.29308 (59) obj. -16.4374 iterations 21
# Cbc0038I Pass  49: suminf.   13.27885 (59) obj. -16.4374 iterations 6
# Cbc0038I Pass  50: suminf.   13.86309 (55) obj. -16.4374 iterations 39
# Cbc0038I Pass  51: suminf.   13.26169 (59) obj. -16.4374 iterations 25
# Cbc0038I Pass  52: suminf.   13.06731 (58) obj. -16.4374 iterations 15
# Cbc0038I Pass  53: suminf.   12.94616 (57) obj. -16.4374 iterations 18
# Cbc0038I Pass  54: suminf.   12.90839 (57) obj. -16.4374 iterations 11
# Cbc0038I Pass  55: suminf.   12.85826 (57) obj. -16.4374 iterations 10
# Cbc0038I Pass  56: suminf.   14.46744 (54) obj. -16.4374 iterations 55
# Cbc0038I Pass  57: suminf.   13.65339 (55) obj. -16.4374 iterations 30
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 295 rows 64 columns, reduced to 295 rows 64 columns - 1 fixed gives 256, 52 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I After 0.07 seconds - Feasibility pump exiting with objective of -15 - took 0.04 seconds
# Cbc0012I Integer solution of -15 found by feasibility pump after 0 iterations and 0 nodes (0.07 seconds)
# Cbc0031I 15 added rows had average density of 36.733333
# Cbc0013I At root node, 15 cuts changed objective from -17.458078 to -16.910945 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.051 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1012 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 1 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.017 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 167 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.044 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 174 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.411 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -15 best solution, best possible -16.910945 (1.00 seconds)
# Cbc0001I Search completed - best objective -15, took 9428 iterations and 10 nodes (1.25 seconds)
# Cbc0032I Strong branching done 270 times (10726 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 4, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -17.4581 to -16.9109
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.051 seconds)
# Gomory was tried 100 times and created 1012 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# Clique was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.017 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 120 times and created 357 cuts of which 0 were active after adding rounds of cuts (0.067 seconds)
# ZeroHalf was tried 120 times and created 213 cuts of which 0 were active after adding rounds of cuts (0.485 seconds)
#
# Result - Optimal solution found
#
# Objective value:                15.00000000
# Enumerated nodes:               10
# Total iterations:               9428
# Time (CPU seconds):             1.19
# Time (Wallclock seconds):       1.26
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.19   (Wallclock seconds):       1.26
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/761ce44b0d3142228510931d51618232-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/761ce44b0d3142228510931d51618232-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 580 COLUMNS
# At line 1923 RHS
# At line 2499 BOUNDS
# At line 2564 ENDATA
# Problem MODEL has 575 rows, 64 columns and 1150 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 473 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 338 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 157 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 53 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 345 rows, 64 columns (64 integer (64 of which binary)) and 1307 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 63 integers unsatisfied sum - 15.967
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 345 rows 64 columns, reduced to 345 rows 63 columns - 0 fixed gives 345, 63 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -3.40211
# Cbc0038I Pass   1: suminf.    0.40211 (1) obj. -3.40211 iterations 127
# Cbc0038I Pass   2: suminf.    0.40211 (1) obj. -3.40211 iterations 1
# Cbc0038I Solution found of -4
# Cbc0038I Rounding solution of -10 is better than previous of -4
#
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 345 rows 64 columns, reduced to 345 rows 63 columns - 1 fixed gives 312, 52 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -12.0043
# Cbc0038I Pass   3: suminf.    6.06473 (28) obj. -12.0043 iterations 52
# Cbc0038I Pass   4: suminf.    0.01704 (52) obj. -12.0043 iterations 74
# Cbc0038I Pass   5: suminf.    0.01669 (56) obj. -12.0043 iterations 16
# Cbc0038I Pass   6: suminf.    0.01669 (56) obj. -12.0043 iterations 0
# Cbc0038I Pass   7: suminf.    0.02016 (54) obj. -12.0043 iterations 43
# Cbc0038I Pass   8: suminf.    0.02128 (49) obj. -12.0043 iterations 47
# Cbc0038I Pass   9: suminf.    0.02158 (5) obj. -12.0043 iterations 84
# Cbc0038I Pass  10: suminf.    0.01787 (57) obj. -12.0043 iterations 131
# Cbc0038I Pass  11: suminf.    0.02158 (5) obj. -12.0043 iterations 26
# Cbc0038I Pass  12: suminf.    0.03268 (38) obj. -12.0043 iterations 109
# Cbc0038I Pass  13: suminf.    0.01914 (58) obj. -12.0043 iterations 89
# Cbc0038I Pass  14: suminf.    0.01914 (58) obj. -12.0043 iterations 0
# Cbc0038I Pass  15: suminf.    4.01133 (32) obj. -12.0043 iterations 60
# Cbc0038I Pass  16: suminf.    0.03884 (15) obj. -12.0043 iterations 48
# Cbc0038I Pass  17: suminf.    0.01772 (59) obj. -12.0043 iterations 64
# Cbc0038I Pass  18: suminf.    0.01772 (59) obj. -12.0043 iterations 0
# Cbc0038I Pass  19: suminf.    4.35203 (13) obj. -12.0043 iterations 65
# Cbc0038I Pass  20: suminf.    2.76187 (33) obj. -12.0043 iterations 51
# Cbc0038I Pass  21: suminf.    0.01985 (16) obj. -12.0043 iterations 87
# Cbc0038I Pass  22: suminf.    0.01295 (3) obj. -12.0043 iterations 102
# Cbc0038I Solution found of -13
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 345 rows 64 columns, reduced to 345 rows 64 columns - 1 fixed gives 315, 53 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -14.6065
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 4
# Cbc0038I Pass  23: suminf.   11.94211 (46) obj. -14.6065 iterations 70
# Cbc0038I Pass  24: suminf.    9.85540 (55) obj. -14.6065 iterations 67
# Cbc0038I Pass  25: suminf.    9.66611 (55) obj. -14.6065 iterations 20
# Cbc0038I Pass  26: suminf.   13.32677 (51) obj. -14.6065 iterations 115
# Cbc0038I Pass  27: suminf.   11.95063 (53) obj. -14.6065 iterations 56
# Cbc0038I Pass  28: suminf.    8.29222 (45) obj. -14.6065 iterations 52
# Cbc0038I Pass  29: suminf.    5.42838 (60) obj. -14.6065 iterations 48
# Cbc0038I Pass  30: suminf.    5.12143 (60) obj. -14.6065 iterations 29
# Cbc0038I Pass  31: suminf.   10.46340 (55) obj. -14.6065 iterations 81
# Cbc0038I Pass  32: suminf.   10.15132 (54) obj. -14.6065 iterations 21
# Cbc0038I Pass  33: suminf.   10.09327 (45) obj. -14.6065 iterations 45
# Cbc0038I Pass  34: suminf.    5.12263 (61) obj. -14.6065 iterations 53
# Cbc0038I Pass  35: suminf.    5.12143 (60) obj. -14.6065 iterations 8
# Cbc0038I Pass  36: suminf.   10.46340 (55) obj. -14.6065 iterations 81
# Cbc0038I Pass  37: suminf.   10.15132 (54) obj. -14.6065 iterations 21
# Cbc0038I Pass  38: suminf.   10.35292 (44) obj. -14.6065 iterations 36
# Cbc0038I Pass  39: suminf.    9.33932 (56) obj. -14.6065 iterations 45
# Cbc0038I Pass  40: suminf.    9.91590 (47) obj. -14.6065 iterations 51
# Cbc0038I Pass  41: suminf.    8.38861 (56) obj. -14.6065 iterations 51
# Cbc0038I Pass  42: suminf.    8.33438 (58) obj. -14.6065 iterations 6
# Cbc0038I Pass  43: suminf.   10.92245 (46) obj. -14.6065 iterations 60
# Cbc0038I Pass  44: suminf.   10.39348 (42) obj. -14.6065 iterations 26
# Cbc0038I Pass  45: suminf.   10.13326 (50) obj. -14.6065 iterations 35
# Cbc0038I Pass  46: suminf.    9.69188 (54) obj. -14.6065 iterations 17
# Cbc0038I Pass  47: suminf.    9.56878 (53) obj. -14.6065 iterations 9
# Cbc0038I Pass  48: suminf.   11.74966 (37) obj. -14.6065 iterations 58
# Cbc0038I Pass  49: suminf.   10.38411 (44) obj. -14.6065 iterations 57
# Cbc0038I Pass  50: suminf.    9.89174 (39) obj. -14.6065 iterations 30
# Cbc0038I Pass  51: suminf.    9.81957 (38) obj. -14.6065 iterations 18
# Cbc0038I Pass  52: suminf.    7.63500 (47) obj. -14.6065 iterations 80
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 345 rows 64 columns, reduced to 345 rows 63 columns - 1 fixed gives 312, 52 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.09 seconds)
# Cbc0038I After 0.09 seconds - Feasibility pump exiting with objective of -13 - took 0.06 seconds
# Cbc0012I Integer solution of -13 found by feasibility pump after 0 iterations and 0 nodes (0.09 seconds)
# Cbc0031I 16 added rows had average density of 41.5
# Cbc0013I At root node, 16 cuts changed objective from -16.021978 to -15.504691 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 7 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.056 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1496 row cuts average 62.9 elements, 0 column cuts (0 active)  in 0.031 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 2 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 284 row cuts average 61.8 elements, 0 column cuts (0 active)  in 0.051 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 74 row cuts average 4.1 elements, 0 column cuts (0 active)  in 0.400 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -13 best solution, best possible -15.504691 (1.11 seconds)
# Cbc0012I Integer solution of -14 found by DiveCoefficient after 8694 iterations and 2 nodes (1.18 seconds)
# Cbc0001I Search completed - best objective -14, took 9305 iterations and 12 nodes (1.30 seconds)
# Cbc0032I Strong branching done 326 times (12256 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 5, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -16.022 to -15.5047
# Probing was tried 100 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.056 seconds)
# Gomory was tried 100 times and created 1496 cuts of which 0 were active after adding rounds of cuts (0.031 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# Clique was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 112 times and created 535 cuts of which 0 were active after adding rounds of cuts (0.070 seconds)
# ZeroHalf was tried 100 times and created 74 cuts of which 0 were active after adding rounds of cuts (0.400 seconds)
#
# Result - Optimal solution found
#
# Objective value:                14.00000000
# Enumerated nodes:               12
# Total iterations:               9305
# Time (CPU seconds):             1.25
# Time (Wallclock seconds):       1.31
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.25   (Wallclock seconds):       1.31
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f67e193f20f549dfb3565e28b406ecc2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f67e193f20f549dfb3565e28b406ecc2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 114 COLUMNS
# At line 525 RHS
# At line 635 BOUNDS
# At line 700 ENDATA
# Problem MODEL has 109 rows, 64 columns and 218 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 33.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 48 rows, 31 columns (31 integer (31 of which binary)) and 97 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 6 integers unsatisfied sum - 3
# Cbc0038I Solution found of -30
# Cbc0038I Before mini branch and bound, 25 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 48 rows 31 columns, reduced to 7 rows 6 columns
# Cbc0038I Mini branch and bound improved solution from -30 to -33 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -33 - took 0.00 seconds
# Cbc0012I Integer solution of -33 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -33, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -33 to -33
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                33.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/05f60e5496c74e2ebcc2ff774be277f9-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/05f60e5496c74e2ebcc2ff774be277f9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1519 COLUMNS
# At line 4740 RHS
# At line 6255 BOUNDS
# At line 6320 ENDATA
# Problem MODEL has 1514 rows, 64 columns and 3028 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1514 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1441 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1414 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1406 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1397 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1387 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1324 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1148 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 782 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1372 rows, 64 columns (64 integer (64 of which binary)) and 14195 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 58 integers unsatisfied sum - 6.38167
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1372 rows 64 columns, reduced to 1327 rows 58 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.68 seconds)
# Cbc0038I Round again with cutoff of -1.53808
# Cbc0038I Pass   1: suminf.    0.46192 (1) obj. -1.53808 iterations 236
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -3 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1372 rows 64 columns, reduced to 1327 rows 58 columns - 2 fixed gives 4, 3 - ok now
# Cbc0038I Full problem 1372 rows 64 columns, reduced to 4 rows 3 columns
# Cbc0038I Mini branch and bound did not improve solution (0.71 seconds)
# Cbc0038I Round again with cutoff of -4.47625
# Cbc0038I Pass   2: suminf.    3.51933 (30) obj. -4.47625 iterations 75
# Cbc0038I Pass   3: suminf.    1.65409 (50) obj. -4.47625 iterations 144
# Cbc0038I Pass   4: suminf.    4.32681 (21) obj. -4.47625 iterations 135
# Cbc0038I Pass   5: suminf.    2.61939 (12) obj. -4.47625 iterations 57
# Cbc0038I Pass   6: suminf.    1.68295 (47) obj. -4.47625 iterations 147
# Cbc0038I Pass   7: suminf.    5.00000 (21) obj. -5 iterations 136
# Cbc0038I Pass   8: suminf.    3.51933 (30) obj. -4.47625 iterations 153
# Cbc0038I Pass   9: suminf.    1.65409 (50) obj. -4.47625 iterations 126
# Cbc0038I Pass  10: suminf.    4.32681 (21) obj. -4.47625 iterations 135
# Cbc0038I Pass  11: suminf.    2.61939 (12) obj. -4.47625 iterations 57
# Cbc0038I Pass  12: suminf.    1.68295 (47) obj. -4.47625 iterations 125
# Cbc0038I Pass  13: suminf.    3.36514 (15) obj. -4.47625 iterations 108
# Cbc0038I Pass  14: suminf.    1.50214 (47) obj. -4.47625 iterations 107
# Cbc0038I Pass  15: suminf.    4.73684 (21) obj. -4.73684 iterations 120
# Cbc0038I Pass  16: suminf.    3.51933 (30) obj. -4.47625 iterations 123
# Cbc0038I Pass  17: suminf.    1.65409 (50) obj. -4.47625 iterations 147
# Cbc0038I Pass  18: suminf.    4.24548 (16) obj. -4.47625 iterations 132
# Cbc0038I Pass  19: suminf.    3.47625 (7) obj. -4.47625 iterations 101
# Cbc0038I Pass  20: suminf.    3.50000 (7) obj. -4.5 iterations 67
# Cbc0038I Pass  21: suminf.    2.34212 (27) obj. -4.47625 iterations 70
# Cbc0038I Pass  22: suminf.    1.48564 (48) obj. -4.47625 iterations 92
# Cbc0038I Pass  23: suminf.    1.74161 (42) obj. -4.47625 iterations 193
# Cbc0038I Pass  24: suminf.    1.58419 (46) obj. -4.47625 iterations 81
# Cbc0038I Pass  25: suminf.    2.50000 (5) obj. -4.5 iterations 142
# Cbc0038I Pass  26: suminf.    1.42876 (3) obj. -4.47625 iterations 69
# Cbc0038I Pass  27: suminf.    1.42876 (3) obj. -4.47625 iterations 78
# Cbc0038I Solution found of -5
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1372 rows 64 columns, reduced to 1341 rows 60 columns - 0 fixed gives 1341, 60 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.90 seconds)
# Cbc0038I Round again with cutoff of -6.11443
# Cbc0038I Reduced cost fixing fixed 3 variables on major pass 4
# Cbc0038I Pass  28: suminf.    6.11443 (53) obj. -6.11443 iterations 167
# Cbc0038I Pass  29: suminf.    6.01576 (47) obj. -6.11443 iterations 71
# Cbc0038I Pass  30: suminf.    5.73627 (47) obj. -6.11443 iterations 69
# Cbc0038I Pass  31: suminf.    6.10727 (41) obj. -6.11443 iterations 84
# Cbc0038I Pass  32: suminf.    6.11443 (47) obj. -6.11443 iterations 87
# Cbc0038I Pass  33: suminf.    6.11443 (43) obj. -6.11443 iterations 103
# Cbc0038I Pass  34: suminf.    6.03517 (50) obj. -6.11443 iterations 73
# Cbc0038I Pass  35: suminf.    6.11443 (51) obj. -6.11443 iterations 71
# Cbc0038I Pass  36: suminf.    6.11443 (49) obj. -6.11443 iterations 130
# Cbc0038I Pass  37: suminf.    6.11443 (50) obj. -6.11443 iterations 86
# Cbc0038I Pass  38: suminf.    5.98488 (45) obj. -6.11443 iterations 87
# Cbc0038I Pass  39: suminf.    6.11443 (48) obj. -6.11443 iterations 83
# Cbc0038I Pass  40: suminf.    6.11443 (51) obj. -6.11443 iterations 109
# Cbc0038I Pass  41: suminf.    6.11443 (53) obj. -6.11443 iterations 98
# Cbc0038I Pass  42: suminf.    6.08448 (49) obj. -6.11443 iterations 65
# Cbc0038I Pass  43: suminf.    6.11443 (47) obj. -6.11443 iterations 110
# Cbc0038I Pass  44: suminf.    6.11443 (45) obj. -6.11443 iterations 96
# Cbc0038I Pass  45: suminf.    6.11443 (49) obj. -6.11443 iterations 83
# Cbc0038I Pass  46: suminf.    5.93523 (43) obj. -6.11443 iterations 89
# Cbc0038I Pass  47: suminf.    6.11443 (51) obj. -6.11443 iterations 78
# Cbc0038I Pass  48: suminf.    6.11443 (51) obj. -6.11443 iterations 89
# Cbc0038I Pass  49: suminf.    6.11443 (48) obj. -6.11443 iterations 99
# Cbc0038I Pass  50: suminf.    6.11443 (53) obj. -6.11443 iterations 119
# Cbc0038I Pass  51: suminf.    6.11443 (48) obj. -6.11443 iterations 119
# Cbc0038I Pass  52: suminf.    6.11443 (53) obj. -6.11443 iterations 121
# Cbc0038I Pass  53: suminf.    6.11443 (45) obj. -6.11443 iterations 73
# Cbc0038I Pass  54: suminf.    6.11443 (52) obj. -6.11443 iterations 80
# Cbc0038I Pass  55: suminf.    6.11443 (51) obj. -6.11443 iterations 77
# Cbc0038I Pass  56: suminf.    6.11443 (54) obj. -6.11443 iterations 105
# Cbc0038I Pass  57: suminf.    6.11443 (52) obj. -6.11443 iterations 90
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1372 rows 64 columns, reduced to 1341 rows 61 columns - 3 fixed gives 0, 0 - ok now
# Cbc0038I Mini branch and bound did not improve solution (1.19 seconds)
# Cbc0038I After 1.19 seconds - Feasibility pump exiting with objective of -5 - took 0.46 seconds
# Cbc0012I Integer solution of -5 found by feasibility pump after 0 iterations and 0 nodes (1.19 seconds)
# Cbc0031I 29 added rows had average density of 21.275862
# Cbc0013I At root node, 118 cuts changed objective from -6.3816677 to -5.956837 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 51 row cuts average 10.8 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 168 row cuts average 62.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 73 row cuts average 10.7 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -5, took 527 iterations and 0 nodes (1.36 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Cuts at root node changed objective from -6.38167 to -5.95684
# Probing was tried 3 times and created 51 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# Gomory was tried 3 times and created 168 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 3 times and created 73 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# FlowCover was tried 3 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               0
# Total iterations:               527
# Time (CPU seconds):             1.30
# Time (Wallclock seconds):       1.39
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.30   (Wallclock seconds):       1.39
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/be28340a1e114da3833a76826c0a6dbf-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/be28340a1e114da3833a76826c0a6dbf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 22 COLUMNS
# At line 249 RHS
# At line 267 BOUNDS
# At line 332 ENDATA
# Problem MODEL has 17 rows, 64 columns and 34 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 52.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -52 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                52.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/aaf2442b0c2943c9abf12cd8acee39bd-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/aaf2442b0c2943c9abf12cd8acee39bd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1569 COLUMNS
# At line 4890 RHS
# At line 6455 BOUNDS
# At line 6520 ENDATA
# Problem MODEL has 1564 rows, 64 columns and 3128 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1564 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1489 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1471 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1454 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1447 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1444 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1427 strengthened rows, 0 substitutions
# ...
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.36   (Wallclock seconds):       3.48
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/085e8206ae064c969bc4f128f67fd2d3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/085e8206ae064c969bc4f128f67fd2d3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1836 COLUMNS
# At line 5691 RHS
# At line 7523 BOUNDS
# At line 7588 ENDATA
# Problem MODEL has 1831 rows, 64 columns and 3662 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1831 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1767 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1741 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1720 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1707 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1699 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1694 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1688 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1688 strengthened rows, 0 substitutions
# Cgl0004I processed model has 1688 rows, 64 columns (64 integer (64 of which binary)) and 18568 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 48 integers unsatisfied sum - 10.6891
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 16 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1688 rows 64 columns, reduced to 1415 rows 48 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (1.94 seconds)
# Cbc0038I Round again with cutoff of -1.96882
# Cbc0038I Pass   1: suminf.    1.93765 (4) obj. -1.96882 iterations 431
# Cbc0038I Pass   2: suminf.    0.03118 (1) obj. -1.96882 iterations 4
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1688 rows 64 columns, reduced to 1677 rows 59 columns - 1 fixed gives 12, 5 - ok now
# Cbc0038I Full problem 1688 rows 64 columns, reduced to 12 rows 5 columns
# Cbc0038I Mini branch and bound improved solution from -2 to -3 (1.99 seconds)
# Cbc0038I Round again with cutoff of -5.33774
# Cbc0038I Reduced cost fixing fixed 4 variables on major pass 3
# Cbc0038I Pass   3: suminf.    5.33774 (17) obj. -5.33774 iterations 37
# Cbc0038I Pass   4: suminf.    5.66667 (17) obj. -5.66667 iterations 31
# Cbc0038I Pass   5: suminf.    5.33774 (22) obj. -5.33774 iterations 109
# Cbc0038I Pass   6: suminf.    5.33774 (11) obj. -5.33774 iterations 61
# Cbc0038I Pass   7: suminf.    5.33774 (18) obj. -5.33774 iterations 69
# Cbc0038I Pass   8: suminf.    7.34680 (25) obj. -7.3468 iterations 64
# Cbc0038I Pass   9: suminf.    5.33774 (17) obj. -5.33774 iterations 41
# Cbc0038I Pass  10: suminf.    3.37674 (38) obj. -5.33774 iterations 56
# Cbc0038I Pass  11: suminf.    3.22229 (33) obj. -5.33774 iterations 19
# Cbc0038I Pass  12: suminf.    5.33774 (11) obj. -5.33774 iterations 74
# Cbc0038I Pass  13: suminf.    5.33774 (17) obj. -5.33774 iterations 73
# Cbc0038I Pass  14: suminf.    5.66667 (17) obj. -5.66667 iterations 31
# Cbc0038I Pass  15: suminf.    5.33774 (11) obj. -5.33774 iterations 72
# Cbc0038I Pass  16: suminf.    5.33774 (18) obj. -5.33774 iterations 58
# Cbc0038I Pass  17: suminf.    5.33774 (11) obj. -5.33774 iterations 45
# Cbc0038I Pass  18: suminf.    5.33774 (11) obj. -5.33774 iterations 54
# Cbc0038I Pass  19: suminf.    5.33774 (15) obj. -5.33774 iterations 32
# Cbc0038I Pass  20: suminf.    6.07143 (17) obj. -6.07143 iterations 44
# Cbc0038I Pass  21: suminf.    5.62500 (17) obj. -5.625 iterations 33
# Cbc0038I Pass  22: suminf.    5.05203 (19) obj. -5.33774 iterations 47
# Cbc0038I Pass  23: suminf.    3.95872 (36) obj. -5.33774 iterations 48
# Cbc0038I Pass  24: suminf.    7.33333 (22) obj. -7.33333 iterations 68
# Cbc0038I Pass  25: suminf.    5.75000 (19) obj. -5.75 iterations 65
# Cbc0038I Pass  26: suminf.    5.08774 (16) obj. -5.33774 iterations 47
# Cbc0038I Pass  27: suminf.    4.37868 (36) obj. -5.33774 iterations 53
# Cbc0038I Pass  28: suminf.    3.32206 (32) obj. -5.33774 iterations 24
# Cbc0038I Pass  29: suminf.    3.13925 (33) obj. -5.33774 iterations 27
# Cbc0038I Pass  30: suminf.    6.00000 (12) obj. -6 iterations 62
# Cbc0038I Pass  31: suminf.    5.33774 (17) obj. -5.33774 iterations 113
# Cbc0038I Pass  32: suminf.    5.66667 (17) obj. -5.66667 iterations 30
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 1688 rows 64 columns, reduced to 1581 rows 52 columns - 1 fixed gives 12, 5 - ok now
# Cbc0038I Full problem 1688 rows 64 columns, reduced to 12 rows 5 columns
# Cbc0038I Mini branch and bound did not improve solution (2.10 seconds)
# Cbc0038I After 2.10 seconds - Feasibility pump exiting with objective of -3 - took 0.16 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (2.10 seconds)
# Cbc0038I Full problem 1688 rows 64 columns, reduced to 1415 rows 48 columns - 1 fixed gives 12, 5 - ok now
# Cbc0038I Full problem 1688 rows 64 columns, reduced to 12 rows 5 columns
# Cbc0012I Integer solution of -4 found by DiveCoefficient after 1566 iterations and 0 nodes (2.54 seconds)
# Cbc0031I 45 added rows had average density of 15.577778
# Cbc0013I At root node, 45 cuts changed objective from -10.689115 to -4 in 6 passes
# Cbc0014I Cut generator 0 (Probing) - 1891 row cuts average 10.3 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 156 row cuts average 60.9 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 1925 row cuts average 16.2 elements, 0 column cuts (0 active)  in 0.061 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.006 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 76 row cuts average 11.2 elements, 0 column cuts (0 active)  in 0.089 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -4, took 1566 iterations and 0 nodes (2.54 seconds)
# Cbc0035I Maximum depth 0, 19 variables fixed on reduced cost
# Cuts at root node changed objective from -10.6891 to -4
# Probing was tried 6 times and created 1891 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# Gomory was tried 6 times and created 156 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Knapsack was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# Clique was tried 6 times and created 1925 cuts of which 0 were active after adding rounds of cuts (0.061 seconds)
# MixedIntegerRounding2 was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
# FlowCover was tried 6 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 6 times and created 76 cuts of which 0 were active after adding rounds of cuts (0.089 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               1566
# Time (CPU seconds):             2.41
# Time (Wallclock seconds):       2.56
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.41   (Wallclock seconds):       2.56
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/3b372aecbf4348afab032cab55d9fb49-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/3b372aecbf4348afab032cab55d9fb49-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 328 COLUMNS
# At line 1167 RHS
# At line 1491 BOUNDS
# At line 1556 ENDATA
# Problem MODEL has 323 rows, 64 columns and 646 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 125 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 105 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 52 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 196 rows, 64 columns (64 integer (64 of which binary)) and 542 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 61 integers unsatisfied sum - 19.0223
# Cbc0038I Solution found of -9
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 196 rows 64 columns, reduced to 191 rows 61 columns - 3 fixed gives 120, 43 - ok now
# Cbc0038I Full problem 196 rows 64 columns, reduced to 120 rows 43 columns
# Cbc0038I Mini branch and bound improved solution from -9 to -19 (0.02 seconds)
# Cbc0038I Round again with cutoff of -20.1083
# Cbc0038I Pass   1: suminf.   14.41462 (51) obj. -20.1083 iterations 50
# Cbc0038I Pass   2: suminf.   13.90609 (55) obj. -20.1083 iterations 16
# Cbc0038I Pass   3: suminf.   13.90609 (55) obj. -20.1083 iterations 6
# Cbc0038I Pass   4: suminf.   12.11969 (56) obj. -20.1083 iterations 28
# Cbc0038I Pass   5: suminf.   11.03471 (56) obj. -20.1083 iterations 18
# Cbc0038I Pass   6: suminf.   14.65098 (55) obj. -20.1083 iterations 25
# Cbc0038I Pass   7: suminf.   13.12800 (58) obj. -20.1083 iterations 22
# Cbc0038I Pass   8: suminf.   12.59294 (58) obj. -20.1083 iterations 8
# Cbc0038I Pass   9: suminf.   12.23575 (57) obj. -20.1083 iterations 7
# Cbc0038I Pass  10: suminf.   11.30456 (58) obj. -20.1083 iterations 7
# Cbc0038I Pass  11: suminf.   11.03471 (56) obj. -20.1083 iterations 7
# Cbc0038I Pass  12: suminf.   16.49067 (56) obj. -20.1083 iterations 58
# Cbc0038I Pass  13: suminf.   13.69430 (50) obj. -20.1083 iterations 52
# Cbc0038I Pass  14: suminf.   13.68254 (54) obj. -20.1083 iterations 9
# Cbc0038I Pass  15: suminf.   12.38860 (50) obj. -20.1083 iterations 29
# Cbc0038I Pass  16: suminf.   11.48613 (55) obj. -20.1083 iterations 18
# Cbc0038I Pass  17: suminf.   11.16815 (55) obj. -20.1083 iterations 12
# Cbc0038I Pass  18: suminf.   11.03471 (56) obj. -20.1083 iterations 5
# Cbc0038I Pass  19: suminf.   14.29370 (57) obj. -20.1083 iterations 27
# Cbc0038I Pass  20: suminf.   13.31471 (51) obj. -20.1083 iterations 15
# Cbc0038I Pass  21: suminf.   11.82176 (55) obj. -20.1083 iterations 18
# Cbc0038I Pass  22: suminf.   15.55273 (55) obj. -20.1083 iterations 39
# Cbc0038I Pass  23: suminf.   12.05103 (54) obj. -20.1083 iterations 38
# Cbc0038I Pass  24: suminf.   11.30456 (58) obj. -20.1083 iterations 13
# Cbc0038I Pass  25: suminf.   11.03471 (56) obj. -20.1083 iterations 12
# Cbc0038I Pass  26: suminf.   14.78075 (53) obj. -20.1083 iterations 38
# Cbc0038I Pass  27: suminf.   12.74218 (57) obj. -20.1083 iterations 27
# Cbc0038I Pass  28: suminf.   11.67281 (59) obj. -20.1083 iterations 12
# Cbc0038I Pass  29: suminf.   11.30456 (58) obj. -20.1083 iterations 4
# Cbc0038I Pass  30: suminf.   11.03471 (56) obj. -20.1083 iterations 12
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 196 rows 64 columns, reduced to 196 rows 64 columns - 7 fixed gives 72, 30 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -19 - took 0.01 seconds
# Cbc0012I Integer solution of -19 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0031I 21 added rows had average density of 27.47619
# Cbc0013I At root node, 21 cuts changed objective from -21.083799 to -20.00001 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.026 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2351 row cuts average 63.9 elements, 0 column cuts (0 active)  in 0.029 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.008 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 2 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 169 row cuts average 61.9 elements, 0 column cuts (0 active)  in 0.033 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 505 row cuts average 5.6 elements, 0 column cuts (0 active)  in 0.320 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -19 best solution, best possible -20.00001 (0.70 seconds)
# Cbc0001I Search completed - best objective -19, took 8038 iterations and 2 nodes (0.73 seconds)
# Cbc0032I Strong branching done 126 times (4918 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -21.0838 to -20
# Probing was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# Gomory was tried 104 times and created 2351 cuts of which 0 were active after adding rounds of cuts (0.030 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.008 seconds)
# Clique was tried 100 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 104 times and created 303 cuts of which 0 were active after adding rounds of cuts (0.044 seconds)
# ZeroHalf was tried 104 times and created 531 cuts of which 0 were active after adding rounds of cuts (0.333 seconds)
#
# Result - Optimal solution found
#
# Objective value:                19.00000000
# Enumerated nodes:               2
# Total iterations:               8038
# Time (CPU seconds):             0.71
# Time (Wallclock seconds):       0.74
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.71   (Wallclock seconds):       0.74
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Average ILP Time: 1.2357 seconds
# Average CNN Time: 0.0345 seconds
# Average ILP Stability Number: 19.6000
# Average CNN Predicted Stability Number: 1.4589

# %%
# Parameters, This is the same as the previous experiment, but now repeated for 20 graphs instead of 10. It compares
#time and accuracy more thoroughly.
num_trials = 20
num_nodes = 64

ilp_times = []
cnn_times = []
ilp_results = []
cnn_results = []

for _ in range(num_trials):
    # Generate a random graph
    G = nx.gnp_random_graph(num_nodes, np.random.rand())

    # Measure time for ILP method
    start_time = time.time()
    mis = max_independent_set_ilp(G)
    ilp_time = time.time() - start_time
    ilp_independence_number = len(mis)

    # Convert graph to image
    input_image = np.array(convert_to_heatmap_image(G)).reshape(1, 64, 64, 1)  # Add batch and channel dimensions

    # Measure time for CNN prediction
    start_time = time.time()
    cnn_pred = model.predict(input_image)[0][0]
    cnn_time = time.time() - start_time

    # Collect results
    ilp_times.append(ilp_time)
    cnn_times.append(cnn_time)
    ilp_results.append(ilp_independence_number)
    cnn_results.append(cnn_pred)

# Compute averages
avg_ilp_time = np.mean(ilp_times)
avg_cnn_time = np.mean(cnn_times)
avg_ilp_result = np.mean(ilp_results)
avg_cnn_result = np.mean(cnn_results)

print(f"Average ILP Time: {avg_ilp_time:.4f} seconds")
print(f"Average CNN Time: {avg_cnn_time:.4f} seconds")
print(f"Average ILP Stability Number: {avg_ilp_result:.4f}")
print(f"Average CNN Predicted Stability Number: {avg_cnn_result:.4f}")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/003c06af11ce4d3dbfff9641e43f8c27-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/003c06af11ce4d3dbfff9641e43f8c27-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 557 COLUMNS
# At line 1854 RHS
# At line 2407 BOUNDS
# At line 2472 ENDATA
# Problem MODEL has 552 rows, 64 columns and 1104 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 435 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 324 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 131 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 39 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 323 rows, 64 columns (64 integer (64 of which binary)) and 1187 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 63 integers unsatisfied sum - 15.75
# Cbc0038I Solution found of -5
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 323 rows 64 columns, reduced to 323 rows 63 columns - 2 fixed gives 228, 42 - still too large
# Cbc0038I Full problem 323 rows 64 columns, reduced to 228 rows 42 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I Round again with cutoff of -7.04876
# Cbc0038I Pass   1: suminf.    0.04876 (1) obj. -7.04876 iterations 127
# Cbc0038I Pass   2: suminf.    0.04876 (1) obj. -7.04876 iterations 3
# Cbc0038I Solution found of -8
# Cbc0038I Rounding solution of -12 is better than previous of -8
#
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 323 rows 64 columns, reduced to 323 rows 63 columns - 5 fixed gives 108, 26 - ok now
# Cbc0038I Full problem 323 rows 64 columns, reduced to 108 rows 26 columns
# Cbc0038I Mini branch and bound improved solution from -12 to -13 (0.05 seconds)
# Cbc0038I Round again with cutoff of -14.4976
# Cbc0038I Pass   3: suminf.    8.49284 (26) obj. -14.4976 iterations 54
# Cbc0038I Pass   4: suminf.    6.87458 (53) obj. -14.4976 iterations 46
# Cbc0038I Pass   5: suminf.    6.69446 (52) obj. -14.4976 iterations 22
# Cbc0038I Pass   6: suminf.    8.04967 (43) obj. -14.4976 iterations 38
# Cbc0038I Pass   7: suminf.    6.52733 (52) obj. -14.4976 iterations 34
# Cbc0038I Pass   8: suminf.    9.70048 (29) obj. -14.4976 iterations 86
# Cbc0038I Pass   9: suminf.    8.24085 (29) obj. -14.4976 iterations 36
# Cbc0038I Pass  10: suminf.    8.10156 (54) obj. -14.4976 iterations 23
# Cbc0038I Pass  11: suminf.    8.28997 (27) obj. -14.4976 iterations 35
# Cbc0038I Pass  12: suminf.    7.39997 (46) obj. -14.4976 iterations 44
# Cbc0038I Pass  13: suminf.    7.11366 (32) obj. -14.4976 iterations 22
# Cbc0038I Pass  14: suminf.    8.20644 (24) obj. -14.4976 iterations 93
# Cbc0038I Pass  15: suminf.    7.48806 (45) obj. -14.4976 iterations 44
# Cbc0038I Pass  16: suminf.    6.66179 (47) obj. -14.4976 iterations 22
# Cbc0038I Pass  17: suminf.    8.49284 (29) obj. -14.4976 iterations 97
# Cbc0038I Pass  18: suminf.    7.31058 (40) obj. -14.4976 iterations 35
# Cbc0038I Pass  19: suminf.    7.21665 (39) obj. -14.4976 iterations 7
# Cbc0038I Pass  20: suminf.    8.16269 (27) obj. -14.4976 iterations 48
# Cbc0038I Pass  21: suminf.    6.73926 (33) obj. -14.4976 iterations 38
# Cbc0038I Pass  22: suminf.    6.51664 (49) obj. -14.4976 iterations 32
# Cbc0038I Pass  23: suminf.    9.95982 (33) obj. -14.4976 iterations 86
# Cbc0038I Pass  24: suminf.    9.91611 (51) obj. -14.4976 iterations 38
# Cbc0038I Pass  25: suminf.    8.89156 (44) obj. -14.4976 iterations 20
# Cbc0038I Pass  26: suminf.    8.48329 (33) obj. -14.4976 iterations 17
# Cbc0038I Pass  27: suminf.    3.90395 (56) obj. -14.4976 iterations 43
# Cbc0038I Pass  28: suminf.    3.45923 (60) obj. -14.4976 iterations 21
# Cbc0038I Pass  29: suminf.    7.49125 (26) obj. -14.4976 iterations 57
# Cbc0038I Pass  30: suminf.    6.22691 (38) obj. -14.4976 iterations 49
# Cbc0038I Pass  31: suminf.    3.85650 (58) obj. -14.4976 iterations 111
# Cbc0038I Pass  32: suminf.    3.51308 (61) obj. -14.4976 iterations 37
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 323 rows 64 columns, reduced to 323 rows 63 columns - 5 fixed gives 108, 26 - ok now
# Cbc0038I Full problem 323 rows 64 columns, reduced to 82 rows 24 columns
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I After 0.08 seconds - Feasibility pump exiting with objective of -13 - took 0.04 seconds
# Cbc0012I Integer solution of -13 found by feasibility pump after 0 iterations and 0 nodes (0.08 seconds)
# Cbc0031I 13 added rows had average density of 41.461538
# Cbc0013I At root node, 13 cuts changed objective from -16.488462 to -16.043981 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.058 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1554 row cuts average 63.8 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.010 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 6 row cuts average 4.2 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.015 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 271 row cuts average 61.7 elements, 0 column cuts (0 active)  in 0.049 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 130 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.400 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -13 best solution, best possible -16.043981 (1.17 seconds)
# Cbc0012I Integer solution of -14 found by DiveCoefficient after 8296 iterations and 6 nodes (1.37 seconds)
# Cbc0001I Search completed - best objective -14, took 10139 iterations and 22 nodes (1.65 seconds)
# Cbc0032I Strong branching done 536 times (19053 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 5, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -16.4885 to -16.044
# Probing was tried 100 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.058 seconds)
# Gomory was tried 100 times and created 1554 cuts of which 0 were active after adding rounds of cuts (0.032 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.010 seconds)
# Clique was tried 100 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.015 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 131 times and created 732 cuts of which 0 were active after adding rounds of cuts (0.083 seconds)
# ZeroHalf was tried 131 times and created 228 cuts of which 0 were active after adding rounds of cuts (0.515 seconds)
#
# Result - Optimal solution found
#
# Objective value:                14.00000000
# Enumerated nodes:               22
# Total iterations:               10139
# Time (CPU seconds):             1.50
# Time (Wallclock seconds):       1.66
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.50   (Wallclock seconds):       1.66
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/437680359fd348f4b0f062cce9f2a957-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/437680359fd348f4b0f062cce9f2a957-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 673 COLUMNS
# At line 2202 RHS
# At line 2871 BOUNDS
# At line 2936 ENDATA
# Problem MODEL has 668 rows, 64 columns and 1336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 626 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 403 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 210 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 73 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 20 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 396 rows, 64 columns (64 integer (64 of which binary)) and 1619 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 64 integers unsatisfied sum - 14.2203
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 396 rows 64 columns, reduced to 396 rows 64 columns - 0 fixed gives 396, 64 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of -3.22964
# Cbc0038I Pass   1: suminf.    0.22964 (1) obj. -3.22964 iterations 138
# Cbc0038I Pass   2: suminf.    0.22964 (1) obj. -3.22964 iterations 0
# Cbc0038I Solution found of -4
# Cbc0038I Rounding solution of -8 is better than previous of -4
#
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 396 rows 64 columns, reduced to 396 rows 64 columns - 1 fixed gives 316, 46 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -10.0594
# Cbc0038I Pass   3: suminf.    8.04939 (24) obj. -10.0594 iterations 74
# Cbc0038I Pass   4: suminf.    3.26467 (58) obj. -10.0594 iterations 77
# Cbc0038I Pass   5: suminf.    3.12381 (48) obj. -10.0594 iterations 30
# Cbc0038I Pass   6: suminf.    0.17814 (3) obj. -10.0594 iterations 161
# Cbc0038I Pass   7: suminf.    0.17814 (3) obj. -10.0594 iterations 58
# Cbc0038I Solution found of -11
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 396 rows 64 columns, reduced to 396 rows 64 columns - 1 fixed gives 316, 46 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I Round again with cutoff of -12.6891
# Cbc0038I Pass   8: suminf.   11.56412 (43) obj. -12.6891 iterations 75
# Cbc0038I Pass   9: suminf.   10.88338 (49) obj. -12.6891 iterations 59
# Cbc0038I Pass  10: suminf.   10.65434 (53) obj. -12.6891 iterations 58
# Cbc0038I Pass  11: suminf.    7.54444 (61) obj. -12.6891 iterations 74
# Cbc0038I Pass  12: suminf.    7.51997 (61) obj. -12.6891 iterations 6
# Cbc0038I Pass  13: suminf.   11.95337 (48) obj. -12.6891 iterations 95
# Cbc0038I Pass  14: suminf.   10.99061 (53) obj. -12.6891 iterations 46
# Cbc0038I Pass  15: suminf.   10.74286 (53) obj. -12.6891 iterations 34
# Cbc0038I Pass  16: suminf.   10.23538 (53) obj. -12.6891 iterations 27
# Cbc0038I Pass  17: suminf.   10.09208 (51) obj. -12.6891 iterations 40
# Cbc0038I Pass  18: suminf.   12.06736 (50) obj. -12.6891 iterations 98
# Cbc0038I Pass  19: suminf.    8.60101 (57) obj. -12.6891 iterations 80
# Cbc0038I Pass  20: suminf.   12.31670 (51) obj. -12.6891 iterations 104
# Cbc0038I Pass  21: suminf.   10.05388 (51) obj. -12.6891 iterations 58
# Cbc0038I Pass  22: suminf.    9.50291 (54) obj. -12.6891 iterations 29
# Cbc0038I Pass  23: suminf.    8.92420 (58) obj. -12.6891 iterations 28
# Cbc0038I Pass  24: suminf.    8.13726 (57) obj. -12.6891 iterations 69
# Cbc0038I Pass  25: suminf.    8.01033 (58) obj. -12.6891 iterations 23
# Cbc0038I Pass  26: suminf.   10.03714 (56) obj. -12.6891 iterations 110
# Cbc0038I Pass  27: suminf.    8.23228 (57) obj. -12.6891 iterations 73
# Cbc0038I Pass  28: suminf.    8.03061 (58) obj. -12.6891 iterations 16
# Cbc0038I Pass  29: suminf.    7.97337 (56) obj. -12.6891 iterations 14
# Cbc0038I Pass  30: suminf.    9.76781 (53) obj. -12.6891 iterations 61
# Cbc0038I Pass  31: suminf.    8.36779 (56) obj. -12.6891 iterations 58
# Cbc0038I Pass  32: suminf.   11.69833 (49) obj. -12.6891 iterations 126
# Cbc0038I Pass  33: suminf.   10.30473 (58) obj. -12.6891 iterations 92
# Cbc0038I Pass  34: suminf.   11.82729 (48) obj. -12.6891 iterations 68
# Cbc0038I Pass  35: suminf.   10.01700 (56) obj. -12.6891 iterations 76
# Cbc0038I Pass  36: suminf.    9.92697 (57) obj. -12.6891 iterations 25
# Cbc0038I Pass  37: suminf.    9.95285 (57) obj. -12.6891 iterations 40
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 396 rows 64 columns, reduced to 396 rows 64 columns - 1 fixed gives 316, 46 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.11 seconds)
# Cbc0038I After 0.11 seconds - Feasibility pump exiting with objective of -11 - took 0.06 seconds
# Cbc0012I Integer solution of -11 found by feasibility pump after 0 iterations and 0 nodes (0.11 seconds)
# Cbc0031I 13 added rows had average density of 45.692308
# Cbc0013I At root node, 13 cuts changed objective from -14.297295 to -13.793012 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.061 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1153 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.037 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 12 row cuts average 4.3 elements, 0 column cuts (0 active)  in 0.026 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.019 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 74 row cuts average 3.2 elements, 0 column cuts (0 active)  in 0.563 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -11 best solution, best possible -13.793012 (1.48 seconds)
# Cbc0001I Search completed - best objective -11, took 10719 iterations and 22 nodes (1.89 seconds)
# Cbc0032I Strong branching done 484 times (18628 iterations), fathomed 4 nodes and fixed 0 variables
# Cbc0035I Maximum depth 10, 6 variables fixed on reduced cost
# Cuts at root node changed objective from -14.2973 to -13.793
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.061 seconds)
# Gomory was tried 100 times and created 1153 cuts of which 0 were active after adding rounds of cuts (0.037 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Clique was tried 100 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.026 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.019 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# ZeroHalf was tried 100 times and created 74 cuts of which 0 were active after adding rounds of cuts (0.563 seconds)
#
# Result - Optimal solution found
#
# Objective value:                11.00000000
# Enumerated nodes:               22
# Total iterations:               10719
# Time (CPU seconds):             1.71
# Time (Wallclock seconds):       1.90
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.71   (Wallclock seconds):       1.90
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/7e1970c1594e40428430f839486d0f80-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/7e1970c1594e40428430f839486d0f80-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1233 COLUMNS
# At line 3882 RHS
# At line 5111 BOUNDS
# At line 5176 ENDATA
# Problem MODEL has 1228 rows, 64 columns and 2456 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1227 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1152 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1137 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1087 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 908 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 492 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 195 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 63 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 22 strengthened rows, 0 substitutions
# Cgl0004I processed model has 982 rows, 64 columns (64 integer (64 of which binary)) and 7286 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 59 integers unsatisfied sum - 8.48534
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 982 rows 64 columns, reduced to 950 rows 59 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.30 seconds)
# Cbc0038I Round again with cutoff of -1.74844
# Cbc0038I Pass   1: suminf.    1.74844 (6) obj. -1.74844 iterations 213
# Cbc0038I Pass   2: suminf.    1.66667 (5) obj. -2.33333 iterations 1
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -5 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 982 rows 64 columns, reduced to 955 rows 60 columns - 1 fixed gives 556, 29 - still too large
# Cbc0038I Full problem 982 rows 64 columns, reduced to 556 rows 29 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.32 seconds)
# Cbc0038I Round again with cutoff of -6.49699
# Cbc0038I Pass   3: suminf.    6.40032 (34) obj. -6.49699 iterations 81
# Cbc0038I Pass   4: suminf.    4.78528 (17) obj. -6.49699 iterations 120
# Cbc0038I Pass   5: suminf.    0.49699 (1) obj. -6.49699 iterations 99
# Cbc0038I Pass   6: suminf.    0.49699 (1) obj. -6.49699 iterations 109
# Cbc0038I Solution found of -7
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 982 rows 64 columns, reduced to 950 rows 59 columns - 1 fixed gives 556, 29 - still too large
# Cbc0038I Full problem 982 rows 64 columns, reduced to 556 rows 29 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.35 seconds)
# Cbc0038I Round again with cutoff of -8.14553
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 4
# Cbc0038I Pass   7: suminf.    8.14553 (56) obj. -8.14553 iterations 159
# Cbc0038I Pass   8: suminf.    7.75517 (54) obj. -8.14553 iterations 83
# Cbc0038I Pass   9: suminf.    7.42435 (53) obj. -8.14553 iterations 49
# Cbc0038I Pass  10: suminf.    8.12921 (52) obj. -8.14553 iterations 90
# Cbc0038I Pass  11: suminf.    7.58792 (57) obj. -8.14553 iterations 90
# Cbc0038I Pass  12: suminf.    7.49722 (57) obj. -8.14553 iterations 37
# Cbc0038I Pass  13: suminf.    7.86726 (58) obj. -8.14553 iterations 59
# Cbc0038I Pass  14: suminf.    7.40608 (54) obj. -8.14553 iterations 63
# Cbc0038I Pass  15: suminf.    7.78982 (56) obj. -8.14553 iterations 67
# Cbc0038I Pass  16: suminf.    7.51217 (55) obj. -8.14553 iterations 53
# Cbc0038I Pass  17: suminf.    7.89937 (49) obj. -8.14553 iterations 90
# Cbc0038I Pass  18: suminf.    7.48805 (52) obj. -8.14553 iterations 53
# Cbc0038I Pass  19: suminf.    7.40608 (54) obj. -8.14553 iterations 28
# Cbc0038I Pass  20: suminf.    7.88731 (51) obj. -8.14553 iterations 80
# Cbc0038I Pass  21: suminf.    8.14553 (56) obj. -8.14553 iterations 74
# Cbc0038I Pass  22: suminf.    8.14553 (56) obj. -8.14553 iterations 85
# Cbc0038I Pass  23: suminf.    8.14553 (49) obj. -8.14553 iterations 74
# Cbc0038I Pass  24: suminf.    8.14553 (54) obj. -8.14553 iterations 74
# Cbc0038I Pass  25: suminf.    8.14553 (56) obj. -8.14553 iterations 56
# Cbc0038I Pass  26: suminf.    8.14553 (52) obj. -8.14553 iterations 95
# Cbc0038I Pass  27: suminf.    8.14553 (55) obj. -8.14553 iterations 69
# Cbc0038I Pass  28: suminf.    7.95179 (55) obj. -8.14553 iterations 103
# Cbc0038I Pass  29: suminf.    7.48805 (52) obj. -8.14553 iterations 74
# Cbc0038I Pass  30: suminf.    7.40608 (54) obj. -8.14553 iterations 29
# Cbc0038I Pass  31: suminf.    7.92397 (51) obj. -8.14553 iterations 79
# Cbc0038I Pass  32: suminf.    8.14553 (52) obj. -8.14553 iterations 75
# Cbc0038I Pass  33: suminf.    8.14553 (56) obj. -8.14553 iterations 91
# Cbc0038I Pass  34: suminf.    7.81221 (53) obj. -8.14553 iterations 105
# Cbc0038I Pass  35: suminf.    7.43878 (54) obj. -8.14553 iterations 38
# Cbc0038I Pass  36: suminf.    7.42599 (55) obj. -8.14553 iterations 14
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 982 rows 64 columns, reduced to 959 rows 63 columns - 1 fixed gives 556, 29 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.48 seconds)
# Cbc0038I After 0.48 seconds - Feasibility pump exiting with objective of -7 - took 0.18 seconds
# Cbc0012I Integer solution of -7 found by feasibility pump after 0 iterations and 0 nodes (0.48 seconds)
# Cbc0031I 23 added rows had average density of 16.73913
# Cbc0013I At root node, 94 cuts changed objective from -8.4853448 to -7.9997703 in 45 passes
# Cbc0014I Cut generator 0 (Probing) - 290 row cuts average 7.3 elements, 0 column cuts (4 active)  in 0.064 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 995 row cuts average 60.3 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 39 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -7, took 5055 iterations and 0 nodes (1.09 seconds)
# Cbc0035I Maximum depth 0, 5 variables fixed on reduced cost
# Cuts at root node changed objective from -8.48534 to -7.99977
# Probing was tried 45 times and created 290 cuts of which 4 were active after adding rounds of cuts (0.064 seconds)
# Gomory was tried 45 times and created 995 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# Knapsack was tried 45 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Clique was tried 45 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# MixedIntegerRounding2 was tried 45 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# FlowCover was tried 45 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.00000000
# Enumerated nodes:               0
# Total iterations:               5055
# Time (CPU seconds):             1.05
# Time (Wallclock seconds):       1.11
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.05   (Wallclock seconds):       1.11
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/78f7771414254de995cdb6867242f9e3-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/78f7771414254de995cdb6867242f9e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 644 COLUMNS
# At line 2115 RHS
# At line 2755 BOUNDS
# At line 2820 ENDATA
# Problem MODEL has 639 rows, 64 columns and 1278 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 570 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 394 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 162 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 63 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 6 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 383 rows, 64 columns (64 integer (64 of which binary)) and 1509 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 63 integers unsatisfied sum - 14.7762
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 64 columns, reduced to 382 rows 63 columns - 0 fixed gives 382, 63 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of -4.19222
# Cbc0038I Pass   1: suminf.    0.19222 (1) obj. -4.19222 iterations 127
# Cbc0038I Pass   2: suminf.    0.19222 (1) obj. -4.19222 iterations 7
# Cbc0038I Solution found of -5
# Cbc0038I Rounding solution of -9 is better than previous of -5
#
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 64 columns, reduced to 382 rows 63 columns - 2 fixed gives 215, 36 - still too large
# Cbc0038I Full problem 383 rows 64 columns, reduced to 215 rows 36 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.05 seconds)
# Cbc0038I Round again with cutoff of -10.9845
# Cbc0038I Pass   3: suminf.    7.22482 (22) obj. -10.9845 iterations 63
# Cbc0038I Pass   4: suminf.    4.63059 (14) obj. -10.9845 iterations 56
# Cbc0038I Pass   5: suminf.    4.12801 (27) obj. -10.9845 iterations 82
# Cbc0038I Pass   6: suminf.    2.90920 (50) obj. -10.9845 iterations 40
# Cbc0038I Pass   7: suminf.    3.98454 (8) obj. -10.9845 iterations 107
# Cbc0038I Pass   8: suminf.    0.01546 (1) obj. -10.9845 iterations 30
# Cbc0038I Solution found of -11
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 64 columns, reduced to 382 rows 64 columns - 2 fixed gives 225, 37 - still too large
# Cbc0038I Full problem 383 rows 64 columns, reduced to 225 rows 37 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.07 seconds)
# Cbc0038I Round again with cutoff of -12.8769
# Cbc0038I Pass   9: suminf.   10.55742 (41) obj. -12.8769 iterations 74
# Cbc0038I Pass  10: suminf.    9.86714 (41) obj. -12.8769 iterations 52
# Cbc0038I Pass  11: suminf.    9.18446 (42) obj. -12.8769 iterations 37
# Cbc0038I Pass  12: suminf.    9.71267 (42) obj. -12.8769 iterations 52
# Cbc0038I Pass  13: suminf.    7.63256 (55) obj. -12.8769 iterations 54
# Cbc0038I Pass  14: suminf.    7.39909 (56) obj. -12.8769 iterations 21
# Cbc0038I Pass  15: suminf.    8.02925 (50) obj. -12.8769 iterations 118
# Cbc0038I Pass  16: suminf.    0.86199 (7) obj. -12.8769 iterations 127
# Cbc0038I Solution found of -13
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 64 columns, reduced to 382 rows 64 columns - 1 fixed gives 317, 48 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.08 seconds)
# Cbc0038I Round again with cutoff of -14.2769
# Cbc0038I Pass  17: suminf.   13.07822 (60) obj. -14.2769 iterations 73
# Cbc0038I Pass  18: suminf.   12.85163 (57) obj. -14.2769 iterations 41
# Cbc0038I Pass  19: suminf.   13.07088 (54) obj. -14.2769 iterations 40
# Cbc0038I Pass  20: suminf.   12.59965 (54) obj. -14.2769 iterations 57
# Cbc0038I Pass  21: suminf.   12.51508 (57) obj. -14.2769 iterations 22
# Cbc0038I Pass  22: suminf.   12.43096 (59) obj. -14.2769 iterations 13
# Cbc0038I Pass  23: suminf.   12.67324 (53) obj. -14.2769 iterations 46
# Cbc0038I Pass  24: suminf.   11.70134 (61) obj. -14.2769 iterations 41
# Cbc0038I Pass  25: suminf.   11.50260 (62) obj. -14.2769 iterations 16
# Cbc0038I Pass  26: suminf.   11.49829 (62) obj. -14.2769 iterations 9
# Cbc0038I Pass  27: suminf.   12.38024 (55) obj. -14.2769 iterations 50
# Cbc0038I Pass  28: suminf.   11.64580 (63) obj. -14.2769 iterations 39
# Cbc0038I Pass  29: suminf.   13.63839 (54) obj. -14.2769 iterations 68
# Cbc0038I Pass  30: suminf.   13.07764 (55) obj. -14.2769 iterations 56
# Cbc0038I Pass  31: suminf.   12.75337 (58) obj. -14.2769 iterations 55
# Cbc0038I Pass  32: suminf.   12.39773 (59) obj. -14.2769 iterations 29
# Cbc0038I Pass  33: suminf.   12.71716 (56) obj. -14.2769 iterations 75
# Cbc0038I Pass  34: suminf.   11.95049 (55) obj. -14.2769 iterations 44
# Cbc0038I Pass  35: suminf.   11.64580 (63) obj. -14.2769 iterations 20
# Cbc0038I Pass  36: suminf.   11.50260 (62) obj. -14.2769 iterations 12
# Cbc0038I Pass  37: suminf.   11.49829 (62) obj. -14.2769 iterations 9
# Cbc0038I Pass  38: suminf.   13.07058 (57) obj. -14.2769 iterations 84
# Cbc0038I Pass  39: suminf.   12.67268 (55) obj. -14.2769 iterations 58
# Cbc0038I Pass  40: suminf.   12.99125 (55) obj. -14.2769 iterations 44
# Cbc0038I Pass  41: suminf.   12.44967 (60) obj. -14.2769 iterations 38
# Cbc0038I Pass  42: suminf.   13.04144 (51) obj. -14.2769 iterations 41
# Cbc0038I Pass  43: suminf.   12.67699 (53) obj. -14.2769 iterations 34
# Cbc0038I Pass  44: suminf.   12.94397 (56) obj. -14.2769 iterations 43
# Cbc0038I Pass  45: suminf.   12.51048 (58) obj. -14.2769 iterations 38
# Cbc0038I Pass  46: suminf.   12.39773 (59) obj. -14.2769 iterations 23
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 383 rows 64 columns, reduced to 382 rows 64 columns - 1 fixed gives 317, 48 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.12 seconds)
# Cbc0038I After 0.12 seconds - Feasibility pump exiting with objective of -13 - took 0.07 seconds
# Cbc0012I Integer solution of -13 found by feasibility pump after 0 iterations and 0 nodes (0.12 seconds)
# Cbc0031I 8 added rows had average density of 28.625
# Cbc0013I At root node, 8 cuts changed objective from -14.923094 to -14.000014 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.055 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2967 row cuts average 63.9 elements, 0 column cuts (0 active)  in 0.027 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.012 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 22 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 169 row cuts average 3.9 elements, 0 column cuts (0 active)  in 0.384 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -13 best solution, best possible -14.000014 (1.11 seconds)
# Cbc0001I Search completed - best objective -13, took 10767 iterations and 10 nodes (1.26 seconds)
# Cbc0032I Strong branching done 254 times (8755 iterations), fathomed 0 nodes and fixed 0 variables
# Cbc0035I Maximum depth 4, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -14.9231 to -14
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.055 seconds)
# Gomory was tried 106 times and created 2967 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.012 seconds)
# Clique was tried 100 times and created 22 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# TwoMirCuts was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# ZeroHalf was tried 100 times and created 169 cuts of which 0 were active after adding rounds of cuts (0.384 seconds)
#
# Result - Optimal solution found
#
# Objective value:                13.00000000
# Enumerated nodes:               10
# Total iterations:               10767
# Time (CPU seconds):             1.21
# Time (Wallclock seconds):       1.27
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       1.21   (Wallclock seconds):       1.27
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/2d6ce942882c41d58bd047fdf8b6299e-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/2d6ce942882c41d58bd047fdf8b6299e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 893 COLUMNS
# At line 2862 RHS
# At line 3751 BOUNDS
# At line 3816 ENDATA
# Problem MODEL has 888 rows, 64 columns and 1776 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 881 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 767 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 588 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 255 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 102 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 27 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0004I processed model has 602 rows, 64 columns (64 integer (64 of which binary)) and 3088 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 62 integers unsatisfied sum - 11.6257
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 602 rows 64 columns, reduced to 600 rows 62 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.10 seconds)
# Cbc0038I Round again with cutoff of -2.06248
# Cbc0038I Pass   1: suminf.    0.06248 (1) obj. -2.06248 iterations 147
# Cbc0038I Pass   2: suminf.    0.06248 (1) obj. -2.06248 iterations 0
# Cbc0038I Solution found of -3
# Cbc0038I Rounding solution of -6 is better than previous of -3
#
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 602 rows 64 columns, reduced to 600 rows 62 columns - 2 fixed gives 85, 17 - ok now
# Cbc0038I Full problem 602 rows 64 columns, reduced to 85 rows 17 columns
# Cbc0038I Mini branch and bound improved solution from -6 to -7 (0.11 seconds)
# Cbc0038I Round again with cutoff of -8.72506
# Cbc0038I Pass   3: suminf.    8.15363 (28) obj. -8.72506 iterations 68
# Cbc0038I Pass   4: suminf.    0.27494 (1) obj. -8.72506 iterations 74
# Cbc0038I Solution found of -9
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 602 rows 64 columns, reduced to 600 rows 62 columns - 1 fixed gives 327, 32 - still too large
# Cbc0038I Full problem 602 rows 64 columns, reduced to 327 rows 32 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.12 seconds)
# Cbc0038I Round again with cutoff of -10.4876
# Cbc0038I Pass   5: suminf.   10.22382 (55) obj. -10.4876 iterations 106
# Cbc0038I Pass   6: suminf.    8.62476 (44) obj. -10.4876 iterations 91
# Cbc0038I Pass   7: suminf.    7.01413 (53) obj. -10.4876 iterations 59
# Cbc0038I Pass   8: suminf.    9.86161 (43) obj. -10.4876 iterations 99
# Cbc0038I Pass   9: suminf.    7.82923 (52) obj. -10.4876 iterations 68
# Cbc0038I Pass  10: suminf.    7.76774 (54) obj. -10.4876 iterations 23
# Cbc0038I Pass  11: suminf.    9.08564 (47) obj. -10.4876 iterations 98
# Cbc0038I Pass  12: suminf.    8.00422 (48) obj. -10.4876 iterations 46
# Cbc0038I Pass  13: suminf.    7.85601 (47) obj. -10.4876 iterations 21
# Cbc0038I Pass  14: suminf.    7.14884 (47) obj. -10.4876 iterations 28
# Cbc0038I Pass  15: suminf.    6.91368 (50) obj. -10.4876 iterations 24
# Cbc0038I Pass  16: suminf.    9.39325 (45) obj. -10.4876 iterations 100
# Cbc0038I Pass  17: suminf.    4.19612 (51) obj. -10.4876 iterations 90
# Cbc0038I Pass  18: suminf.    3.96549 (51) obj. -10.4876 iterations 29
# Cbc0038I Pass  19: suminf.   10.08845 (46) obj. -10.4876 iterations 117
# Cbc0038I Pass  20: suminf.    8.97527 (41) obj. -10.4876 iterations 77
# Cbc0038I Pass  21: suminf.    8.69704 (43) obj. -10.4876 iterations 42
# Cbc0038I Pass  22: suminf.    8.41797 (48) obj. -10.4876 iterations 39
# Cbc0038I Pass  23: suminf.    8.25099 (55) obj. -10.4876 iterations 40
# Cbc0038I Pass  24: suminf.    7.84356 (53) obj. -10.4876 iterations 35
# Cbc0038I Pass  25: suminf.    6.98563 (55) obj. -10.4876 iterations 45
# Cbc0038I Pass  26: suminf.    8.39745 (49) obj. -10.4876 iterations 113
# Cbc0038I Pass  27: suminf.    7.41728 (45) obj. -10.4876 iterations 50
# Cbc0038I Pass  28: suminf.    7.04073 (48) obj. -10.4876 iterations 29
# Cbc0038I Pass  29: suminf.    6.92052 (53) obj. -10.4876 iterations 20
# Cbc0038I Pass  30: suminf.    7.88020 (48) obj. -10.4876 iterations 96
# Cbc0038I Pass  31: suminf.    4.09913 (51) obj. -10.4876 iterations 86
# Cbc0038I Pass  32: suminf.    3.96549 (51) obj. -10.4876 iterations 37
# Cbc0038I Pass  33: suminf.    4.45610 (49) obj. -10.4876 iterations 72
# Cbc0038I Pass  34: suminf.    3.84657 (54) obj. -10.4876 iterations 33
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 602 rows 64 columns, reduced to 600 rows 62 columns - 1 fixed gives 327, 32 - still too large
# Cbc0038I Full problem 602 rows 64 columns, reduced to 327 rows 32 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.19 seconds)
# Cbc0038I After 0.19 seconds - Feasibility pump exiting with objective of -9 - took 0.09 seconds
# Cbc0012I Integer solution of -9 found by feasibility pump after 0 iterations and 0 nodes (0.19 seconds)
# Cbc0012I Integer solution of -10 found by DiveCoefficient after 0 iterations and 0 nodes (0.20 seconds)
# Cbc0031I 17 added rows had average density of 28.941176
# Cbc0013I At root node, 17 cuts changed objective from -11.625688 to -11.351329 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 12 row cuts average 5.6 elements, 0 column cuts (0 active)  in 0.073 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1819 row cuts average 63.0 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.016 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 17 row cuts average 4.9 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 411 row cuts average 63.0 elements, 0 column cuts (0 active)  in 0.079 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 24 row cuts average 3.6 elements, 0 column cuts (0 active)  in 0.635 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -10 best solution, best possible -11.351329 (1.85 seconds)
# Cbc0001I Search completed - best objective -10, took 10795 iterations and 8 nodes (2.14 seconds)
# Cbc0032I Strong branching done 242 times (10383 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 3, 2 variables fixed on reduced cost
# Cuts at root node changed objective from -11.6257 to -11.3513
# Probing was tried 100 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.073 seconds)
# Gomory was tried 100 times and created 1819 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.016 seconds)
# Clique was tried 100 times and created 17 cuts of which 0 were active after adding rounds of cuts (0.035 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# TwoMirCuts was tried 111 times and created 938 cuts of which 0 were active after adding rounds of cuts (0.103 seconds)
# ZeroHalf was tried 100 times and created 24 cuts of which 0 were active after adding rounds of cuts (0.635 seconds)
#
# Result - Optimal solution found
#
# Objective value:                10.00000000
# Enumerated nodes:               8
# Total iterations:               10795
# Time (CPU seconds):             2.08
# Time (Wallclock seconds):       2.15
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.08   (Wallclock seconds):       2.15
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/452c4a079bf64c54b9436fff8532eab0-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/452c4a079bf64c54b9436fff8532eab0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 147 COLUMNS
# At line 624 RHS
# At line 767 BOUNDS
# At line 832 ENDATA
# Problem MODEL has 142 rows, 64 columns and 284 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 12 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0004I processed model has 101 rows, 56 columns (56 integer (56 of which binary)) and 215 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -30
# Cbc0038I Before mini branch and bound, 56 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -30 - took 0.00 seconds
# Cbc0012I Integer solution of -30 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -30, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -30 to -30
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                30.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/25c4dd0dd1d644908b3d681461fd3551-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/25c4dd0dd1d644908b3d681461fd3551-pulp.sol (default strategy 1)
# ...
#
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 713 rows 64 columns, reduced to 709 rows 60 columns - 2 fixed gives 68, 15 - ok now
# Cbc0038I Full problem 713 rows 64 columns, reduced to 68 rows 15 columns
# Cbc0038I Mini branch and bound improved solution from -6 to -7 (0.15 seconds)
# Cbc0038I Round again with cutoff of -8.52922
# Cbc0038I Pass   2: suminf.    6.80301 (30) obj. -8.52922 iterations 75
# Cbc0038I Pass   3: suminf.    5.10233 (44) obj. -8.52922 iterations 90
# Cbc0038I Pass   4: suminf.    3.24470 (43) obj. -8.52922 iterations 32
# Cbc0038I Pass   5: suminf.    2.54968 (52) obj. -8.52922 iterations 63
# Cbc0038I Pass   6: suminf.    6.06789 (31) obj. -8.52922 iterations 114
# Cbc0038I Pass   7: suminf.    4.83856 (43) obj. -8.52922 iterations 79
# Cbc0038I Pass   8: suminf.    6.53895 (25) obj. -8.52922 iterations 149
# Cbc0038I Pass   9: suminf.    4.56817 (26) obj. -8.52922 iterations 44
# Cbc0038I Pass  10: suminf.    2.70417 (35) obj. -8.52922 iterations 46
# Cbc0038I Pass  11: suminf.    2.43995 (48) obj. -8.52922 iterations 53
# Cbc0038I Pass  12: suminf.    6.23515 (19) obj. -8.52922 iterations 101
# Cbc0038I Pass  13: suminf.    5.36428 (17) obj. -8.52922 iterations 73
# Cbc0038I Pass  14: suminf.    3.17530 (12) obj. -8.52922 iterations 118
# Cbc0038I Pass  15: suminf.    2.43676 (47) obj. -8.52922 iterations 130
# Cbc0038I Pass  16: suminf.    2.57888 (33) obj. -8.52922 iterations 87
# Cbc0038I Pass  17: suminf.    2.39605 (53) obj. -8.52922 iterations 55
# Cbc0038I Pass  18: suminf.    7.74270 (23) obj. -8.52922 iterations 124
# Cbc0038I Pass  19: suminf.    5.35259 (19) obj. -8.52922 iterations 124
# Cbc0038I Pass  20: suminf.    4.91550 (43) obj. -8.52922 iterations 110
# Cbc0038I Pass  21: suminf.    6.17530 (23) obj. -8.52922 iterations 124
# Cbc0038I Pass  22: suminf.    3.84777 (45) obj. -8.52922 iterations 79
# Cbc0038I Pass  23: suminf.    2.42687 (52) obj. -8.52922 iterations 73
# Cbc0038I Pass  24: suminf.    6.52922 (20) obj. -8.52922 iterations 160
# Cbc0038I Pass  25: suminf.    2.87566 (48) obj. -8.52922 iterations 99
# Cbc0038I Pass  26: suminf.    2.68528 (55) obj. -8.52922 iterations 30
# Cbc0038I Pass  27: suminf.    7.04827 (32) obj. -8.52922 iterations 124
# Cbc0038I Pass  28: suminf.    6.53953 (42) obj. -8.52922 iterations 50
# Cbc0038I Pass  29: suminf.    7.52922 (20) obj. -8.52922 iterations 88
# Cbc0038I Pass  30: suminf.    6.14460 (25) obj. -8.52922 iterations 58
# Cbc0038I Pass  31: suminf.    4.87255 (47) obj. -8.52922 iterations 72
# Cbc0038I Rounding solution of -8 is better than previous of -7
#
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 713 rows 64 columns, reduced to 712 rows 64 columns - 2 fixed gives 85, 16 - ok now
# Cbc0038I Full problem 713 rows 64 columns, reduced to 85 rows 16 columns
# Cbc0038I Mini branch and bound did not improve solution (0.24 seconds)
# Cbc0038I Round again with cutoff of -9.49387
# Cbc0038I Pass  31: suminf.    9.29724 (44) obj. -9.49387 iterations 59
# Cbc0038I Pass  32: suminf.    7.63651 (45) obj. -9.49387 iterations 86
# Cbc0038I Pass  33: suminf.    7.34157 (44) obj. -9.49387 iterations 37
# Cbc0038I Pass  34: suminf.    8.28059 (42) obj. -9.49387 iterations 75
# Cbc0038I Pass  35: suminf.    7.59495 (44) obj. -9.49387 iterations 60
# Cbc0038I Pass  36: suminf.    8.82176 (33) obj. -9.49387 iterations 94
# Cbc0038I Pass  37: suminf.    7.44215 (45) obj. -9.49387 iterations 78
# Cbc0038I Pass  38: suminf.    7.28338 (47) obj. -9.49387 iterations 34
# Cbc0038I Pass  39: suminf.    8.59414 (43) obj. -9.49387 iterations 103
# Cbc0038I Pass  40: suminf.    8.13108 (47) obj. -9.49387 iterations 40
# Cbc0038I Pass  41: suminf.    8.08111 (48) obj. -9.49387 iterations 7
# Cbc0038I Pass  42: suminf.    8.54349 (40) obj. -9.49387 iterations 102
# Cbc0038I Pass  43: suminf.    7.17534 (38) obj. -9.49387 iterations 72
# Cbc0038I Pass  44: suminf.    6.99039 (40) obj. -9.49387 iterations 41
# Cbc0038I Pass  45: suminf.    8.38821 (45) obj. -9.49387 iterations 91
# Cbc0038I Pass  46: suminf.    7.00050 (47) obj. -9.49387 iterations 67
# Cbc0038I Pass  47: suminf.    6.69577 (51) obj. -9.49387 iterations 47
# Cbc0038I Pass  48: suminf.    6.68565 (53) obj. -9.49387 iterations 13
# Cbc0038I Pass  49: suminf.    8.62134 (43) obj. -9.49387 iterations 123
# Cbc0038I Pass  50: suminf.    7.22856 (28) obj. -9.49387 iterations 94
# Cbc0038I Pass  51: suminf.    6.92593 (52) obj. -9.49387 iterations 61
# Cbc0038I Pass  52: suminf.    6.75444 (50) obj. -9.49387 iterations 22
# Cbc0038I Pass  53: suminf.    8.78048 (37) obj. -9.49387 iterations 119
# Cbc0038I Pass  54: suminf.    7.52588 (43) obj. -9.49387 iterations 60
# Cbc0038I Pass  55: suminf.    7.34157 (44) obj. -9.49387 iterations 25
# Cbc0038I Pass  56: suminf.    8.77959 (38) obj. -9.49387 iterations 124
# Cbc0038I Pass  57: suminf.    7.82488 (40) obj. -9.49387 iterations 63
# Cbc0038I Pass  58: suminf.    7.18775 (45) obj. -9.49387 iterations 39
# Cbc0038I Pass  59: suminf.    6.61564 (46) obj. -9.49387 iterations 39
# Cbc0038I Pass  60: suminf.    7.69044 (34) obj. -9.49387 iterations 121
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 713 rows 64 columns, reduced to 712 rows 63 columns - 2 fixed gives 85, 16 - ok now
# Cbc0038I Full problem 713 rows 64 columns, reduced to 85 rows 16 columns
# Cbc0038I Mini branch and bound did not improve solution (0.32 seconds)
# Cbc0038I After 0.32 seconds - Feasibility pump exiting with objective of -8 - took 0.19 seconds
# Cbc0012I Integer solution of -8 found by feasibility pump after 0 iterations and 0 nodes (0.32 seconds)
# Cbc0031I 18 added rows had average density of 31.722222
# Cbc0013I At root node, 18 cuts changed objective from -10.646481 to -10.293905 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.094 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1914 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.041 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.022 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 24 row cuts average 5.9 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.034 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 514 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.099 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -8 best solution, best possible -10.293905 (1.63 seconds)
# Cbc0001I Search completed - best objective -8, took 13959 iterations and 18 nodes (2.46 seconds)
# Cbc0032I Strong branching done 404 times (19731 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 8, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -10.6465 to -10.2939
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.094 seconds)
# Gomory was tried 100 times and created 1914 cuts of which 0 were active after adding rounds of cuts (0.041 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.022 seconds)
# Clique was tried 100 times and created 24 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.034 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# TwoMirCuts was tried 114 times and created 807 cuts of which 0 were active after adding rounds of cuts (0.126 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               18
# Total iterations:               13959
# Time (CPU seconds):             2.42
# Time (Wallclock seconds):       2.48
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       2.42   (Wallclock seconds):       2.48
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/ad3489db84ab4f568e49c9c917be0f16-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/ad3489db84ab4f568e49c9c917be0f16-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 271 COLUMNS
# At line 996 RHS
# At line 1263 BOUNDS
# At line 1328 ENDATA
# Problem MODEL has 266 rows, 64 columns and 532 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 85 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 83 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 30 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 2 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 169 rows, 64 columns (64 integer (64 of which binary)) and 437 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 63 integers unsatisfied sum - 20.1634
# Cbc0038I Solution found of -17
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 169 rows 64 columns, reduced to 167 rows 63 columns - 5 fixed gives 32, 21 - ok now
# Cbc0038I Full problem 169 rows 64 columns, reduced to 22 rows 17 columns
# Cbc0038I Mini branch and bound improved solution from -17 to -21 (0.01 seconds)
# Cbc0038I Round again with cutoff of -22.1829
# Cbc0038I Pass   1: suminf.   10.91458 (48) obj. -22.1829 iterations 29
# Cbc0038I Pass   2: suminf.   10.42949 (43) obj. -22.1829 iterations 19
# Cbc0038I Pass   3: suminf.   12.83535 (48) obj. -22.1829 iterations 31
# Cbc0038I Pass   4: suminf.   10.91458 (54) obj. -22.1829 iterations 21
# Cbc0038I Pass   5: suminf.   10.91458 (54) obj. -22.1829 iterations 4
# Cbc0038I Pass   6: suminf.   14.93903 (45) obj. -22.1829 iterations 43
# Cbc0038I Pass   7: suminf.    8.28042 (54) obj. -22.1829 iterations 38
# Cbc0038I Pass   8: suminf.    8.16212 (59) obj. -22.1829 iterations 14
# Cbc0038I Pass   9: suminf.   12.14021 (45) obj. -22.1829 iterations 35
# Cbc0038I Pass  10: suminf.   11.84839 (45) obj. -22.1829 iterations 6
# Cbc0038I Pass  11: suminf.   12.96825 (38) obj. -22.1829 iterations 21
# Cbc0038I Pass  12: suminf.    6.28646 (37) obj. -22.1829 iterations 11
# Cbc0038I Pass  13: suminf.    5.46333 (48) obj. -22.1829 iterations 21
# Cbc0038I Pass  14: suminf.    5.43285 (48) obj. -22.1829 iterations 7
# Cbc0038I Pass  15: suminf.    1.96635 (51) obj. -22.1829 iterations 15
# Cbc0038I Pass  16: suminf.    1.93892 (44) obj. -22.1829 iterations 4
# Cbc0038I Pass  17: suminf.    2.15842 (46) obj. -22.1829 iterations 19
# Cbc0038I Pass  18: suminf.    2.01208 (53) obj. -22.1829 iterations 18
# Cbc0038I Pass  19: suminf.   12.00403 (42) obj. -22.1829 iterations 47
# Cbc0038I Pass  20: suminf.    9.12536 (50) obj. -22.1829 iterations 28
# Cbc0038I Pass  21: suminf.    2.56083 (45) obj. -22.1829 iterations 16
# Cbc0038I Pass  22: suminf.    2.01208 (44) obj. -22.1829 iterations 17
# Cbc0038I Pass  23: suminf.    7.43217 (41) obj. -22.1829 iterations 26
# Cbc0038I Pass  24: suminf.    5.31090 (48) obj. -22.1829 iterations 18
# Cbc0038I Pass  25: suminf.    2.10354 (52) obj. -22.1829 iterations 12
# Cbc0038I Pass  26: suminf.    1.93892 (44) obj. -22.1829 iterations 4
# Cbc0038I Pass  27: suminf.    2.07305 (47) obj. -22.1829 iterations 12
# Cbc0038I Pass  28: suminf.    2.01208 (53) obj. -22.1829 iterations 10
# Cbc0038I Pass  29: suminf.    8.67472 (41) obj. -22.1829 iterations 19
# Cbc0038I Pass  30: suminf.    2.46937 (46) obj. -22.1829 iterations 18
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 169 rows 64 columns, reduced to 167 rows 63 columns - 14 fixed gives 0, 0 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -21 - took 0.01 seconds
# Cbc0012I Integer solution of -21 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0012I Integer solution of -22 found by DiveCoefficient after 3016 iterations and 0 nodes (0.34 seconds)
# Cbc0031I 39 added rows had average density of 10.435897
# Cbc0013I At root node, 39 cuts changed objective from -23.830065 to -22.000014 in 54 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.011 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1096 row cuts average 63.7 elements, 0 column cuts (0 active)  in 0.014 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.005 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 148 row cuts average 63.0 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 534 row cuts average 6.6 elements, 0 column cuts (0 active)  in 0.166 seconds - new frequency is 1
# Cbc0001I Search completed - best objective -22, took 3016 iterations and 0 nodes (0.34 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -23.8301 to -22
# Probing was tried 54 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.011 seconds)
# Gomory was tried 54 times and created 1096 cuts of which 0 were active after adding rounds of cuts (0.014 seconds)
# Knapsack was tried 54 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# Clique was tried 54 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.005 seconds)
# MixedIntegerRounding2 was tried 54 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# FlowCover was tried 54 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 54 times and created 148 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# ZeroHalf was tried 54 times and created 534 cuts of which 0 were active after adding rounds of cuts (0.166 seconds)
#
# Result - Optimal solution found
#
# Objective value:                22.00000000
# Enumerated nodes:               0
# Total iterations:               3016
# Time (CPU seconds):             0.32
# Time (Wallclock seconds):       0.34
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.32   (Wallclock seconds):       0.34
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Average ILP Time: 2.0286 seconds
# Average CNN Time: 0.0345 seconds
# Average ILP Stability Number: 10.3000
# Average CNN Predicted Stability Number: 2.5091

# %%
# Parameters
graph_sizes = [5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60, 64]
ilp_times = []
cnn_times = []
independence_number_diffs = []

for n in graph_sizes:
    G = nx.gnp_random_graph(n, np.random.rand())

    # Measure time for ILP method
    start_time = time.time()
    mis = max_independent_set_ilp(G)
    ilp_time = time.time() - start_time
    ilp_independence_number = len(mis)

    # Convert graph to image
    input_image = np.array(convert_to_heatmap_image(G)).reshape(1, 64, 64, 1)  # Add batch and channel dimensions

    # Measure time for CNN prediction
    start_time = time.time()
    cnn_pred = model.predict(input_image)[0][0]
    cnn_time = time.time() - start_time

    # Collect results
    ilp_times.append(ilp_time)
    cnn_times.append(cnn_time)
    independence_number_diffs.append(abs(ilp_independence_number - cnn_pred))

# Plot results
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))

# Plot runtime comparison
ax1.plot(graph_sizes, ilp_times, label='ILP Runtime', marker='o')
ax1.plot(graph_sizes, cnn_times, label='CNN Runtime', marker='x')
ax1.set_xlabel('Order of the Graph (n)')
ax1.set_ylabel('Runtime (seconds)')
ax1.set_title('Runtime Comparison')
ax1.legend()

# Plot difference in independence numbers
ax2.plot(graph_sizes, independence_number_diffs, label='Difference in Stability Number', marker='o', color='r')
ax2.set_xlabel('Order of the Graph (n)')
ax2.set_ylabel('Difference in Stability Number')
ax2.set_title('Stability Number Difference')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/27804d2cecb94c9cabf79bbae38bd54f-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/27804d2cecb94c9cabf79bbae38bd54f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 8 COLUMNS
# At line 30 RHS
# At line 34 BOUNDS
# At line 40 ENDATA
# Problem MODEL has 3 rows, 5 columns and 6 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 3 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -3 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                3.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/cc936d458dbe4f57b2b72c425401e465-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/cc936d458dbe4f57b2b72c425401e465-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 14 COLUMNS
# At line 63 RHS
# At line 73 BOUNDS
# At line 84 ENDATA
# Problem MODEL has 9 rows, 10 columns and 18 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 8 - 0.00 seconds
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -8 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/b10f18bbcf5145a3b36c8b4280165806-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/b10f18bbcf5145a3b36c8b4280165806-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 101 COLUMNS
# At line 339 RHS
# At line 436 BOUNDS
# At line 452 ENDATA
# Problem MODEL has 96 rows, 15 columns and 192 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 7.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 92 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 80 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 79 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 78 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 76 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 71 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 54 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 24 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0004I processed model has 62 rows, 15 columns (15 integer (15 of which binary)) and 571 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 0 integers unsatisfied sum - 0
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 15 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -2 - took 0.00 seconds
# Cbc0012I Integer solution of -2 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -2, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -2 to -2
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                2.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/147b3c3812c5495da18dba8c1592ded2-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/147b3c3812c5495da18dba8c1592ded2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 70 COLUMNS
# At line 261 RHS
# At line 327 BOUNDS
# At line 348 ENDATA
# Problem MODEL has 65 rows, 20 columns and 130 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 10 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 24 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 3 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 30 rows, 18 columns (18 integer (18 of which binary)) and 86 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 11 integers unsatisfied sum - 3.66667
# Cbc0038I Solution found of -7
# Cbc0038I Before mini branch and bound, 7 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.00 seconds)
# Cbc0038I After 0.00 seconds - Feasibility pump exiting with objective of -7 - took 0.00 seconds
# Cbc0012I Integer solution of -7 found by feasibility pump after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective -7, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 2 variables fixed on reduced cost
# Cuts at root node changed objective from -7.33333 to -7.33333
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/55c6fa890f2848758686422208b3f8c5-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/55c6fa890f2848758686422208b3f8c5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 217 COLUMNS
# At line 717 RHS
# At line 930 BOUNDS
# At line 956 ENDATA
# Problem MODEL has 212 rows, 25 columns and 424 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 12.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 210 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 184 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 176 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 160 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 100 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 43 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0004I processed model has 120 rows, 25 columns (25 integer (25 of which binary)) and 800 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 16 integers unsatisfied sum - 4
# Cbc0038I Solution found of -1
# Cbc0038I Before mini branch and bound, 9 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 120 rows 25 columns, reduced to 83 rows 16 columns
# Cbc0038I Mini branch and bound improved solution from -1 to -4 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -4 - took 0.00 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -4, took 0 iterations and 0 nodes (0.03 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Cuts at root node changed objective from -4.09091 to -4.09091
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/56a376c7e2ef4d32889e7b856678b1a1-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/56a376c7e2ef4d32889e7b856678b1a1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 210 COLUMNS
# At line 711 RHS
# At line 917 BOUNDS
# At line 948 ENDATA
# Problem MODEL has 205 rows, 30 columns and 410 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 15 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 178 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 161 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 100 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 40 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 15 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 105 rows, 30 columns (30 integer (30 of which binary)) and 476 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 18 integers unsatisfied sum - 6.75
# Cbc0038I Solution found of -3
# Cbc0038I Before mini branch and bound, 12 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 105 rows 30 columns, reduced to 58 rows 18 columns
# Cbc0038I Mini branch and bound improved solution from -3 to -7 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -7 - took 0.00 seconds
# Cbc0012I Integer solution of -7 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -7, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 3 variables fixed on reduced cost
# Cuts at root node changed objective from -7.25 to -7.25
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/79891c2492ef44cab4182f89ad263f27-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/79891c2492ef44cab4182f89ad263f27-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 301 COLUMNS
# At line 999 RHS
# At line 1296 BOUNDS
# At line 1332 ENDATA
# Problem MODEL has 296 rows, 35 columns and 592 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 17.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 282 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 227 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 118 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 59 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 18 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0004I processed model has 176 rows, 35 columns (35 integer (35 of which binary)) and 794 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 34 integers unsatisfied sum - 7.125
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 176 rows 35 columns, reduced to 176 rows 34 columns - 0 fixed gives 176, 34 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.02 seconds)
# Cbc0038I Round again with cutoff of -3.43324
# Cbc0038I Pass   1: suminf.    0.43324 (1) obj. -3.43324 iterations 65
# Cbc0038I Pass   2: suminf.    0.43324 (1) obj. -3.43324 iterations 0
# Cbc0038I Solution found of -4
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 176 rows 35 columns, reduced to 176 rows 34 columns - 2 fixed gives 54, 13 - ok now
# Cbc0038I Full problem 176 rows 35 columns, reduced to 54 rows 13 columns
# Cbc0038I Mini branch and bound improved solution from -4 to -7 (0.02 seconds)
# Cbc0038I After 0.02 seconds - Feasibility pump exiting with objective of -7 - took 0.00 seconds
# Cbc0012I Integer solution of -7 found by feasibility pump after 0 iterations and 0 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective -7, took 0 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 1 variables fixed on reduced cost
# Cuts at root node changed objective from -7.33333 to -7.33333
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.03
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d3f9bfb6bf1545699829593d52865c41-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/d3f9bfb6bf1545699829593d52865c41-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 584 COLUMNS
# At line 1863 RHS
# At line 2443 BOUNDS
# At line 2484 ENDATA
# Problem MODEL has 579 rows, 40 columns and 1158 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 20 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 579 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 530 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 523 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 521 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 512 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 453 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 309 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 124 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 44 strengthened rows, 0 substitutions
# Cgl0004I processed model has 468 rows, 40 columns (40 integer (40 of which binary)) and 4121 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 30 integers unsatisfied sum - 5.06897
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 10 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 468 rows 40 columns, reduced to 376 rows 30 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.13 seconds)
# Cbc0038I Round again with cutoff of -1.40681
# Cbc0038I Pass   1: suminf.    0.40681 (1) obj. -1.40681 iterations 116
# Cbc0038I Pass   2: suminf.    0.40681 (1) obj. -1.40681 iterations 0
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -4 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 10 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 468 rows 40 columns, reduced to 376 rows 30 columns - 0 fixed gives 376, 30 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.14 seconds)
# Cbc0038I Round again with cutoff of -5.01371
# Cbc0038I Reduced cost fixing fixed 7 variables on major pass 3
# Cbc0038I Pass   3: suminf.    5.01371 (30) obj. -5.01371 iterations 75
# Cbc0038I Pass   4: suminf.    1.30274 (29) obj. -5.01371 iterations 46
# Cbc0038I Pass   5: suminf.    1.24302 (30) obj. -5.01371 iterations 7
# Cbc0038I Pass   6: suminf.    5.01371 (27) obj. -5.01371 iterations 29
# Cbc0038I Pass   7: suminf.    5.01371 (29) obj. -5.01371 iterations 10
# Cbc0038I Pass   8: suminf.    5.01371 (29) obj. -5.01371 iterations 11
# Cbc0038I Pass   9: suminf.    5.01371 (29) obj. -5.01371 iterations 23
# Cbc0038I Pass  10: suminf.    1.28903 (29) obj. -5.01371 iterations 41
# Cbc0038I Pass  11: suminf.    1.23379 (31) obj. -5.01371 iterations 8
# Cbc0038I Pass  12: suminf.    1.22595 (30) obj. -5.01371 iterations 3
# Cbc0038I Pass  13: suminf.    5.01371 (27) obj. -5.01371 iterations 34
# Cbc0038I Pass  14: suminf.    5.01371 (30) obj. -5.01371 iterations 8
# Cbc0038I Pass  15: suminf.    1.25818 (29) obj. -5.01371 iterations 39
# Cbc0038I Pass  16: suminf.    1.24302 (30) obj. -5.01371 iterations 2
# Cbc0038I Pass  17: suminf.    5.01371 (28) obj. -5.01371 iterations 37
# Cbc0038I Pass  18: suminf.    5.01371 (29) obj. -5.01371 iterations 22
# Cbc0038I Pass  19: suminf.    1.25094 (29) obj. -5.01371 iterations 36
# Cbc0038I Pass  20: suminf.    1.22595 (30) obj. -5.01371 iterations 5
# Cbc0038I Pass  21: suminf.    5.01371 (27) obj. -5.01371 iterations 32
# Cbc0038I Pass  22: suminf.    5.01371 (30) obj. -5.01371 iterations 15
# Cbc0038I Pass  23: suminf.    1.27837 (29) obj. -5.01371 iterations 31
# Cbc0038I Pass  24: suminf.    1.24302 (30) obj. -5.01371 iterations 6
# Cbc0038I Pass  25: suminf.    5.01371 (27) obj. -5.01371 iterations 32
# Cbc0038I Pass  26: suminf.    1.33017 (27) obj. -5.01371 iterations 32
# Cbc0038I Pass  27: suminf.    1.24551 (30) obj. -5.01371 iterations 12
# Cbc0038I Pass  28: suminf.    1.22666 (30) obj. -5.01371 iterations 3
# Cbc0038I Pass  29: suminf.    1.22595 (30) obj. -5.01371 iterations 1
# Cbc0038I Pass  30: suminf.    5.01371 (27) obj. -5.01371 iterations 38
# Cbc0038I Pass  31: suminf.    5.01371 (30) obj. -5.01371 iterations 18
# Cbc0038I Pass  32: suminf.    1.30274 (29) obj. -5.01371 iterations 47
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 8 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 468 rows 40 columns, reduced to 398 rows 32 columns - 0 fixed gives 398, 32 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.16 seconds)
# Cbc0038I After 0.16 seconds - Feasibility pump exiting with objective of -4 - took 0.03 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.16 seconds)
# Cbc0012I Integer solution of -5 found by DiveCoefficient after 0 iterations and 0 nodes (0.17 seconds)
# Cbc0038I Full problem 468 rows 40 columns, reduced to 376 rows 30 columns - 1 fixed gives 57, 9 - ok now
# Cbc0001I Search completed - best objective -5, took 0 iterations and 0 nodes (0.17 seconds)
# Cbc0035I Maximum depth 0, 9 variables fixed on reduced cost
# Cuts at root node changed objective from -5.06897 to -5.06897
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.17
# Time (Wallclock seconds):       0.17
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.17   (Wallclock seconds):       0.18
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/e89cd6d0a7654dbea6479bbe1adfc2f7-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/e89cd6d0a7654dbea6479bbe1adfc2f7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 528 COLUMNS
# At line 1710 RHS
# At line 2234 BOUNDS
# At line 2280 ENDATA
# Problem MODEL has 523 rows, 45 columns and 1046 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 22.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 522 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 452 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 383 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 213 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 77 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 29 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 9 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 5 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 339 rows, 45 columns (45 integer (45 of which binary)) and 1842 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 41 integers unsatisfied sum - 7.88656
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 339 rows 45 columns, reduced to 334 rows 41 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -1.68857
# Cbc0038I Pass   1: suminf.    1.31143 (4) obj. -1.68857 iterations 92
# Cbc0038I Pass   2: suminf.    0.31143 (1) obj. -1.68857 iterations 1
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -6 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 4 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 339 rows 45 columns, reduced to 334 rows 41 columns - 2 fixed gives 9, 6 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.06 seconds)
# Cbc0038I Round again with cutoff of -7.17723
# Cbc0038I Reduced cost fixing fixed 1 variables on major pass 3
# Cbc0038I Pass   3: suminf.    6.75393 (32) obj. -7.17723 iterations 74
# Cbc0038I Pass   4: suminf.    5.62837 (39) obj. -7.17723 iterations 57
# Cbc0038I Pass   5: suminf.    6.84390 (25) obj. -7.17723 iterations 74
# Cbc0038I Pass   6: suminf.    2.57108 (39) obj. -7.17723 iterations 51
# Cbc0038I Pass   7: suminf.    2.20639 (40) obj. -7.17723 iterations 26
# Cbc0038I Pass   8: suminf.    1.52420 (29) obj. -7.17723 iterations 58
# Cbc0038I Pass   9: suminf.    1.47694 (28) obj. -7.17723 iterations 27
# Cbc0038I Pass  10: suminf.    6.67711 (36) obj. -7.17723 iterations 63
# Cbc0038I Pass  11: suminf.    6.15039 (38) obj. -7.17723 iterations 34
# Cbc0038I Pass  12: suminf.    6.04128 (38) obj. -7.17723 iterations 17
# Cbc0038I Pass  13: suminf.    5.94758 (37) obj. -7.17723 iterations 11
# Cbc0038I Pass  14: suminf.    1.83140 (33) obj. -7.17723 iterations 60
# Cbc0038I Pass  15: suminf.    1.47694 (35) obj. -7.17723 iterations 24
# Cbc0038I Pass  16: suminf.    6.46524 (34) obj. -7.17723 iterations 64
# Cbc0038I Pass  17: suminf.    5.99659 (29) obj. -7.17723 iterations 43
# Cbc0038I Pass  18: suminf.    5.71281 (35) obj. -7.17723 iterations 19
# Cbc0038I Pass  19: suminf.    5.58769 (22) obj. -7.17723 iterations 44
# Cbc0038I Pass  20: suminf.    4.55139 (30) obj. -7.17723 iterations 39
# Cbc0038I Pass  21: suminf.    1.53601 (28) obj. -7.17723 iterations 35
# Cbc0038I Pass  22: suminf.    1.47694 (35) obj. -7.17723 iterations 9
# Cbc0038I Pass  23: suminf.    6.73422 (33) obj. -7.17723 iterations 73
# Cbc0038I Pass  24: suminf.    6.19717 (38) obj. -7.17723 iterations 45
# Cbc0038I Pass  25: suminf.    6.01568 (36) obj. -7.17723 iterations 14
# Cbc0038I Pass  26: suminf.    6.57723 (28) obj. -7.17723 iterations 63
# Cbc0038I Pass  27: suminf.    1.55419 (33) obj. -7.17723 iterations 48
# Cbc0038I Pass  28: suminf.    1.47694 (35) obj. -7.17723 iterations 16
# Cbc0038I Pass  29: suminf.    6.73422 (33) obj. -7.17723 iterations 66
# Cbc0038I Pass  30: suminf.    6.19717 (38) obj. -7.17723 iterations 51
# Cbc0038I Pass  31: suminf.    6.01568 (36) obj. -7.17723 iterations 18
# Cbc0038I Pass  32: suminf.    6.36378 (36) obj. -7.17723 iterations 59
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 2 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 339 rows 45 columns, reduced to 335 rows 43 columns - 1 fixed gives 155, 21 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.09 seconds)
# Cbc0038I After 0.09 seconds - Feasibility pump exiting with objective of -6 - took 0.04 seconds
# Cbc0012I Integer solution of -6 found by feasibility pump after 0 iterations and 0 nodes (0.09 seconds)
# Cbc0012I Integer solution of -7 found by DiveCoefficient after 0 iterations and 0 nodes (0.10 seconds)
# Cbc0001I Search completed - best objective -7, took 0 iterations and 0 nodes (0.10 seconds)
# Cbc0035I Maximum depth 0, 4 variables fixed on reduced cost
# Cuts at root node changed objective from -7.88656 to -7.88656
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.10
# Time (Wallclock seconds):       0.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.10   (Wallclock seconds):       0.10
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f4ab52ccb6c9414e91b725eafd4c3285-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/f4ab52ccb6c9414e91b725eafd4c3285-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 233 COLUMNS
# At line 840 RHS
# At line 1069 BOUNDS
# At line 1120 ENDATA
# Problem MODEL has 228 rows, 50 columns and 456 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 25 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 101 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 79 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 25 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 7 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 131 rows, 50 columns (50 integer (50 of which binary)) and 361 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 36 integers unsatisfied sum - 12
# Cbc0038I Solution found of -12
# Cbc0038I Before mini branch and bound, 14 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 131 rows 50 columns, reduced to 84 rows 36 columns
# Cbc0038I Mini branch and bound improved solution from -12 to -17 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -17 - took 0.00 seconds
# Cbc0012I Integer solution of -17 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -17, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 5 variables fixed on reduced cost
# Cuts at root node changed objective from -17.3333 to -17.3333
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                17.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/17e895bbb2e34917ba9e50cc23449cfa-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/17e895bbb2e34917ba9e50cc23449cfa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 74 COLUMNS
# At line 378 RHS
# At line 448 BOUNDS
# At line 504 ENDATA
# Problem MODEL has 69 rows, 55 columns and 138 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 30.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from -30 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                30.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/874dc9801de74015b36acb09fdc1ca83-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/874dc9801de74015b36acb09fdc1ca83-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 135 COLUMNS
# At line 576 RHS
# At line 707 BOUNDS
# At line 768 ENDATA
# Problem MODEL has 130 rows, 60 columns and 260 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 30.5 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 13 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 10 strengthened rows, 0 substitutions
# Cgl0004I processed model has 91 rows, 53 columns (53 integer (53 of which binary)) and 195 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 47 integers unsatisfied sum - 21.5
# Cbc0038I Solution found of -8
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 91 rows 53 columns, reduced to 68 rows 39 columns
# Cbc0038I Mini branch and bound improved solution from -8 to -26 (0.01 seconds)
# Cbc0038I Round again with cutoff of -27.0499
# Cbc0038I Pass   1: suminf.   15.34937 (40) obj. -27.0499 iterations 18
# Cbc0038I Pass   2: suminf.    1.94649 (38) obj. -27.0499 iterations 10
# Cbc0038I Pass   3: suminf.    1.74685 (35) obj. -27.0499 iterations 7
# Cbc0038I Pass   4: suminf.    7.21508 (34) obj. -27.0499 iterations 8
# Cbc0038I Pass   5: suminf.    1.84667 (32) obj. -27.0499 iterations 5
# Cbc0038I Pass   6: suminf.    1.54721 (31) obj. -27.0499 iterations 5
# Cbc0038I Pass   7: suminf.   11.75045 (31) obj. -27.0499 iterations 8
# Cbc0038I Pass   8: suminf.    1.54721 (31) obj. -27.0499 iterations 6
# Cbc0038I Pass   9: suminf.    1.54721 (31) obj. -27.0499 iterations 3
# Cbc0038I Pass  10: suminf.    1.54721 (31) obj. -27.0499 iterations 0
# Cbc0038I Pass  11: suminf.    8.34937 (31) obj. -27.0499 iterations 6
# Cbc0038I Pass  12: suminf.    1.54721 (31) obj. -27.0499 iterations 4
# Cbc0038I Pass  13: suminf.   13.34937 (34) obj. -27.0499 iterations 19
# Cbc0038I Pass  14: suminf.   12.65063 (32) obj. -27.0499 iterations 7
# Cbc0038I Pass  15: suminf.    1.64703 (32) obj. -27.0499 iterations 5
# Cbc0038I Pass  16: suminf.    1.54721 (31) obj. -27.0499 iterations 2
# Cbc0038I Pass  17: suminf.    1.54721 (31) obj. -27.0499 iterations 3
# Cbc0038I Pass  18: suminf.    1.54721 (31) obj. -27.0499 iterations 0
# Cbc0038I Pass  19: suminf.   15.14973 (35) obj. -27.0499 iterations 15
# Cbc0038I Pass  20: suminf.   11.29020 (32) obj. -27.0499 iterations 11
# Cbc0038I Pass  21: suminf.    1.64703 (32) obj. -27.0499 iterations 10
# Cbc0038I Pass  22: suminf.    1.54721 (31) obj. -27.0499 iterations 1
# Cbc0038I Pass  23: suminf.    1.54721 (31) obj. -27.0499 iterations 4
# Cbc0038I Pass  24: suminf.    1.54721 (31) obj. -27.0499 iterations 2
# Cbc0038I Pass  25: suminf.   13.34937 (34) obj. -27.0499 iterations 13
# Cbc0038I Pass  26: suminf.   12.65063 (32) obj. -27.0499 iterations 7
# Cbc0038I Pass  27: suminf.    1.64703 (32) obj. -27.0499 iterations 9
# Cbc0038I Pass  28: suminf.    1.54721 (31) obj. -27.0499 iterations 1
# Cbc0038I Pass  29: suminf.   14.24955 (34) obj. -27.0499 iterations 15
# Cbc0038I Pass  30: suminf.   12.65063 (32) obj. -27.0499 iterations 12
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 91 rows 53 columns, reduced to 76 rows 44 columns
# Cbc0038I Mini branch and bound improved solution from -26 to -27 (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of -27 - took 0.01 seconds
# Cbc0012I Integer solution of -27 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0001I Search completed - best objective -27, took 0 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -27.5 to -27.5
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                27.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/anaconda3/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/c8551d8087b5416c9e94e7ff222bdbae-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/6c/m8gy3bzs5nv3gdd7vqsvb9940000gn/T/c8551d8087b5416c9e94e7ff222bdbae-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 1111 COLUMNS
# At line 3516 RHS
# At line 4623 BOUNDS
# At line 4688 ENDATA
# Problem MODEL has 1106 rows, 64 columns and 2212 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 32 - 0.00 seconds
# Cgl0003I 0 fixed, 0 tightened bounds, 1106 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 1019 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 981 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 806 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 400 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 161 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 51 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 4 strengthened rows, 0 substitutions
# Cgl0004I processed model has 836 rows, 64 columns (64 integer (64 of which binary)) and 5302 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 58 integers unsatisfied sum - 9.4685
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 6 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 836 rows 64 columns, reduced to 806 rows 58 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.20 seconds)
# Cbc0038I Round again with cutoff of -1.84676
# Cbc0038I Pass   1: suminf.    0.15324 (1) obj. -1.84676 iterations 168
# Cbc0038I Solution found of -2
# Cbc0038I Rounding solution of -5 is better than previous of -2
#
# Cbc0038I Before mini branch and bound, 5 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 836 rows 64 columns, reduced to 826 rows 59 columns - 2 fixed gives 24, 7 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.22 seconds)
# Cbc0038I Round again with cutoff of -6.69362
# Cbc0038I Pass   2: suminf.    6.69362 (40) obj. -6.69362 iterations 86
# Cbc0038I Pass   3: suminf.    4.11985 (38) obj. -6.69362 iterations 88
# Cbc0038I Pass   4: suminf.    2.41130 (53) obj. -6.69362 iterations 107
# Cbc0038I Pass   5: suminf.    4.69362 (16) obj. -6.69362 iterations 119
# Cbc0038I Pass   6: suminf.    2.47470 (48) obj. -6.69362 iterations 106
# Cbc0038I Pass   7: suminf.    2.21943 (55) obj. -6.69362 iterations 55
# Cbc0038I Pass   8: suminf.    2.52477 (31) obj. -6.69362 iterations 155
# Cbc0038I Pass   9: suminf.    2.08381 (45) obj. -6.69362 iterations 60
# Cbc0038I Pass  10: suminf.    5.69362 (14) obj. -6.69362 iterations 153
# Cbc0038I Pass  11: suminf.    3.80103 (25) obj. -6.69362 iterations 55
# Cbc0038I Pass  12: suminf.    2.21943 (55) obj. -6.69362 iterations 124
# Cbc0038I Pass  13: suminf.    2.34509 (32) obj. -6.69362 iterations 134
# Cbc0038I Pass  14: suminf.    2.08381 (45) obj. -6.69362 iterations 77
# Cbc0038I Pass  15: suminf.    6.28511 (20) obj. -6.69362 iterations 128
# Cbc0038I Pass  16: suminf.    4.64371 (16) obj. -6.69362 iterations 101
# Cbc0038I Pass  17: suminf.    1.53190 (5) obj. -6.69362 iterations 36
# Cbc0038I Solution found of -7
# Cbc0038I Before mini branch and bound, 3 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 836 rows 64 columns, reduced to 826 rows 61 columns - 3 fixed gives 4, 4 - ok now
# Cbc0038I Full problem 836 rows 64 columns, reduced to 0 rows 0 columns
# Cbc0038I Mini branch and bound did not improve solution (0.31 seconds)
# Cbc0038I Round again with cutoff of -8.44048
# Cbc0038I Pass  18: suminf.    8.44048 (51) obj. -8.44048 iterations 140
# Cbc0038I Pass  19: suminf.    8.06641 (48) obj. -8.44048 iterations 107
# Cbc0038I Pass  20: suminf.    7.56772 (44) obj. -8.44048 iterations 55
# Cbc0038I Pass  21: suminf.    8.13249 (40) obj. -8.44048 iterations 75
# Cbc0038I Pass  22: suminf.    6.73776 (48) obj. -8.44048 iterations 110
# Cbc0038I Pass  23: suminf.    8.16884 (35) obj. -8.44048 iterations 85
# Cbc0038I Pass  24: suminf.    7.62949 (43) obj. -8.44048 iterations 64
# Cbc0038I Pass  25: suminf.    7.50272 (48) obj. -8.44048 iterations 77
# Cbc0038I Pass  26: suminf.    6.59129 (51) obj. -8.44048 iterations 76
# Cbc0038I Pass  27: suminf.    6.52207 (54) obj. -8.44048 iterations 21
# Cbc0038I Pass  28: suminf.    8.20373 (44) obj. -8.44048 iterations 118
# Cbc0038I Pass  29: suminf.    6.82272 (54) obj. -8.44048 iterations 72
# Cbc0038I Pass  30: suminf.    6.58250 (54) obj. -8.44048 iterations 38
# Cbc0038I Pass  31: suminf.    7.81207 (46) obj. -8.44048 iterations 139
# Cbc0038I Pass  32: suminf.    7.40758 (52) obj. -8.44048 iterations 66
# Cbc0038I Pass  33: suminf.    7.91138 (31) obj. -8.44048 iterations 101
# Cbc0038I Pass  34: suminf.    6.73776 (48) obj. -8.44048 iterations 106
# Cbc0038I Pass  35: suminf.    8.04990 (34) obj. -8.44048 iterations 89
# Cbc0038I Pass  36: suminf.    7.08507 (50) obj. -8.44048 iterations 90
# Cbc0038I Pass  37: suminf.    7.87864 (45) obj. -8.44048 iterations 103
# Cbc0038I Pass  38: suminf.    7.58476 (49) obj. -8.44048 iterations 106
# Cbc0038I Pass  39: suminf.    7.44048 (39) obj. -8.44048 iterations 86
# Cbc0038I Pass  40: suminf.    6.73776 (48) obj. -8.44048 iterations 76
# Cbc0038I Pass  41: suminf.    8.15029 (38) obj. -8.44048 iterations 100
# Cbc0038I Pass  42: suminf.    8.44048 (48) obj. -8.44048 iterations 110
# Cbc0038I Pass  43: suminf.    8.44048 (51) obj. -8.44048 iterations 130
# Cbc0038I Pass  44: suminf.    8.37283 (47) obj. -8.44048 iterations 86
# Cbc0038I Pass  45: suminf.    7.43128 (51) obj. -8.44048 iterations 90
# Cbc0038I Pass  46: suminf.    7.04212 (49) obj. -8.44048 iterations 57
# Cbc0038I Pass  47: suminf.    6.73776 (48) obj. -8.44048 iterations 49
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 0 continuous
# Cbc0038I Mini branch and bound did not improve solution (0.41 seconds)
# Cbc0038I Round again with cutoff of -8.74888
# Cbc0038I Pass  47: suminf.    8.74888 (56) obj. -8.74888 iterations 33
# Cbc0038I Pass  48: suminf.    8.72283 (48) obj. -8.74888 iterations 92
# Cbc0038I Pass  49: suminf.    8.02362 (56) obj. -8.74888 iterations 85
# Cbc0038I Pass  50: suminf.    7.76296 (54) obj. -8.74888 iterations 56
# Cbc0038I Pass  51: suminf.    8.24228 (42) obj. -8.74888 iterations 77
# Cbc0038I Pass  52: suminf.    7.40385 (50) obj. -8.74888 iterations 85
# Cbc0038I Pass  53: suminf.    8.40843 (44) obj. -8.74888 iterations 78
# Cbc0038I Pass  54: suminf.    8.02464 (46) obj. -8.74888 iterations 85
# Cbc0038I Pass  55: suminf.    8.16202 (41) obj. -8.74888 iterations 54
# Cbc0038I Pass  56: suminf.    8.70557 (49) obj. -8.74888 iterations 101
# Cbc0038I Pass  57: suminf.    8.32063 (50) obj. -8.74888 iterations 89
# Cbc0038I Pass  58: suminf.    7.82837 (51) obj. -8.74888 iterations 69
# Cbc0038I Pass  59: suminf.    8.56740 (44) obj. -8.74888 iterations 76
# Cbc0038I Pass  60: suminf.    7.94243 (46) obj. -8.74888 iterations 82
# Cbc0038I Pass  61: suminf.    8.33010 (45) obj. -8.74888 iterations 71
# Cbc0038I Pass  62: suminf.    7.71573 (46) obj. -8.74888 iterations 76
# Cbc0038I Pass  63: suminf.    8.66255 (44) obj. -8.74888 iterations 94
# Cbc0038I Pass  64: suminf.    8.02464 (46) obj. -8.74888 iterations 136
# Cbc0038I Pass  65: suminf.    8.18051 (43) obj. -8.74888 iterations 69
# Cbc0038I Pass  66: suminf.    8.37781 (47) obj. -8.74888 iterations 127
# Cbc0038I Pass  67: suminf.    7.79130 (47) obj. -8.74888 iterations 95
# Cbc0038I Pass  68: suminf.    8.15424 (49) obj. -8.74888 iterations 86
# Cbc0038I Pass  69: suminf.    7.71407 (50) obj. -8.74888 iterations 74
# Cbc0038I Pass  70: suminf.    8.37632 (39) obj. -8.74888 iterations 91
# Cbc0038I Pass  71: suminf.    8.02464 (46) obj. -8.74888 iterations 83
# Cbc0038I Pass  72: suminf.    8.12673 (45) obj. -8.74888 iterations 52
# Cbc0038I Pass  73: suminf.    7.68047 (50) obj. -8.74888 iterations 70
# Cbc0038I Pass  74: suminf.    8.31703 (42) obj. -8.74888 iterations 65
# Cbc0038I Pass  75: suminf.    8.39354 (48) obj. -8.74888 iterations 111
# Cbc0038I Pass  76: suminf.    8.58542 (49) obj. -8.74888 iterations 118
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 836 rows 64 columns, reduced to 832 rows 64 columns - 1 fixed gives 376, 27 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.53 seconds)
# Cbc0038I After 0.53 seconds - Feasibility pump exiting with objective of -7 - took 0.32 seconds
# Cbc0012I Integer solution of -7 found by feasibility pump after 0 iterations and 0 nodes (0.53 seconds)
# Cbc0031I 18 added rows had average density of 22.5
# Cbc0013I At root node, 18 cuts changed objective from -9.4684965 to -9.1009785 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 7.0 elements, 0 column cuts (0 active)  in 0.120 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 2556 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.025 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 40 row cuts average 6.3 elements, 0 column cuts (0 active)  in 0.048 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.042 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.004 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 496 row cuts average 64.0 elements, 0 column cuts (0 active)  in 0.111 seconds - new frequency is 1
# Cbc0010I After 0 nodes, 1 on tree, -7 best solution, best possible -9.1009785 (2.10 seconds)
# Cbc0001I Search completed - best objective -7, took 14966 iterations and 20 nodes (3.05 seconds)
# Cbc0032I Strong branching done 394 times (19877 iterations), fathomed 1 nodes and fixed 0 variables
# Cbc0035I Maximum depth 9, 8 variables fixed on reduced cost
# Cuts at root node changed objective from -9.4685 to -9.10098
# Probing was tried 100 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.120 seconds)
# Gomory was tried 100 times and created 2556 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.025 seconds)
# Clique was tried 100 times and created 40 cuts of which 0 were active after adding rounds of cuts (0.048 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.042 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.004 seconds)
# TwoMirCuts was tried 114 times and created 972 cuts of which 0 were active after adding rounds of cuts (0.139 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.006 seconds)
#
# Result - Optimal solution found
#
# Objective value:                7.00000000
# Enumerated nodes:               20
# Total iterations:               14966
# Time (CPU seconds):             3.01
# Time (Wallclock seconds):       3.07
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       3.01   (Wallclock seconds):       3.07
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
